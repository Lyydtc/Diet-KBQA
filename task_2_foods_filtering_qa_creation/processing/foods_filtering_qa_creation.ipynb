# %% [markdown]
# <!-- #### Step 1: remove rows where food_desc == ingredient_dec -->

# %% [markdown]
# ### **Approach 1 (did not work): making API calls to `food.com` to find if a corresponding url can be retrieved for a food item**

# %% [markdown]
# Using the name of the food and try to look up on food.com directly kept returning error code 200

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import time
import random

foods_df = pd.read_csv('../processed_data/foods_list.csv.csv')

# Function to search Food.com for a specific food item
def find_recipe_on_food_com(food_desc):
    # Format the search URL
    search_url = f"https://www.food.com/search/{food_desc.replace(' ', '%20')}"
    
    try:
        # Send a GET request to Food.com
        response = requests.get(search_url, headers={'User-Agent': 'Mozilla/5.0'})
        
        # Debugging: Print status code
        print(f"Requesting {search_url}, Status Code: {response.status_code}")

        if response.status_code == 200:
            # Parse the HTML response with BeautifulSoup
            soup = BeautifulSoup(response.content, 'html.parser')
            
            # Look for recipe results
            recipe_cards = soup.find_all('div', class_='card__detailsContainer-left')
            if recipe_cards:
                # Extract the first recipe link as an example
                first_recipe = recipe_cards[0]
                recipe_link_tag = first_recipe.find('a', href=True)
                if recipe_link_tag:
                    recipe_url = "https://www.food.com" + recipe_link_tag['href']
                    return True, recipe_url
            return False, None
        else:
            print(f"Failed to retrieve results for {food_desc} (status code: {response.status_code})")
            return False, None
    except Exception as e:
        print(f"Error while searching for {food_desc}: {e}")
        return False, None

# Filter the foods dataframe and collect those that are found on Food.com
filtered_foods = []
matched_foods = []

for _, row in foods_df.iterrows():
    food_desc = row['food_desc']
    found, recipe_url = find_recipe_on_food_com(food_desc)
    if found:
        # Append row and the recipe URL to the list
        row_dict = row.to_dict()
        row_dict['recipe_url'] = recipe_url
        matched_foods.append(row_dict)
        print(f"Found recipe for '{food_desc}': {recipe_url}")
    else:
        filtered_foods.append(row)
    
    # Randomized sleep to avoid rate limiting
    time.sleep(random.uniform(3, 7))

filtered_foods_df = pd.DataFrame(filtered_foods)
matched_foods_df = pd.DataFrame(matched_foods)

filtered_foods_df.to_csv('../processed_data/food.com_filtered_foods_df.csv', index=False)
matched_foods_df.to_csv('../processed_data/food.com_matched_foods_df.csv', index=False)
# Out:
# Requesting https://www.food.com/search/Hard%20candy, Status Code: 200
# Requesting https://www.food.com/search/Soft%20drink,%20root%20beer, Status Code: 200
# Requesting https://www.food.com/search/Potato%20chips,%20baked,%20flavored, Status Code: 200
# Requesting https://www.food.com/search/Ham,%20prepackaged%20or%20deli,%20luncheon%20meat,%20reduced%20sodium, Status Code: 200
# Requesting https://www.food.com/search/Bread,%20wheat%20or%20cracked%20wheat, Status Code: 200
# Requesting https://www.food.com/search/Mayonnaise-type%20salad%20dressing, Status Code: 200
# Requesting https://www.food.com/search/Popcorn,%20air-popped,%20no%20butter%20added, Status Code: 200
# Requesting https://www.food.com/search/Fruit%20flavored%20drink,%20powdered,%20reconstituted, Status Code: 200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 59
#      56         filtered_foods.append(row)
#      58     # Randomized sleep to avoid rate limiting
# ---> 59     time.sleep(random.uniform(3, 7))
#      61 filtered_foods_df = pd.DataFrame(filtered_foods)
#      62 matched_foods_df = pd.DataFrame(matched_foods)
#
# KeyboardInterrupt:

# %% [markdown]
# ### **Approach 2 (worked but not quite satisfactorily): same as approach 1 but looking up on AllRecipes.com**
#
#  also we should not use AllRecipes.com since it doesn't have the same nutrition facts as food.com

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ------------------------ --------------- 7.9/12.8 MB 37.3 MB/s eta 0:00:01
#      --------------------------------------- 12.8/12.8 MB 34.8 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in c:\users\halan\miniconda3\envs\mle\lib\site-packages (from en-core-web-sm==3.7.1) (3.7.6)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\halan\miniconda3\envs\mle\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\halan\miniconda3\envs\mle\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\halan\miniconda3\envs\mle\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\halan\miniconda3\envs\mle\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\halan\miniconda3\envs\mle\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\halan\miniconda3\envs\mle\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\halan\miniconda3\envs\mle\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\halan\miniconda3\envs\mle\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\halan\miniconda3\envs\mle\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\halan\miniconda3\envs\mle\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\halan\miniconda3\envs\mle\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.12.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\halan\miniconda3\envs\mle\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.66.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\halan\miniconda3\envs\mle\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\halan\miniconda3\envs\mle\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.8.2)
# Requirement already satisfied: jinja2 in c:\users\halan\miniconda3\envs\mle\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\halan\miniconda3\envs\mle\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (72.1.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\halan\miniconda3\envs\mle\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\halan\miniconda3\envs\mle\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4.1)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\halan\miniconda3\envs\mle\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.21.5)
# Requirement already satisfied: language-data>=1.2 in c:\users\halan\miniconda3\envs\mle\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\halan\miniconda3\envs\mle\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\halan\miniconda3\envs\mle\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\halan\miniconda3\envs\mle\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\halan\miniconda3\envs\mle\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\halan\miniconda3\envs\mle\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\halan\miniconda3\envs\mle\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\halan\miniconda3\envs\mle\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2024.8.30)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\halan\miniconda3\envs\mle\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\halan\miniconda3\envs\mle\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.5)
# Requirement already satisfied: colorama in c:\users\halan\miniconda3\envs\mle\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\halan\miniconda3\envs\mle\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\halan\miniconda3\envs\mle\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\halan\miniconda3\envs\mle\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (13.8.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\halan\miniconda3\envs\mle\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.19.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\halan\miniconda3\envs\mle\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\halan\miniconda3\envs\mle\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.3)
# Requirement already satisfied: marisa-trie>=0.7.7 in c:\users\halan\miniconda3\envs\mle\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\halan\miniconda3\envs\mle\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\halan\miniconda3\envs\mle\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\halan\miniconda3\envs\mle\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.2)
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.7.1
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import pandas as pd
import time
import re
from allrecipes import AllRecipes
from transformers import pipeline, AutoModelForCausalLM, AutoTokenizer
import spacy

# Load your dataset
file_path = '../processed_data/foods_list.csv'
foods_df = pd.read_csv(file_path)

# Load an open-source LLM (using GPT-Neo here as an example)
model_name = "EleutherAI/gpt-neo-1.3B"  # You can replace this with another open-source model
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)
generator = pipeline("text-generation", model=model, tokenizer=tokenizer)

# Load spaCy model for fallback noun extraction
nlp = spacy.load("en_core_web_sm")

# Rule-based simplification function
def rule_based_simplify(food_desc):
    # Convert to lowercase for uniformity
    food_desc = food_desc.lower()

    # # Remove known unnecessary words and phrases
    # food_desc = re.sub(r'\b(no butter added|reduced sodium|low fat|unsweetened|packaged|prepackaged|deli|flavored|optional)\b', '', food_desc, flags=re.IGNORECASE)

    # Keep only the first 2-3 key terms (focus on the core description)
    simplified_name = " ".join(food_desc.split()[:3])

    # Remove conjunctions and unnecessary small words like "or", "and", "with", etc.
    simplified_name = re.sub(r'\b(or|and|with)\b', '', simplified_name)

    # Strip unnecessary commas, trailing or leading whitespaces
    simplified_name = re.sub(r',', '', simplified_name).strip()

    return simplified_name

# Function to extract the main food noun from the food description using a rule-based approach with spaCy, and fallback to LLM if necessary
def extract_main_noun(food_desc):
    # First try extracting with spaCy
    main_noun = extract_main_noun_spacy(food_desc)
    if main_noun:
        return main_noun

    # If spaCy fails, use the LLM
    prompt = f"From the following food description, extract only one word that is the main food noun: '{food_desc}'. Make sure it is the most important word that describes the food."
    try:
        response = generator(prompt, max_new_tokens=5, temperature=0.2, num_return_sequences=1)
        main_noun = response[0]['generated_text'].strip().split()[0]  # Extract the first word of the LLM response

        # Log the extracted main noun
        print(f"Extracted main noun: '{main_noun}' from '{food_desc}'")
        return main_noun

    except Exception as e:
        print(f"Error while extracting main noun for '{food_desc}' using LLM: {e}")
        return ""

# Function to extract the main noun using spaCy
def extract_main_noun_spacy(food_desc):
    doc = nlp(food_desc)
    nouns = [token.text for token in doc if token.pos_ == "NOUN"]
    if nouns:
        main_noun = nouns[0]  # Choose the first noun as the main food item
        print(f"spaCy extracted main noun: '{main_noun}' from '{food_desc}'")
        return main_noun
    else:
        print(f"No noun found in '{food_desc}' using spaCy.")
        return ""

# Function to use allrecipes package to search AllRecipes.com for a specific food item
def find_recipe_on_allrecipes(food_desc):
    # Use combined approach to simplify the food description
    simplified_name = rule_based_simplify(food_desc)
    print(f"Simplified food name for AllRecipes: '{simplified_name}' from '{food_desc}'")

    try:
        # Use AllRecipes package to perform the search
        query_result = AllRecipes.search(simplified_name)

        # If no results found, print a message for debugging
        if not query_result:
            print(f"No recipe found for '{simplified_name}' on AllRecipes.")
            return False, None

        # Get the details of the first returned recipe
        main_recipe_url = query_result[0]['url']

        # Extract the main food noun for validation
        main_noun = extract_main_noun(food_desc)

        # Check if the main noun appears in the URL
        if main_noun and main_noun.lower() in main_recipe_url.lower():
            return True, main_recipe_url
        else:
            print(f"Recipe URL '{main_recipe_url}' does not match the main noun '{main_noun}' from '{food_desc}'.")
            return False, None

    except Exception as e:
        print(f"Error while searching for '{simplified_name}' on AllRecipes: {e}")
        return False, None

filtered_foods = []
matched_foods = []

for _, row in foods_df.iterrows():
    food_desc = row['food_desc']
    found, recipe_url = find_recipe_on_allrecipes(food_desc)

    if found:
        row_dict = row.to_dict()
        row_dict['recipe_url'] = recipe_url
        matched_foods.append(row_dict)
        print(f"Found recipe for '{food_desc}': {recipe_url}")
    else:
        filtered_foods.append(row)

    time.sleep(3)

filtered_foods_df = pd.DataFrame(filtered_foods)
matched_foods_df = pd.DataFrame(matched_foods)

filtered_foods_df.to_csv('../processed_data/filtered_foods_df.csv', index=False)
matched_foods_df.to_csv('../processed_data/matched_foods_df.csv', index=False)

print("Filtered data saved to 'filtered_foods_df.csv'")
print("Matched data saved to 'matched_foods_df.csv'")
# Out:
# Simplified food name for AllRecipes: 'hard candy' from 'Hard candy'
# spaCy extracted main noun: 'candy' from 'Hard candy'
# Found recipe for 'Hard candy': https://www.allrecipes.com/recipe/35842/hard-candy/
# Simplified food name for AllRecipes: 'soft drink root' from 'Soft drink, root beer'
# spaCy extracted main noun: 'drink' from 'Soft drink, root beer'
# Recipe URL 'https://www.allrecipes.com/recipe/284771/old-fashioned-root-beer-slushy/' does not match the main noun 'drink' from 'Soft drink, root beer'.
# Simplified food name for AllRecipes: 'potato chips baked' from 'Potato chips, baked, flavored'
# spaCy extracted main noun: 'chips' from 'Potato chips, baked, flavored'
# Recipe URL 'https://www.allrecipes.com/recipe/8848/potato-chip-chicken-casserole/' does not match the main noun 'chips' from 'Potato chips, baked, flavored'.
# Simplified food name for AllRecipes: 'ham' from 'Ham, prepackaged or deli, luncheon meat, reduced sodium'
# spaCy extracted main noun: 'Ham' from 'Ham, prepackaged or deli, luncheon meat, reduced sodium'
# Found recipe for 'Ham, prepackaged or deli, luncheon meat, reduced sodium': https://www.allrecipes.com/recipe/24501/tangy-honey-glazed-ham/
# Simplified food name for AllRecipes: 'bread wheat' from 'Bread, wheat or cracked wheat'
# spaCy extracted main noun: 'wheat' from 'Bread, wheat or cracked wheat'
# Found recipe for 'Bread, wheat or cracked wheat': https://www.allrecipes.com/recipe/142267/steakhouse-wheat-bread-for-the-bread-machine/
# Simplified food name for AllRecipes: 'mayonnaise-type salad dressing' from 'Mayonnaise-type salad dressing'
# spaCy extracted main noun: 'Mayonnaise' from 'Mayonnaise-type salad dressing'
# Recipe URL 'https://www.allrecipes.com/recipe/8499/basic-chicken-salad/' does not match the main noun 'Mayonnaise' from 'Mayonnaise-type salad dressing'.
# Simplified food name for AllRecipes: 'popcorn air-popped' from 'Popcorn, air-popped, no butter added'
# spaCy extracted main noun: 'Popcorn' from 'Popcorn, air-popped, no butter added'
# Found recipe for 'Popcorn, air-popped, no butter added': https://www.allrecipes.com/recipe/59854/cinnamon-sugar-popcorn/
# Simplified food name for AllRecipes: 'fruit drink powdered' from 'Fruit flavored drink, powdered, reconstituted'
# spaCy extracted main noun: 'Fruit' from 'Fruit flavored drink, powdered, reconstituted'
# Recipe URL 'https://www.allrecipes.com/recipe/70908/drink-mix-jelly/' does not match the main noun 'Fruit' from 'Fruit flavored drink, powdered, reconstituted'.
# Simplified food name for AllRecipes: 'pretzels nfs' from 'Pretzels, NFS'
# No recipe found for 'pretzels nfs' on AllRecipes.
# Simplified food name for AllRecipes: 'cookie shortbread' from 'Cookie, shortbread'
# spaCy extracted main noun: 'shortbread' from 'Cookie, shortbread'
# Found recipe for 'Cookie, shortbread': https://www.allrecipes.com/recipe/10269/shortbread-cookies-ii/
# Simplified food name for AllRecipes: 'crackers sandwich peanut' from 'Crackers, sandwich, peanut butter filled'
# spaCy extracted main noun: 'Crackers' from 'Crackers, sandwich, peanut butter filled'
# Found recipe for 'Crackers, sandwich, peanut butter filled': https://www.allrecipes.com/recipe/10445/chocolate-coated-peanut-butter-crackers/
# Simplified food name for AllRecipes: 'chicken thigh sauteed' from 'Chicken thigh, sauteed, skin not eaten'
# spaCy extracted main noun: 'Chicken' from 'Chicken thigh, sauteed, skin not eaten'
# Found recipe for 'Chicken thigh, sauteed, skin not eaten': https://www.allrecipes.com/recipe/273489/creamy-chipotle-chicken-thighs-with-sauteed-squash/
# Simplified food name for AllRecipes: 'chicken drumstick sauteed' from 'Chicken drumstick, sauteed, skin not eaten'
# spaCy extracted main noun: 'Chicken' from 'Chicken drumstick, sauteed, skin not eaten'
# Recipe URL 'https://www.allrecipes.com/recipe/28376/black-bean-mushroom-happy/' does not match the main noun 'Chicken' from 'Chicken drumstick, sauteed, skin not eaten'.
# Simplified food name for AllRecipes: 'potato salad' from 'Potato salad with egg, made with mayonnaise'
# spaCy extracted main noun: 'egg' from 'Potato salad with egg, made with mayonnaise'
# Recipe URL 'https://www.allrecipes.com/recipe/16729/old-fashioned-potato-salad/' does not match the main noun 'egg' from 'Potato salad with egg, made with mayonnaise'.
# Simplified food name for AllRecipes: 'roll white soft' from 'Roll, white, soft'
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# No noun found in 'Roll, white, soft' using spaCy.
# Extracted main noun: 'From' from 'Roll, white, soft'
# Recipe URL 'https://www.allrecipes.com/recipe/15295/soft-sugar-cookies-iv/' does not match the main noun 'From' from 'Roll, white, soft'.
# Simplified food name for AllRecipes: 'fruit juice drink' from 'Fruit juice drink'
# spaCy extracted main noun: 'Fruit' from 'Fruit juice drink'
# Found recipe for 'Fruit juice drink': https://www.allrecipes.com/recipe/20699/exotic-fruit-drink/
# Simplified food name for AllRecipes: 'egg salad made' from 'Egg Salad, made with any type of fat free dressing'
# spaCy extracted main noun: 'type' from 'Egg Salad, made with any type of fat free dressing'
# Recipe URL 'https://www.allrecipes.com/recipe/103767/jens-heavenly-egg-salad/' does not match the main noun 'type' from 'Egg Salad, made with any type of fat free dressing'.
# Simplified food name for AllRecipes: 'grits instant made' from 'Grits, instant, made with water, no added fat'
# spaCy extracted main noun: 'Grits' from 'Grits, instant, made with water, no added fat'
# Found recipe for 'Grits, instant, made with water, no added fat': https://www.allrecipes.com/recipe/8445903/microwave-corn-cheese-grits-in-a-mug/
# Simplified food name for AllRecipes: 'butter tub' from 'Butter, tub'
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# No noun found in 'Butter, tub' using spaCy.
# Extracted main noun: 'From' from 'Butter, tub'
# Recipe URL 'https://www.allrecipes.com/recipe/246358/johnsonville-brat-hot-tub/' does not match the main noun 'From' from 'Butter, tub'.
# Simplified food name for AllRecipes: 'potato french fries' from 'Potato, french fries, fast food'
# spaCy extracted main noun: 'fries' from 'Potato, french fries, fast food'
# Found recipe for 'Potato, french fries, fast food': https://www.allrecipes.com/recipe/50223/homemade-crispy-seasoned-french-fries/
# Simplified food name for AllRecipes: 'chili con carne' from 'Chili con carne, NS as to beans'
# spaCy extracted main noun: 'carne' from 'Chili con carne, NS as to beans'
# Found recipe for 'Chili con carne, NS as to beans': https://www.allrecipes.com/recipe/89993/award-winning-chili-con-carne/
# Simplified food name for AllRecipes: 'soft drink fruit' from 'Soft drink, fruit flavored, caffeine free'
# spaCy extracted main noun: 'drink' from 'Soft drink, fruit flavored, caffeine free'
# Recipe URL 'https://www.allrecipes.com/recipe/112336/strawberry-ginger-and-mint-sekanjabin/' does not match the main noun 'drink' from 'Soft drink, fruit flavored, caffeine free'.
# Simplified food name for AllRecipes: 'candy taffy' from 'Candy, taffy'
# spaCy extracted main noun: 'Candy' from 'Candy, taffy'
# Recipe URL 'https://www.allrecipes.com/recipe/24337/vinegar-taffy/' does not match the main noun 'Candy' from 'Candy, taffy'.
# Simplified food name for AllRecipes: 'tortilla chips plain' from 'Tortilla chips, plain'
# spaCy extracted main noun: 'chips' from 'Tortilla chips, plain'
# Recipe URL 'https://www.allrecipes.com/recipe/8389355/quick-and-easy-air-fryer-nachos/' does not match the main noun 'chips' from 'Tortilla chips, plain'.
# Simplified food name for AllRecipes: 'salsa red' from 'Salsa, red'
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# No noun found in 'Salsa, red' using spaCy.
# Extracted main noun: 'From' from 'Salsa, red'
# Recipe URL 'https://www.allrecipes.com/recipe/238420/fiery-red-salsa/' does not match the main noun 'From' from 'Salsa, red'.
# Simplified food name for AllRecipes: 'breakfast tart' from 'Breakfast tart'
# spaCy extracted main noun: 'Breakfast' from 'Breakfast tart'
# Found recipe for 'Breakfast tart': https://www.allrecipes.com/recipe/23378/country-manor-breakfast-tart/
# Simplified food name for AllRecipes: 'orange juice 100%' from 'Orange juice, 100%, canned, bottled or in a carton'
# spaCy extracted main noun: 'juice' from 'Orange juice, 100%, canned, bottled or in a carton'
# Recipe URL 'https://www.allrecipes.com/recipe/264721/orange-cream-pops/' does not match the main noun 'juice' from 'Orange juice, 100%, canned, bottled or in a carton'.
# Simplified food name for AllRecipes: 'chicken fillet grilled' from 'Chicken fillet, grilled'
# spaCy extracted main noun: 'Chicken' from 'Chicken fillet, grilled'
# Recipe URL 'https://www.allrecipes.com/recipe/143760/grilled-mahi-mahi-with-roasted-pepper-sauce-and-cilantro-pesto/' does not match the main noun 'Chicken' from 'Chicken fillet, grilled'.
# Simplified food name for AllRecipes: 'ketchup' from 'Ketchup'
# spaCy extracted main noun: 'Ketchup' from 'Ketchup'
# Found recipe for 'Ketchup': https://www.allrecipes.com/recipe/232397/homemade-ketchup/
# Simplified food name for AllRecipes: 'soft drink cola' from 'Soft drink, cola'
# spaCy extracted main noun: 'drink' from 'Soft drink, cola'
# Recipe URL 'https://www.allrecipes.com/recipe/7502/coco-cola-cake-ii/' does not match the main noun 'drink' from 'Soft drink, cola'.
# Simplified food name for AllRecipes: 'cookie chocolate chip' from 'Cookie, chocolate chip'
# spaCy extracted main noun: 'chocolate' from 'Cookie, chocolate chip'
# Found recipe for 'Cookie, chocolate chip': https://www.allrecipes.com/recipe/10813/best-chocolate-chip-cookies/
# Simplified food name for AllRecipes: 'pizza  pepperoni' from 'Pizza with pepperoni, from frozen, thick crust'
# spaCy extracted main noun: 'Pizza' from 'Pizza with pepperoni, from frozen, thick crust'
# Found recipe for 'Pizza with pepperoni, from frozen, thick crust': https://www.allrecipes.com/recipe/233222/easy-pepperoni-pizza-muffins/
# Simplified food name for AllRecipes: 'lemonade frozen concentrate' from 'Lemonade, frozen concentrate, not reconstituted'
# spaCy extracted main noun: 'concentrate' from 'Lemonade, frozen concentrate, not reconstituted'
# Recipe URL 'https://www.allrecipes.com/recipe/71929/frozen-strawberry-lemonade/' does not match the main noun 'concentrate' from 'Lemonade, frozen concentrate, not reconstituted'.
# Simplified food name for AllRecipes: 'egg cheese' from 'Egg, cheese, and sausage griddle cake sandwich'
# spaCy extracted main noun: 'cheese' from 'Egg, cheese, and sausage griddle cake sandwich'
# Found recipe for 'Egg, cheese, and sausage griddle cake sandwich': https://www.allrecipes.com/recipe/241166/fast-and-fabulous-egg-and-cottage-cheese-casserole/
# Simplified food name for AllRecipes: 'ravioli cheese' from 'Ravioli, cheese and spinach filled, with tomato sauce'
# spaCy extracted main noun: 'cheese' from 'Ravioli, cheese and spinach filled, with tomato sauce'
# Found recipe for 'Ravioli, cheese and spinach filled, with tomato sauce': https://www.allrecipes.com/recipe/213131/homemade-four-cheese-ravioli/
# Simplified food name for AllRecipes: 'garlic bread from' from 'Garlic bread, from frozen'
# spaCy extracted main noun: 'bread' from 'Garlic bread, from frozen'
# Found recipe for 'Garlic bread, from frozen': https://www.allrecipes.com/recipe/75133/roasted-garlic-bread/
# Simplified food name for AllRecipes: 'egg cheese' from 'Egg, cheese, and bacon on biscuit'
# spaCy extracted main noun: 'cheese' from 'Egg, cheese, and bacon on biscuit'
# Found recipe for 'Egg, cheese, and bacon on biscuit': https://www.allrecipes.com/recipe/241166/fast-and-fabulous-egg-and-cottage-cheese-casserole/
# Simplified food name for AllRecipes: 'chocolate milk ready' from 'Chocolate milk, ready to drink, whole'
# spaCy extracted main noun: 'Chocolate' from 'Chocolate milk, ready to drink, whole'
# Found recipe for 'Chocolate milk, ready to drink, whole': https://www.allrecipes.com/recipe/17395/chocolate-eclair-cake/
# Simplified food name for AllRecipes: 'soft drink cola' from 'Soft drink, cola, fruit or vanilla flavored'
# spaCy extracted main noun: 'drink' from 'Soft drink, cola, fruit or vanilla flavored'
# Recipe URL 'https://www.allrecipes.com/recipe/7502/coco-cola-cake-ii/' does not match the main noun 'drink' from 'Soft drink, cola, fruit or vanilla flavored'.
# Simplified food name for AllRecipes: 'roll sweet cinnamon' from 'Roll, sweet, cinnamon bun, frosted'
# spaCy extracted main noun: 'Roll' from 'Roll, sweet, cinnamon bun, frosted'
# Recipe URL 'https://www.allrecipes.com/recipe/21461/ooey-gooey-cinnamon-buns/' does not match the main noun 'Roll' from 'Roll, sweet, cinnamon bun, frosted'.
# Simplified food name for AllRecipes: 'catfish coated fried' from 'Catfish, coated, fried, made with cooking spray'
# spaCy extracted main noun: 'cooking' from 'Catfish, coated, fried, made with cooking spray'
# Recipe URL 'https://www.allrecipes.com/recipe/140930/southern-fried-catfish/' does not match the main noun 'cooking' from 'Catfish, coated, fried, made with cooking spray'.
# Simplified food name for AllRecipes: 'cornbread prepared from' from 'Cornbread, prepared from mix'
# spaCy extracted main noun: 'mix' from 'Cornbread, prepared from mix'
# Recipe URL 'https://www.allrecipes.com/recipe/17891/golden-sweet-cornbread/' does not match the main noun 'mix' from 'Cornbread, prepared from mix'.
# Simplified food name for AllRecipes: 'okra batter-dipped fried' from 'Okra, batter-dipped, fried'
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# No noun found in 'Okra, batter-dipped, fried' using spaCy.
# Extracted main noun: 'From' from 'Okra, batter-dipped, fried'
# Recipe URL 'https://www.allrecipes.com/recipe/150306/the-best-chicken-fried-steak/' does not match the main noun 'From' from 'Okra, batter-dipped, fried'.
# Simplified food name for AllRecipes: 'coffee substitute dry' from 'Coffee substitute, dry powder'
# spaCy extracted main noun: 'Coffee' from 'Coffee substitute, dry powder'
# Found recipe for 'Coffee substitute, dry powder': https://www.allrecipes.com/recipe/278950/whole-wheat-pumpkin-coffee-cake-muffins/
# Simplified food name for AllRecipes: 'lemon juice 100%' from 'Lemon juice, 100%, freshly squeezed'
# spaCy extracted main noun: 'juice' from 'Lemon juice, 100%, freshly squeezed'
# Recipe URL 'https://www.allrecipes.com/recipe/265432/lemon-cheesecake-bars/' does not match the main noun 'juice' from 'Lemon juice, 100%, freshly squeezed'.
# Simplified food name for AllRecipes: 'sugar substitute saccharin' from 'Sugar substitute, saccharin, powder'
# No recipe found for 'sugar substitute saccharin' on AllRecipes.
# Simplified food name for AllRecipes: 'chocolate candy candy' from 'Chocolate candy, candy shell'
# spaCy extracted main noun: 'Chocolate' from 'Chocolate candy, candy shell'
# Found recipe for 'Chocolate candy, candy shell': https://www.allrecipes.com/recipe/25590/chocolate-candy-bar-cake/
# Simplified food name for AllRecipes: 'ice cream vanilla' from 'Ice cream, vanilla'
# spaCy extracted main noun: 'Ice' from 'Ice cream, vanilla'
# Found recipe for 'Ice cream, vanilla': https://www.allrecipes.com/recipe/233928/how-to-make-vanilla-ice-cream/
# Simplified food name for AllRecipes: 'topping chocolate' from 'Topping, chocolate'
# spaCy extracted main noun: 'chocolate' from 'Topping, chocolate'
# Found recipe for 'Topping, chocolate': https://www.allrecipes.com/recipe/8230/chocolate-cheesecake-ii/
# Simplified food name for AllRecipes: 'strawberries cooked' from 'Strawberries, cooked or canned, in syrup'
# spaCy extracted main noun: 'Strawberries' from 'Strawberries, cooked or canned, in syrup'
# Found recipe for 'Strawberries, cooked or canned, in syrup': https://www.allrecipes.com/recipe/77430/balsamic-strawberries/
# Simplified food name for AllRecipes: 'milk whole' from 'Milk, whole'
# spaCy extracted main noun: 'Milk' from 'Milk, whole'
# Found recipe for 'Milk, whole': https://www.allrecipes.com/recipe/7399/tres-leches-milk-cake/
# Simplified food name for AllRecipes: 'coffee brewed' from 'Coffee, brewed'
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# No noun found in 'Coffee, brewed' using spaCy.
# Extracted main noun: 'From' from 'Coffee, brewed'
# Recipe URL 'https://www.allrecipes.com/recipe/233721/cold-brewed-coffee/' does not match the main noun 'From' from 'Coffee, brewed'.
# Simplified food name for AllRecipes: 'sugar white granulated' from 'Sugar, white, granulated or lump'
# spaCy extracted main noun: 'lump' from 'Sugar, white, granulated or lump'
# Recipe URL 'https://www.allrecipes.com/recipe/10402/the-best-rolled-sugar-cookies/' does not match the main noun 'lump' from 'Sugar, white, granulated or lump'.
# Simplified food name for AllRecipes: 'coffee creamer powder' from 'Coffee creamer, powder'
# spaCy extracted main noun: 'creamer' from 'Coffee creamer, powder'
# Found recipe for 'Coffee creamer, powder': https://www.allrecipes.com/recipe/233504/coffee-creamer/
# Simplified food name for AllRecipes: 'vegetable chips' from 'Vegetable chips'
# spaCy extracted main noun: 'Vegetable' from 'Vegetable chips'
# Found recipe for 'Vegetable chips': https://www.allrecipes.com/recipe/283319/burrata-salad-with-fried-zucchini-and-vegetable-chips/
# Simplified food name for AllRecipes: 'turkey  chicken' from 'Turkey or chicken, pork, and beef sausage, reduced sodium'
# spaCy extracted main noun: 'chicken' from 'Turkey or chicken, pork, and beef sausage, reduced sodium'
# Found recipe for 'Turkey or chicken, pork, and beef sausage, reduced sodium': https://www.allrecipes.com/recipe/25139/chicken-or-turkey-tetrazzini-deluxe/
# Simplified food name for AllRecipes: 'soft drink ginger' from 'Soft drink, ginger ale'
# spaCy extracted main noun: 'drink' from 'Soft drink, ginger ale'
# Recipe URL 'https://www.allrecipes.com/recipe/110656/ginger-sekanjabin/' does not match the main noun 'drink' from 'Soft drink, ginger ale'.
# Simplified food name for AllRecipes: 'chewing gum nfs' from 'Chewing gum, NFS'
# No recipe found for 'chewing gum nfs' on AllRecipes.
# Simplified food name for AllRecipes: 'beer light' from 'Beer, light'
# spaCy extracted main noun: 'Beer' from 'Beer, light'
# Found recipe for 'Beer, light': https://www.allrecipes.com/recipe/12824/beer-batter/
# Simplified food name for AllRecipes: 'macaroni  noodles' from 'Macaroni or noodles with cheese, canned'
# spaCy extracted main noun: 'noodles' from 'Macaroni or noodles with cheese, canned'
# Recipe URL 'https://www.allrecipes.com/recipe/81108/classic-macaroni-salad/' does not match the main noun 'noodles' from 'Macaroni or noodles with cheese, canned'.
# Simplified food name for AllRecipes: 'chicken breast sauteed' from 'Chicken breast, sauteed, skin not eaten'
# spaCy extracted main noun: 'Chicken' from 'Chicken breast, sauteed, skin not eaten'
# Found recipe for 'Chicken breast, sauteed, skin not eaten': https://www.allrecipes.com/recipe/23811/chicken-diane-style/
# Simplified food name for AllRecipes: 'milk reduced fat' from 'Milk, reduced fat (2%)'
# spaCy extracted main noun: 'Milk' from 'Milk, reduced fat (2%)'
# Recipe URL 'https://www.allrecipes.com/recipe/21206/reduced-fat-french-toast/' does not match the main noun 'Milk' from 'Milk, reduced fat (2%)'.
# Simplified food name for AllRecipes: 'pie apple' from 'Pie, apple'
# spaCy extracted main noun: 'Pie' from 'Pie, apple'
# Found recipe for 'Pie, apple': https://www.allrecipes.com/recipe/12681/apple-pie-filling/
# Simplified food name for AllRecipes: 'chocolate syrup' from 'Chocolate syrup'
# spaCy extracted main noun: 'Chocolate' from 'Chocolate syrup'
# Found recipe for 'Chocolate syrup': https://www.allrecipes.com/recipe/210084/chocolate-syrup/
# Simplified food name for AllRecipes: 'baby toddler juice' from 'Baby Toddler juice, apple'
# No recipe found for 'baby toddler juice' on AllRecipes.
# Simplified food name for AllRecipes: 'tequila' from 'Tequila'
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# No noun found in 'Tequila' using spaCy.
# Extracted main noun: 'From' from 'Tequila'
# Recipe URL 'https://www.allrecipes.com/recipe/19127/restaurant-style-tequila-lime-chicken/' does not match the main noun 'From' from 'Tequila'.
# Simplified food name for AllRecipes: 'tea hot herbal' from 'Tea, hot, herbal'
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# No noun found in 'Tea, hot, herbal' using spaCy.
# Extracted main noun: 'From' from 'Tea, hot, herbal'
# Recipe URL 'https://www.allrecipes.com/recipe/40401/hot-toddy/' does not match the main noun 'From' from 'Tea, hot, herbal'.
# Simplified food name for AllRecipes: 'banana raw' from 'Banana, raw'
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# No noun found in 'Banana, raw' using spaCy.
# Extracted main noun: 'From' from 'Banana, raw'
# Recipe URL 'https://www.allrecipes.com/recipe/166611/alexs-raw-chocolate-pudding/' does not match the main noun 'From' from 'Banana, raw'.
# Simplified food name for AllRecipes: 'infant formula powder' from 'Infant formula, powder, made with water, NFS (Similac Go and Grow)'
# No recipe found for 'infant formula powder' on AllRecipes.
# Simplified food name for AllRecipes: 'honey' from 'Honey'
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# No noun found in 'Honey' using spaCy.
# Extracted main noun: 'From' from 'Honey'
# Recipe URL 'https://www.allrecipes.com/recipe/14745/honey-glazed-ham/' does not match the main noun 'From' from 'Honey'.
# Simplified food name for AllRecipes: 'fruit juice drink' from 'Fruit juice drink (Capri Sun)'
# spaCy extracted main noun: 'Fruit' from 'Fruit juice drink (Capri Sun)'
# Found recipe for 'Fruit juice drink (Capri Sun)': https://www.allrecipes.com/recipe/20699/exotic-fruit-drink/
# Simplified food name for AllRecipes: 'pork sausage' from 'Pork sausage, reduced sodium'
# spaCy extracted main noun: 'Pork' from 'Pork sausage, reduced sodium'
# Found recipe for 'Pork sausage, reduced sodium': https://www.allrecipes.com/recipe/22299/pork-sausage-and-cabbage-pitas/
# Simplified food name for AllRecipes: 'egg whole boiled' from 'Egg, whole, boiled or poached '
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# No noun found in 'Egg, whole, boiled or poached ' using spaCy.
# Extracted main noun: 'From' from 'Egg, whole, boiled or poached '
# Recipe URL 'https://www.allrecipes.com/recipe/213737/kens-perfect-hard-boiled-egg-and-i-mean-perfect/' does not match the main noun 'From' from 'Egg, whole, boiled or poached '.
# Simplified food name for AllRecipes: 'rice white cooked' from 'Rice, white, cooked with fat, Puerto Rican style'
# spaCy extracted main noun: 'Rice' from 'Rice, white, cooked with fat, Puerto Rican style'
# Found recipe for 'Rice, white, cooked with fat, Puerto Rican style': https://www.allrecipes.com/recipe/24059/creamy-rice-pudding/
# Simplified food name for AllRecipes: 'bread wheat' from 'Bread, wheat or cracked wheat, toasted'
# spaCy extracted main noun: 'wheat' from 'Bread, wheat or cracked wheat, toasted'
# Found recipe for 'Bread, wheat or cracked wheat, toasted': https://www.allrecipes.com/recipe/142267/steakhouse-wheat-bread-for-the-bread-machine/
# Simplified food name for AllRecipes: 'pork chop coated' from 'Pork, chop, coated, lean and fat eaten'
# spaCy extracted main noun: 'Pork' from 'Pork, chop, coated, lean and fat eaten'
# Found recipe for 'Pork, chop, coated, lean and fat eaten': https://www.allrecipes.com/recipe/234059/best-pork-chop-marinade/
# Simplified food name for AllRecipes: 'bread whole wheat' from 'Bread, whole wheat'
# spaCy extracted main noun: 'wheat' from 'Bread, whole wheat'
# Found recipe for 'Bread, whole wheat': https://www.allrecipes.com/recipe/21108/oatmeal-whole-wheat-quick-bread/
# Simplified food name for AllRecipes: 'whiskey' from 'Whiskey'
# spaCy extracted main noun: 'Whiskey' from 'Whiskey'
# Found recipe for 'Whiskey': https://www.allrecipes.com/recipe/220447/chocolate-beer-cupcakes-with-whiskey-filling-and-irish-cream-icing/
# Simplified food name for AllRecipes: 'potato chips fat' from 'Potato chips, fat free'
# spaCy extracted main noun: 'chips' from 'Potato chips, fat free'
# Recipe URL 'https://www.allrecipes.com/recipe/266404/crispy-baked-chicken-drumsticks/' does not match the main noun 'chips' from 'Potato chips, fat free'.
# Simplified food name for AllRecipes: 'pork sausage' from 'Pork sausage, reduced sodium'
# spaCy extracted main noun: 'Pork' from 'Pork sausage, reduced sodium'
# Found recipe for 'Pork sausage, reduced sodium': https://www.allrecipes.com/recipe/22299/pork-sausage-and-cabbage-pitas/
# Simplified food name for AllRecipes: 'biscuit from fast' from 'Biscuit, from fast food / restaurant'
# spaCy extracted main noun: 'food' from 'Biscuit, from fast food / restaurant'
# Recipe URL 'https://www.allrecipes.com/recipe/214153/monkey-bread-made-easy/' does not match the main noun 'food' from 'Biscuit, from fast food / restaurant'.
# Simplified food name for AllRecipes: 'jelly' from 'Jelly'
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# No noun found in 'Jelly' using spaCy.
# Extracted main noun: 'From' from 'Jelly'
# Recipe URL 'https://www.allrecipes.com/recipe/239824/grape-jelly-meatballs/' does not match the main noun 'From' from 'Jelly'.
# Simplified food name for AllRecipes: 'potato hash brown' from 'Potato, hash brown, from fresh, with cheese'
# spaCy extracted main noun: 'hash' from 'Potato, hash brown, from fresh, with cheese'
# Found recipe for 'Potato, hash brown, from fresh, with cheese': https://www.allrecipes.com/recipe/160132/simply-potatoes-cheesy-hash-browns/
# Simplified food name for AllRecipes: 'coffee substitute dry' from 'Coffee substitute, dry powder'
# spaCy extracted main noun: 'Coffee' from 'Coffee substitute, dry powder'
# Found recipe for 'Coffee substitute, dry powder': https://www.allrecipes.com/recipe/278950/whole-wheat-pumpkin-coffee-cake-muffins/
# Simplified food name for AllRecipes: 'double hamburger 2' from 'Double hamburger, 2 medium patties, with condiments, on bun, from fast food / restaurant (Wendy's 1/2 lb Double)'
# spaCy extracted main noun: 'hamburger' from 'Double hamburger, 2 medium patties, with condiments, on bun, from fast food / restaurant (Wendy's 1/2 lb Double)'
# Found recipe for 'Double hamburger, 2 medium patties, with condiments, on bun, from fast food / restaurant (Wendy's 1/2 lb Double)': https://www.allrecipes.com/recipe/233652/homemade-hamburger-buns/
# Simplified food name for AllRecipes: 'cereal (general mills' from 'Cereal (General Mills Cocoa Puffs)'
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# No noun found in 'Cereal (General Mills Cocoa Puffs)' using spaCy.
# Extracted main noun: 'From' from 'Cereal (General Mills Cocoa Puffs)'
# Recipe URL 'https://www.allrecipes.com/recipe/15820/puppy-chow/' does not match the main noun 'From' from 'Cereal (General Mills Cocoa Puffs)'.
# Simplified food name for AllRecipes: 'grape juice 100%' from 'Grape juice, 100%'
# No recipe found for 'grape juice 100%' on AllRecipes.
# Simplified food name for AllRecipes: 'pork  beans' from 'Pork and beans'
# spaCy extracted main noun: 'Pork' from 'Pork and beans'
# Found recipe for 'Pork and beans': https://www.allrecipes.com/recipe/236731/tender-pork-stew-with-beans/
# Simplified food name for AllRecipes: 'orange raw' from 'Orange, raw'
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# No noun found in 'Orange, raw' using spaCy.
# Extracted main noun: 'From' from 'Orange, raw'
# Recipe URL 'https://www.allrecipes.com/recipe/220406/raw-pad-thai/' does not match the main noun 'From' from 'Orange, raw'.
# Simplified food name for AllRecipes: 'bread white' from 'Bread, white'
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# No noun found in 'Bread, white' using spaCy.
# Extracted main noun: 'From' from 'Bread, white'
# Recipe URL 'https://www.allrecipes.com/recipe/6813/white-bread-for-the-bread-machine/' does not match the main noun 'From' from 'Bread, white'.
# Simplified food name for AllRecipes: 'peanut butter' from 'Peanut butter'
# spaCy extracted main noun: 'Peanut' from 'Peanut butter'
# Found recipe for 'Peanut butter': https://www.allrecipes.com/recipe/10670/peanut-butter-balls-iii/
# Simplified food name for AllRecipes: 'fish ns as' from 'Fish, NS as to type, from fast food'
# No recipe found for 'fish ns as' on AllRecipes.
# Simplified food name for AllRecipes: 'green beans fresh' from 'Green beans, fresh, cooked, fat added, NS as to fat type'
# spaCy extracted main noun: 'beans' from 'Green beans, fresh, cooked, fat added, NS as to fat type'
# Found recipe for 'Green beans, fresh, cooked, fat added, NS as to fat type': https://www.allrecipes.com/recipe/230103/buttery-garlic-green-beans/
# Simplified food name for AllRecipes: 'coffee instant reconstituted' from 'Coffee, instant, reconstituted'
# No recipe found for 'coffee instant reconstituted' on AllRecipes.
# Simplified food name for AllRecipes: 'soy milk' from 'Soy milk'
# spaCy extracted main noun: 'Soy' from 'Soy milk'
# Found recipe for 'Soy milk': https://www.allrecipes.com/recipe/69384/soy-milk-pancakes/
# Simplified food name for AllRecipes: 'oatmeal ns as' from 'Oatmeal, NS as to regular, quick, or instant, no added fat'
# No recipe found for 'oatmeal ns as' on AllRecipes.
# Simplified food name for AllRecipes: 'potato mashed nfs' from 'Potato, mashed, NFS'
# No recipe found for 'potato mashed nfs' on AllRecipes.
# Simplified food name for AllRecipes: 'gravy beef' from 'Gravy, beef or meat, fat free'
# spaCy extracted main noun: 'beef' from 'Gravy, beef or meat, fat free'
# Found recipe for 'Gravy, beef or meat, fat free': https://www.allrecipes.com/recipe/223374/beef-tips-and-merlot-gravy-with-beef-and-onion-rice/
# Simplified food name for AllRecipes: 'corn canned' from 'Corn, canned, reduced sodium, cooked, no added fat'
# spaCy extracted main noun: 'Corn' from 'Corn, canned, reduced sodium, cooked, no added fat'
# Found recipe for 'Corn, canned, reduced sodium, cooked, no added fat': https://www.allrecipes.com/recipe/214920/summer-anytime-crisp-corn-salad/
# Simplified food name for AllRecipes: 'margarine-oil blend tub' from 'Margarine-oil blend, tub, light'
# No recipe found for 'margarine-oil blend tub' on AllRecipes.
# Simplified food name for AllRecipes: 'slush frozen drink' from 'Slush frozen drink, no sugar added'
# spaCy extracted main noun: 'drink' from 'Slush frozen drink, no sugar added'
# Recipe URL 'https://www.allrecipes.com/recipe/32418/frozen-summer-slush/' does not match the main noun 'drink' from 'Slush frozen drink, no sugar added'.
# Simplified food name for AllRecipes: 'pudding chocolate ns' from 'Pudding, chocolate, NS as to from dry mix or ready-to-eat'
# No recipe found for 'pudding chocolate ns' on AllRecipes.
# Simplified food name for AllRecipes: 'apple raw' from 'Apple, raw'
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# No noun found in 'Apple, raw' using spaCy.
# Extracted main noun: 'From' from 'Apple, raw'
# Recipe URL 'https://www.allrecipes.com/recipe/8269/raw-apple-cake/' does not match the main noun 'From' from 'Apple, raw'.
# Simplified food name for AllRecipes: 'cereal (kellogg's frosted' from 'Cereal (Kellogg's Frosted Flakes)'
# No recipe found for 'cereal (kellogg's frosted' on AllRecipes.
# Simplified food name for AllRecipes: 'apple juice 100%' from 'Apple juice, 100%'
# spaCy extracted main noun: 'juice' from 'Apple juice, 100%'
# Recipe URL 'https://www.allrecipes.com/recipe/239259/spinach-salad-with-pomegranate-cranberry-dressing/' does not match the main noun 'juice' from 'Apple juice, 100%'.
# Simplified food name for AllRecipes: 'shrimp fried' from 'Shrimp, fried'
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# No noun found in 'Shrimp, fried' using spaCy.
# Extracted main noun: 'From' from 'Shrimp, fried'
# Recipe URL 'https://www.allrecipes.com/recipe/272834/easy-homemade-shrimp-fried-rice/' does not match the main noun 'From' from 'Shrimp, fried'.
# Simplified food name for AllRecipes: 'pizza  pepperoni' from 'Pizza with pepperoni, from frozen, thick crust'
# spaCy extracted main noun: 'Pizza' from 'Pizza with pepperoni, from frozen, thick crust'
# Found recipe for 'Pizza with pepperoni, from frozen, thick crust': https://www.allrecipes.com/recipe/233222/easy-pepperoni-pizza-muffins/
# Simplified food name for AllRecipes: 'soft drink cola' from 'Soft drink, cola, diet'
# spaCy extracted main noun: 'drink' from 'Soft drink, cola, diet'
# Recipe URL 'https://www.allrecipes.com/recipe/7502/coco-cola-cake-ii/' does not match the main noun 'drink' from 'Soft drink, cola, diet'.
# Simplified food name for AllRecipes: 'gelatin dessert dietetic' from 'Gelatin dessert, dietetic, with fruit, sweetened with low calorie sweetener'
# No recipe found for 'gelatin dessert dietetic' on AllRecipes.
# Simplified food name for AllRecipes: 'coffee instant decaffeinated' from 'Coffee, instant, decaffeinated, reconstituted'
# spaCy extracted main noun: 'Coffee' from 'Coffee, instant, decaffeinated, reconstituted'
# Found recipe for 'Coffee, instant, decaffeinated, reconstituted': https://www.allrecipes.com/recipe/284201/wake-up-coffee-jelly/
# Simplified food name for AllRecipes: 'pan dulce' from 'Pan Dulce, with sugar topping'
# spaCy extracted main noun: 'sugar' from 'Pan Dulce, with sugar topping'
# Recipe URL 'https://www.allrecipes.com/recipe/18117/pan-dulces/' does not match the main noun 'sugar' from 'Pan Dulce, with sugar topping'.
# Simplified food name for AllRecipes: 'spanish rice fat' from 'Spanish rice, fat added'
# spaCy extracted main noun: 'rice' from 'Spanish rice, fat added'
# Found recipe for 'Spanish rice, fat added': https://www.allrecipes.com/recipe/18830/spanish-rice-bake/
# Simplified food name for AllRecipes: 'pinto beans from' from 'Pinto beans, from dried, fat added'
# spaCy extracted main noun: 'Pinto' from 'Pinto beans, from dried, fat added'
# Found recipe for 'Pinto beans, from dried, fat added': https://www.allrecipes.com/recipe/220822/slow-cooker-pinto-beans/
# Simplified food name for AllRecipes: 'beef steak fried' from 'Beef steak, fried, lean and fat eaten'
# spaCy extracted main noun: 'Beef' from 'Beef steak, fried, lean and fat eaten'
# Recipe URL 'https://www.allrecipes.com/recipe/214770/chicken-fried-steak-with-cream-pork-sausage-gravy/' does not match the main noun 'Beef' from 'Beef steak, fried, lean and fat eaten'.
# Simplified food name for AllRecipes: 'tortilla corn' from 'Tortilla, corn'
# spaCy extracted main noun: 'corn' from 'Tortilla, corn'
# Found recipe for 'Tortilla, corn': https://www.allrecipes.com/recipe/23936/corn-tortilla-chips/
# Simplified food name for AllRecipes: 'cookie sandwich-type not' from 'Cookie, sandwich-type, not chocolate or vanilla'
# spaCy extracted main noun: 'sandwich' from 'Cookie, sandwich-type, not chocolate or vanilla'
# Found recipe for 'Cookie, sandwich-type, not chocolate or vanilla': https://www.allrecipes.com/recipe/220775/english-tea-cucumber-sandwiches/
# Simplified food name for AllRecipes: 'pork stew no' from 'Pork stew, no potatoes, tomato-based sauce, Mexican style'
# spaCy extracted main noun: 'Pork' from 'Pork stew, no potatoes, tomato-based sauce, Mexican style'
# Found recipe for 'Pork stew, no potatoes, tomato-based sauce, Mexican style': https://www.allrecipes.com/recipe/236988/chef-johns-irish-pork-stew/
# Simplified food name for AllRecipes: 'cabbage green raw' from 'Cabbage, green, raw'
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# No noun found in 'Cabbage, green, raw' using spaCy.
# Extracted main noun: 'From' from 'Cabbage, green, raw'
# Recipe URL 'https://www.allrecipes.com/recipe/281314/lemon-tahini-quinoa-with-raw-chickpeas/' does not match the main noun 'From' from 'Cabbage, green, raw'.
# Simplified food name for AllRecipes: 'bread white toasted' from 'Bread, white, toasted'
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# No noun found in 'Bread, white, toasted' using spaCy.
# Extracted main noun: 'From' from 'Bread, white, toasted'
# Recipe URL 'https://www.allrecipes.com/recipe/6788/amish-white-bread/' does not match the main noun 'From' from 'Bread, white, toasted'.
# Simplified food name for AllRecipes: 'butter stick' from 'Butter, stick'
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# No noun found in 'Butter, stick' using spaCy.
# Extracted main noun: 'From' from 'Butter, stick'
# Recipe URL 'https://www.allrecipes.com/recipe/10049/butter-tarts/' does not match the main noun 'From' from 'Butter, stick'.
# Simplified food name for AllRecipes: 'tea hot leaf' from 'Tea, hot, leaf, black'
# No recipe found for 'tea hot leaf' on AllRecipes.
# Simplified food name for AllRecipes: 'beef ground' from 'Beef, ground'
# spaCy extracted main noun: 'Beef' from 'Beef, ground'
# Found recipe for 'Beef, ground': https://www.allrecipes.com/recipe/158140/spaghetti-sauce-with-ground-beef/
# Simplified food name for AllRecipes: 'lettuce raw' from 'Lettuce, raw'
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# No noun found in 'Lettuce, raw' using spaCy.
# Extracted main noun: 'From' from 'Lettuce, raw'
# Recipe URL 'https://www.allrecipes.com/recipe/239788/chef-johns-chicken-lettuce-wraps/' does not match the main noun 'From' from 'Lettuce, raw'.
# Simplified food name for AllRecipes: 'cheese brie' from 'Cheese, Brie'
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# No noun found in 'Cheese, Brie' using spaCy.
# Extracted main noun: 'From' from 'Cheese, Brie'
# Recipe URL 'https://www.allrecipes.com/recipe/15015/brie-cheese-appetizer/' does not match the main noun 'From' from 'Cheese, Brie'.
# Simplified food name for AllRecipes: 'oatmeal beverage' from 'Oatmeal beverage with milk'
# spaCy extracted main noun: 'beverage' from 'Oatmeal beverage with milk'
# Recipe URL 'https://www.allrecipes.com/recipe/37934/oatmeal-cookie/' does not match the main noun 'beverage' from 'Oatmeal beverage with milk'.
# Simplified food name for AllRecipes: 'crackers matzo' from 'Crackers, matzo, reduced sodium'
# spaCy extracted main noun: 'Crackers' from 'Crackers, matzo, reduced sodium'
# Recipe URL 'https://www.allrecipes.com/recipe/17110/omas-fabulous-matzo-ball-soup/' does not match the main noun 'Crackers' from 'Crackers, matzo, reduced sodium'.
# Simplified food name for AllRecipes: 'potato boiled from' from 'Potato, boiled, from fresh, peel not eaten, no added fat'
# spaCy extracted main noun: 'peel' from 'Potato, boiled, from fresh, peel not eaten, no added fat'
# Recipe URL 'https://www.allrecipes.com/recipe/16729/old-fashioned-potato-salad/' does not match the main noun 'peel' from 'Potato, boiled, from fresh, peel not eaten, no added fat'.
# Simplified food name for AllRecipes: 'cauliflower fresh cooked' from 'Cauliflower, fresh, cooked, fat added, NS as to fat type'
# spaCy extracted main noun: 'type' from 'Cauliflower, fresh, cooked, fat added, NS as to fat type'
# Recipe URL 'https://www.allrecipes.com/recipe/229373/easy-cauliflower-soup-with-fresh-ginger/' does not match the main noun 'type' from 'Cauliflower, fresh, cooked, fat added, NS as to fat type'.
# Simplified food name for AllRecipes: 'hot thai sauce' from 'Hot Thai sauce'
# spaCy extracted main noun: 'sauce' from 'Hot Thai sauce'
# Found recipe for 'Hot Thai sauce': https://www.allrecipes.com/recipe/72487/the-best-thai-peanut-sauce/
# Simplified food name for AllRecipes: 'sugar substitute sucralose' from 'Sugar substitute, sucralose, powder'
# spaCy extracted main noun: 'Sugar' from 'Sugar substitute, sucralose, powder'
# Found recipe for 'Sugar substitute, sucralose, powder': https://www.allrecipes.com/recipe/74837/sugar-free-blueberry-coffee-cake/
# Simplified food name for AllRecipes: 'chocolate candy' from 'Chocolate candy'
# spaCy extracted main noun: 'Chocolate' from 'Chocolate candy'
# Found recipe for 'Chocolate candy': https://www.allrecipes.com/recipe/25590/chocolate-candy-bar-cake/
# Simplified food name for AllRecipes: 'milk chocolate candy' from 'Milk chocolate candy, with almonds'
# spaCy extracted main noun: 'Milk' from 'Milk chocolate candy, with almonds'
# Recipe URL 'https://www.allrecipes.com/recipe/229164/creamy-chocolate-mousse-pie/' does not match the main noun 'Milk' from 'Milk chocolate candy, with almonds'.
# Simplified food name for AllRecipes: 'coffee brewed decaffeinated' from 'Coffee, brewed, decaffeinated'
# No recipe found for 'coffee brewed decaffeinated' on AllRecipes.
# Simplified food name for AllRecipes: 'cookie chocolate chip' from 'Cookie, chocolate chip, sugar free'
# spaCy extracted main noun: 'chocolate' from 'Cookie, chocolate chip, sugar free'
# Found recipe for 'Cookie, chocolate chip, sugar free': https://www.allrecipes.com/recipe/10813/best-chocolate-chip-cookies/
# Simplified food name for AllRecipes: 'macaroni  noodles' from 'Macaroni or noodles with cheese'
# spaCy extracted main noun: 'noodles' from 'Macaroni or noodles with cheese'
# Recipe URL 'https://www.allrecipes.com/recipe/81108/classic-macaroni-salad/' does not match the main noun 'noodles' from 'Macaroni or noodles with cheese'.
# Simplified food name for AllRecipes: 'walnuts excluding honey' from 'Walnuts, excluding honey roasted'
# No recipe found for 'walnuts excluding honey' on AllRecipes.
# Simplified food name for AllRecipes: 'cereal o's plain' from 'Cereal, O's, plain'
# No recipe found for 'cereal o's plain' on AllRecipes.
# Simplified food name for AllRecipes: 'soft drink cola' from 'Soft drink, cola, decaffeinated'
# spaCy extracted main noun: 'drink' from 'Soft drink, cola, decaffeinated'
# Recipe URL 'https://www.allrecipes.com/recipe/7502/coco-cola-cake-ii/' does not match the main noun 'drink' from 'Soft drink, cola, decaffeinated'.
# Simplified food name for AllRecipes: 'egg salad made' from 'Egg Salad, made with any type of fat free dressing'
# spaCy extracted main noun: 'type' from 'Egg Salad, made with any type of fat free dressing'
# Recipe URL 'https://www.allrecipes.com/recipe/103767/jens-heavenly-egg-salad/' does not match the main noun 'type' from 'Egg Salad, made with any type of fat free dressing'.
# Simplified food name for AllRecipes: 'sopa seca de' from 'Sopa seca de arroz, home recipe, Mexican style'
# spaCy extracted main noun: 'Sopa' from 'Sopa seca de arroz, home recipe, Mexican style'
# Found recipe for 'Sopa seca de arroz, home recipe, Mexican style': https://www.allrecipes.com/recipe/262321/dry-mexican-noodle-soup-sopa-seca-de-fideos/
# Simplified food name for AllRecipes: 'cheese monterey' from 'Cheese, Monterey'
# spaCy extracted main noun: 'Cheese' from 'Cheese, Monterey'
# Found recipe for 'Cheese, Monterey': https://www.allrecipes.com/recipe/22612/jalapeno-cheese-puffs/
# Simplified food name for AllRecipes: 'plum raw' from 'Plum, raw'
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# No noun found in 'Plum, raw' using spaCy.
# Extracted main noun: 'From' from 'Plum, raw'
# Recipe URL 'https://www.allrecipes.com/recipe/96431/fresh-salsa/' does not match the main noun 'From' from 'Plum, raw'.
# Simplified food name for AllRecipes: 'fruit juice blend' from 'Fruit juice blend, 100% juice'
# spaCy extracted main noun: 'Fruit' from 'Fruit juice blend, 100% juice'
# Found recipe for 'Fruit juice blend, 100% juice': https://www.allrecipes.com/recipe/23553/basic-fruit-smoothie/
# Simplified food name for AllRecipes: 'egg cheese' from 'Egg, cheese, and sausage on biscuit'
# spaCy extracted main noun: 'cheese' from 'Egg, cheese, and sausage on biscuit'
# Found recipe for 'Egg, cheese, and sausage on biscuit': https://www.allrecipes.com/recipe/241166/fast-and-fabulous-egg-and-cottage-cheese-casserole/
# Simplified food name for AllRecipes: 'orange juice 100%' from 'Orange juice, 100%, NFS'
# spaCy extracted main noun: 'juice' from 'Orange juice, 100%, NFS'
# Recipe URL 'https://www.allrecipes.com/recipe/264721/orange-cream-pops/' does not match the main noun 'juice' from 'Orange juice, 100%, NFS'.
# Simplified food name for AllRecipes: 'bologna' from 'Bologna'
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# No noun found in 'Bologna' using spaCy.
# Extracted main noun: 'From' from 'Bologna'
# Recipe URL 'https://www.allrecipes.com/recipe/21062/bologna-salad-sandwich-spread-i/' does not match the main noun 'From' from 'Bologna'.
# Simplified food name for AllRecipes: 'bagel' from 'Bagel'
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# No noun found in 'Bagel' using spaCy.
# Extracted main noun: 'From' from 'Bagel'
# Recipe URL 'https://www.allrecipes.com/recipe/38553/bagel-and-cheese-bake/' does not match the main noun 'From' from 'Bagel'.
# Simplified food name for AllRecipes: 'mayonnaise regular' from 'Mayonnaise, regular'
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# No noun found in 'Mayonnaise, regular' using spaCy.
# Extracted main noun: 'From' from 'Mayonnaise, regular'
# Recipe URL 'https://www.allrecipes.com/recipe/91765/salmon-deviled-eggs-with-homemade-mayonnaise/' does not match the main noun 'From' from 'Mayonnaise, regular'.
# Simplified food name for AllRecipes: 'cheese nfs' from 'Cheese, NFS'
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# No noun found in 'Cheese, NFS' using spaCy.
# Extracted main noun: 'From' from 'Cheese, NFS'
# Recipe URL 'https://www.allrecipes.com/recipe/262631/citrus-ricotta-oats/' does not match the main noun 'From' from 'Cheese, NFS'.
# Simplified food name for AllRecipes: 'tea hot leaf' from 'Tea, hot, leaf, black'
# No recipe found for 'tea hot leaf' on AllRecipes.
# Simplified food name for AllRecipes: 'lamb  mutton' from 'Lamb or mutton curry'
# spaCy extracted main noun: 'mutton' from 'Lamb or mutton curry'
# Recipe URL 'https://www.allrecipes.com/recipe/70424/moroccan-tagine/' does not match the main noun 'mutton' from 'Lamb or mutton curry'.
# Simplified food name for AllRecipes: 'rice  beans' from 'Rice with beans'
# spaCy extracted main noun: 'Rice' from 'Rice with beans'
# Found recipe for 'Rice with beans': https://www.allrecipes.com/recipe/53063/rice-beans-haitian-style/
# Simplified food name for AllRecipes: 'egg salad made' from 'Egg Salad, made with any type of fat free dressing'
# spaCy extracted main noun: 'type' from 'Egg Salad, made with any type of fat free dressing'
# Recipe URL 'https://www.allrecipes.com/recipe/103767/jens-heavenly-egg-salad/' does not match the main noun 'type' from 'Egg Salad, made with any type of fat free dressing'.
# Simplified food name for AllRecipes: 'onions cooked ns' from 'Onions, cooked, NS as to form, NS as to fat added in cooking'
# No recipe found for 'onions cooked ns' on AllRecipes.
# Simplified food name for AllRecipes: 'plantain boiled ns' from 'Plantain, boiled, NS as to green or ripe'
# No recipe found for 'plantain boiled ns' on AllRecipes.
# Simplified food name for AllRecipes: 'cereal puffed rice' from 'Cereal, puffed rice'
# spaCy extracted main noun: 'rice' from 'Cereal, puffed rice'
# Recipe URL 'https://www.allrecipes.com/recipe/228334/puffed-millet-squares/' does not match the main noun 'rice' from 'Cereal, puffed rice'.
# Simplified food name for AllRecipes: 'ham' from 'Ham, prepackaged or deli, luncheon meat, reduced sodium'
# spaCy extracted main noun: 'Ham' from 'Ham, prepackaged or deli, luncheon meat, reduced sodium'
# Found recipe for 'Ham, prepackaged or deli, luncheon meat, reduced sodium': https://www.allrecipes.com/recipe/24501/tangy-honey-glazed-ham/
# Simplified food name for AllRecipes: 'roll white hoagie' from 'Roll, white, hoagie, submarine'
# spaCy extracted main noun: 'submarine' from 'Roll, white, hoagie, submarine'
# Recipe URL 'https://www.allrecipes.com/recipe/276001/air-fried-crispy-fish-po-boys-with-chipotle-slaw/' does not match the main noun 'submarine' from 'Roll, white, hoagie, submarine'.
# Simplified food name for AllRecipes: 'tomatoes raw' from 'Tomatoes, raw'
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# No noun found in 'Tomatoes, raw' using spaCy.
# Extracted main noun: 'From' from 'Tomatoes, raw'
# Recipe URL 'https://www.allrecipes.com/recipe/280771/raw-corn-salad/' does not match the main noun 'From' from 'Tomatoes, raw'.
# Simplified food name for AllRecipes: 'snack mix' from 'Snack mix'
# spaCy extracted main noun: 'Snack' from 'Snack mix'
# ...
# No noun found in 'Pasta, cooked' using spaCy.
# Extracted main noun: 'From' from 'Pasta, cooked'
# Recipe URL 'https://www.allrecipes.com/recipe/255823/pasta-fazool-pasta-e-fagioli/' does not match the main noun 'From' from 'Pasta, cooked'.
# Simplified food name for AllRecipes: 'infant formula similac' from 'Infant formula, Similac for Spit-Up, powder, made with water'
# No recipe found for 'infant formula similac' on AllRecipes.
# Simplified food name for AllRecipes: 'baby toddler cereal' from 'Baby Toddler cereal, rice, dry'
# No recipe found for 'baby toddler cereal' on AllRecipes.
# Simplified food name for AllRecipes: 'baby toddler bananas' from 'Baby Toddler bananas, Stage 1'
# spaCy extracted main noun: 'bananas' from 'Baby Toddler bananas, Stage 1'
# Recipe URL 'https://www.allrecipes.com/recipe/219330/toddler-muffins/' does not match the main noun 'bananas' from 'Baby Toddler bananas, Stage 1'.
# Simplified food name for AllRecipes: 'baby toddler sweet' from 'Baby Toddler sweet potatoes, Stage 1'
# spaCy extracted main noun: 'potatoes' from 'Baby Toddler sweet potatoes, Stage 1'
# Recipe URL 'https://www.allrecipes.com/recipe/219330/toddler-muffins/' does not match the main noun 'potatoes' from 'Baby Toddler sweet potatoes, Stage 1'.
# Simplified food name for AllRecipes: 'baby toddler apples' from 'Baby Toddler apples, Stage 1'
# No recipe found for 'baby toddler apples' on AllRecipes.
# Simplified food name for AllRecipes: 'lemon raw' from 'Lemon, raw'
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# No noun found in 'Lemon, raw' using spaCy.
# Extracted main noun: 'From' from 'Lemon, raw'
# Recipe URL 'https://www.allrecipes.com/recipe/166611/alexs-raw-chocolate-pudding/' does not match the main noun 'From' from 'Lemon, raw'.
# Simplified food name for AllRecipes: 'cereal (post raisin' from 'Cereal (Post Raisin Bran)'
# No recipe found for 'cereal (post raisin' on AllRecipes.
# Simplified food name for AllRecipes: 'margarine stick' from 'Margarine, stick'
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# No noun found in 'Margarine, stick' using spaCy.
# Extracted main noun: 'From' from 'Margarine, stick'
# Recipe URL 'https://www.allrecipes.com/recipe/284216/becel-oatmeal-chocolate-chip-cookies/' does not match the main noun 'From' from 'Margarine, stick'.
# Simplified food name for AllRecipes: 'chicken breast grilled' from 'Chicken breast, grilled with sauce, skin not eaten'
# spaCy extracted main noun: 'Chicken' from 'Chicken breast, grilled with sauce, skin not eaten'
# Found recipe for 'Chicken breast, grilled with sauce, skin not eaten': https://www.allrecipes.com/recipe/83793/best-chicken-marinade/
# Simplified food name for AllRecipes: 'cranberries cooked' from 'Cranberries, cooked or canned'
# spaCy extracted main noun: 'Cranberries' from 'Cranberries, cooked or canned'
# Recipe URL 'https://www.allrecipes.com/recipe/157872/winter-chicken-bake/' does not match the main noun 'Cranberries' from 'Cranberries, cooked or canned'.
# Simplified food name for AllRecipes: 'beans string cooked' from 'Beans, string, cooked, from frozen, NS as to color, fat added in cooking, NS as to type of fat'
# spaCy extracted main noun: 'Beans' from 'Beans, string, cooked, from frozen, NS as to color, fat added in cooking, NS as to type of fat'
# Recipe URL 'https://www.allrecipes.com/recipe/13178/creamy-string-bean-soup/' does not match the main noun 'Beans' from 'Beans, string, cooked, from frozen, NS as to color, fat added in cooking, NS as to type of fat'.
# Simplified food name for AllRecipes: 'cornmeal dressing' from 'Cornmeal dressing with chicken or turkey and vegetables'
# spaCy extracted main noun: 'Cornmeal' from 'Cornmeal dressing with chicken or turkey and vegetables'
# Recipe URL 'https://www.allrecipes.com/recipe/27220/cornbread-dressing-ii/' does not match the main noun 'Cornmeal' from 'Cornmeal dressing with chicken or turkey and vegetables'.
# Simplified food name for AllRecipes: 'snack cake white' from 'Snack cake, white'
# spaCy extracted main noun: 'Snack' from 'Snack cake, white'
# Recipe URL 'https://www.allrecipes.com/recipe/229630/polish-cream-cheese-coffee-cake/' does not match the main noun 'Snack' from 'Snack cake, white'.
# Simplified food name for AllRecipes: 'roll wheat' from 'Roll, wheat or cracked wheat'
# spaCy extracted main noun: 'Roll' from 'Roll, wheat or cracked wheat'
# Found recipe for 'Roll, wheat or cracked wheat': https://www.allrecipes.com/recipe/24929/light-wheat-rolls/
# Simplified food name for AllRecipes: 'oatmeal regular' from 'Oatmeal, regular or quick, made with milk, fat added'
# spaCy extracted main noun: 'milk' from 'Oatmeal, regular or quick, made with milk, fat added'
# Recipe URL 'https://www.allrecipes.com/recipe/277114/air-fryer-triple-chocolate-oatmeal-cookies/' does not match the main noun 'milk' from 'Oatmeal, regular or quick, made with milk, fat added'.
# Simplified food name for AllRecipes: 'pretzels soft gluten' from 'Pretzels, soft, gluten free, coated or flavored'
# No recipe found for 'pretzels soft gluten' on AllRecipes.
# Simplified food name for AllRecipes: 'fruit punch made' from 'Fruit punch, made with fruit juice and soda'
# spaCy extracted main noun: 'Fruit' from 'Fruit punch, made with fruit juice and soda'
# Recipe URL 'https://www.allrecipes.com/recipe/236879/jamaican-rum-punch/' does not match the main noun 'Fruit' from 'Fruit punch, made with fruit juice and soda'.
# Simplified food name for AllRecipes: 'roll sweet' from 'Roll, sweet, with fruit, frosted'
# spaCy extracted main noun: 'Roll' from 'Roll, sweet, with fruit, frosted'
# Found recipe for 'Roll, sweet, with fruit, frosted': https://www.allrecipes.com/recipe/216759/the-perfect-cinnamon-roll-icing/
# Simplified food name for AllRecipes: 'fruit punch made' from 'Fruit punch, made with soda, fruit juice, and sherbet or ice cream'
# spaCy extracted main noun: 'Fruit' from 'Fruit punch, made with soda, fruit juice, and sherbet or ice cream'
# Recipe URL 'https://www.allrecipes.com/recipe/236879/jamaican-rum-punch/' does not match the main noun 'Fruit' from 'Fruit punch, made with soda, fruit juice, and sherbet or ice cream'.
# Simplified food name for AllRecipes: 'popcorn popped in' from 'Popcorn, popped in oil, with added butter'
# spaCy extracted main noun: 'Popcorn' from 'Popcorn, popped in oil, with added butter'
# Found recipe for 'Popcorn, popped in oil, with added butter': https://www.allrecipes.com/recipe/87305/microwave-popcorn/
# Simplified food name for AllRecipes: 'blackeyed peas from' from 'Blackeyed peas, from dried'
# spaCy extracted main noun: 'peas' from 'Blackeyed peas, from dried'
# Found recipe for 'Blackeyed peas, from dried': https://www.allrecipes.com/recipe/213029/new-year-black-eyed-peas/
# Simplified food name for AllRecipes: 'okra frozen cooked' from 'Okra, frozen, cooked, no added fat'
# spaCy extracted main noun: 'fat' from 'Okra, frozen, cooked, no added fat'
# Recipe URL 'https://www.allrecipes.com/recipe/143249/okra-with-tomatoes/' does not match the main noun 'fat' from 'Okra, frozen, cooked, no added fat'.
# Simplified food name for AllRecipes: 'beef steak breaded' from 'Beef steak, breaded or floured, baked or fried, lean only eaten'
# spaCy extracted main noun: 'Beef' from 'Beef steak, breaded or floured, baked or fried, lean only eaten'
# Found recipe for 'Beef steak, breaded or floured, baked or fried, lean only eaten': https://www.allrecipes.com/recipe/215853/beef-parmesan-with-garlic-pasta/
# Simplified food name for AllRecipes: 'rice brown cooked' from 'Rice, brown, cooked, no added fat'
# spaCy extracted main noun: 'fat' from 'Rice, brown, cooked, no added fat'
# Recipe URL 'https://www.allrecipes.com/recipe/96787/brown-rice-breakfast-porridge/' does not match the main noun 'fat' from 'Rice, brown, cooked, no added fat'.
# Simplified food name for AllRecipes: 'ice cream bar' from 'Ice cream bar or stick, not chocolate covered or cake covered'
# spaCy extracted main noun: 'Ice' from 'Ice cream bar or stick, not chocolate covered or cake covered'
# Found recipe for 'Ice cream bar or stick, not chocolate covered or cake covered': https://www.allrecipes.com/recipe/22728/hot-fudge-ice-cream-bar-dessert/
# Simplified food name for AllRecipes: 'doughnut cake type' from 'Doughnut, cake type, chocolate covered'
# spaCy extracted main noun: 'cake' from 'Doughnut, cake type, chocolate covered'
# Found recipe for 'Doughnut, cake type, chocolate covered': https://www.allrecipes.com/recipe/33625/cake-doughnuts/
# Simplified food name for AllRecipes: 'funnel cake' from 'Funnel cake with sugar and fruit'
# spaCy extracted main noun: 'Funnel' from 'Funnel cake with sugar and fruit'
# Found recipe for 'Funnel cake with sugar and fruit': https://www.allrecipes.com/recipe/18505/funnel-cakes/
# Simplified food name for AllRecipes: 'whole wheat cereal' from 'Whole wheat cereal, cooked, fat added'
# spaCy extracted main noun: 'wheat' from 'Whole wheat cereal, cooked, fat added'
# Found recipe for 'Whole wheat cereal, cooked, fat added': https://www.allrecipes.com/recipe/202671/whole-wheat-cereal-bars/
# Simplified food name for AllRecipes: 'roast beef sandwich' from 'Roast beef sandwich on white'
# spaCy extracted main noun: 'Roast' from 'Roast beef sandwich on white'
# Found recipe for 'Roast beef sandwich on white': https://www.allrecipes.com/recipe/44764/open-faced-broiled-roast-beef-sandwich/
# Simplified food name for AllRecipes: 'beef roast' from 'Beef, roast'
# spaCy extracted main noun: 'Beef' from 'Beef, roast'
# Found recipe for 'Beef, roast': https://www.allrecipes.com/recipe/42176/all-american-roast-beef/
# Simplified food name for AllRecipes: 'orange canned nfs' from 'Orange, canned, NFS'
# No recipe found for 'orange canned nfs' on AllRecipes.
# Simplified food name for AllRecipes: 'infant formula powder' from 'Infant formula, powder, made with water, NFS (Similac Advance)'
# No recipe found for 'infant formula powder' on AllRecipes.
# Simplified food name for AllRecipes: 'breakfast tart lowfat' from 'Breakfast tart, lowfat'
# No recipe found for 'breakfast tart lowfat' on AllRecipes.
# Simplified food name for AllRecipes: 'tortilla whole wheat' from 'Tortilla, whole wheat'
# spaCy extracted main noun: 'wheat' from 'Tortilla, whole wheat'
# Found recipe for 'Tortilla, whole wheat': https://www.allrecipes.com/recipe/46790/mexican-whole-wheat-flour-tortillas/
# Simplified food name for AllRecipes: 'peppers hot cooked' from 'Peppers, hot, cooked, NS as to form, NS as to fat added in cooking'
# spaCy extracted main noun: 'Peppers' from 'Peppers, hot, cooked, NS as to form, NS as to fat added in cooking'
# Found recipe for 'Peppers, hot, cooked, NS as to form, NS as to fat added in cooking': https://www.allrecipes.com/recipe/21851/stuffed-hot-peppers/
# Simplified food name for AllRecipes: 'cheese american' from 'Cheese, American, reduced sodium'
# spaCy extracted main noun: 'Cheese' from 'Cheese, American, reduced sodium'
# Found recipe for 'Cheese, American, reduced sodium': https://www.allrecipes.com/recipe/223400/old-school-mac-n-cheese/
# Simplified food name for AllRecipes: 'crackers cheese reduced' from 'Crackers, cheese, reduced fat'
# spaCy extracted main noun: 'Crackers' from 'Crackers, cheese, reduced fat'
# Recipe URL 'https://www.allrecipes.com/recipe/255131/mac-n-cheese-bites/' does not match the main noun 'Crackers' from 'Crackers, cheese, reduced fat'.
# Simplified food name for AllRecipes: 'cereal bran flakes' from 'Cereal, bran flakes, flavored'
# spaCy extracted main noun: 'bran' from 'Cereal, bran flakes, flavored'
# Recipe URL 'https://www.allrecipes.com/recipe/236186/mormon-muffins/' does not match the main noun 'bran' from 'Cereal, bran flakes, flavored'.
# Simplified food name for AllRecipes: 'pepperpot soup' from 'Pepperpot soup'
# No recipe found for 'pepperpot soup' on AllRecipes.
# Simplified food name for AllRecipes: 'doughnut raised' from 'Doughnut, raised or yeast, chocolate covered'
# spaCy extracted main noun: 'yeast' from 'Doughnut, raised or yeast, chocolate covered'
# Recipe URL 'https://www.allrecipes.com/recipe/219912/my-moms-raised-doughnuts/' does not match the main noun 'yeast' from 'Doughnut, raised or yeast, chocolate covered'.
# Simplified food name for AllRecipes: 'bread french' from 'Bread, French or Vienna'
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# No noun found in 'Bread, French or Vienna' using spaCy.
# Extracted main noun: 'From' from 'Bread, French or Vienna'
# Recipe URL 'https://www.allrecipes.com/recipe/56689/banana-bread-french-toast/' does not match the main noun 'From' from 'Bread, French or Vienna'.
# Simplified food name for AllRecipes: 'milk evaporated reduced' from 'Milk, evaporated, reduced fat (2%)'
# spaCy extracted main noun: 'Milk' from 'Milk, evaporated, reduced fat (2%)'
# Recipe URL 'https://www.allrecipes.com/recipe/12206/pumpkin-pie-ii/' does not match the main noun 'Milk' from 'Milk, evaporated, reduced fat (2%)'.
# Simplified food name for AllRecipes: 'radish raw' from 'Radish, raw'
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# No noun found in 'Radish, raw' using spaCy.
# Extracted main noun: 'From' from 'Radish, raw'
# Recipe URL 'https://www.allrecipes.com/recipe/278848/roasted-carrots-and-radishes/' does not match the main noun 'From' from 'Radish, raw'.
# Simplified food name for AllRecipes: 'mayonnaise light' from 'Mayonnaise, light'
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# No noun found in 'Mayonnaise, light' using spaCy.
# Extracted main noun: 'From' from 'Mayonnaise, light'
# Recipe URL 'https://www.allrecipes.com/recipe/24023/mayonnaise-biscuits/' does not match the main noun 'From' from 'Mayonnaise, light'.
# Simplified food name for AllRecipes: 'queso asadero' from 'Queso Asadero'
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# No noun found in 'Queso Asadero' using spaCy.
# Extracted main noun: 'From' from 'Queso Asadero'
# Recipe URL 'https://www.allrecipes.com/recipe/237356/honey-lime-chicken-enchiladas/' does not match the main noun 'From' from 'Queso Asadero'.
# Simplified food name for AllRecipes: 'grapefruit raw' from 'Grapefruit, raw'
# No recipe found for 'grapefruit raw' on AllRecipes.
# Simplified food name for AllRecipes: 'enchilada just cheese' from 'Enchilada, just cheese, meatless, no beans, green-chile or enchilada sauce'
# spaCy extracted main noun: 'cheese' from 'Enchilada, just cheese, meatless, no beans, green-chile or enchilada sauce'
# Recipe URL 'https://www.allrecipes.com/recipe/74188/green-chicken-enchilada/' does not match the main noun 'cheese' from 'Enchilada, just cheese, meatless, no beans, green-chile or enchilada sauce'.
# Simplified food name for AllRecipes: 'enchilada sauce green' from 'Enchilada sauce, green'
# spaCy extracted main noun: 'sauce' from 'Enchilada sauce, green'
# Found recipe for 'Enchilada sauce, green': https://www.allrecipes.com/recipe/15500/green-sauce-enchiladas/
# Simplified food name for AllRecipes: 'bratwurst  cheese' from 'Bratwurst, with cheese'
# spaCy extracted main noun: 'cheese' from 'Bratwurst, with cheese'
# Recipe URL 'https://www.allrecipes.com/recipe/240981/easy-beer-bratwurst/' does not match the main noun 'cheese' from 'Bratwurst, with cheese'.
# Simplified food name for AllRecipes: 'mayonnaise-type salad dressing' from 'Mayonnaise-type salad dressing, light'
# spaCy extracted main noun: 'Mayonnaise' from 'Mayonnaise-type salad dressing, light'
# Recipe URL 'https://www.allrecipes.com/recipe/8499/basic-chicken-salad/' does not match the main noun 'Mayonnaise' from 'Mayonnaise-type salad dressing, light'.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[75], line 123
#     120         filtered_foods.append(row)
#     122     # Sleep to avoid overwhelming the server (politeness policy)
# --> 123     time.sleep(3)
#     125 # Create DataFrames from filtered and matched results
#     126 filtered_foods_df = pd.DataFrame(filtered_foods)
#
# KeyboardInterrupt:

# %% [markdown]
# ### **Approach 3: using Autogen to automate the process of judging whether a food is recommendable or not**
#
# Helped reduce from 9.6k foods down to 7.5k foods and can be reduced further with manual filters from human reviewers

# %%
import os
import pandas as pd
import time
from autogen import ConversableAgent
from dotenv import load_dotenv

load_dotenv()
api_key = os.getenv("OPENAI_API_KEY")

llm_config = {
    "model": "gpt-3.5-turbo",
    "api_key": api_key
}

# Define the food recommendation agent
agent = ConversableAgent(
    name="food_recommendation_agent",
    llm_config=llm_config,
    human_input_mode="NEVER",
)

# Define the criteria for what makes a food item recommendable
# We as the prompters can always add more criteria as needed
recommendable_criteria = """
The food description must represent a complete food item or dish that is suitable for recommendation to users. Avoid descriptions that are:
1. Too generic (e.g., "water", "chewing gum").
2. Single ingredients unless they have culinary value (e.g., "garlic").
3. Non-food items or items that do not constitute a recipe (e.g., "salt", "sugar").
4. Raw vegetables, raw fruits, raw meat
5. Condiments
6. Baby foods

Recommendable items are those that can be used as part of a recipe or a full dish.
"""

file_path = '../processed_data/foods_list.csv'
foods_df = pd.read_csv(file_path)

# use the agent to determine if a food item is recommendable with retry
def is_recommendable(food_desc, retries=3):
    prompt = f"""
    You are a food recommendation agent. Your task is to judge whether a food description should be recommended to users or not.
    Follow the criteria below:
    {recommendable_criteria}

    Food Description: "{food_desc}"
    Should this be recommended? Answer "Yes" or "No" with a brief explanation.
    """
    
    for attempt in range(retries):
        try:
            response = agent.generate_reply(
                messages=[{"content": prompt, "role": "user"}]
            )
            answer = response.lower().strip()
            
            if "yes" in answer:
                return True, answer
            elif "no" in answer:
                return False, answer
            else:
                return False, "Unclear response: " + answer

        except Exception as e:
            print(f"Attempt {attempt + 1} failed for '{food_desc}' with error: {e}")
            time.sleep(2 * (attempt + 1))  

    return False, "Error during evaluation after retries"

# Loop through each row in the dataset and use the agent to classify it
recommendable_foods = []
non_recommendable_foods = []

for _, row in foods_df.iterrows():
    food_desc = row['food_desc']
    
    # Determine if the food is recommendable
    is_recommendable_result, explanation = is_recommendable(food_desc)

    if is_recommendable_result:
        recommendable_foods.append({**row.to_dict(), "explanation": explanation})
        print(f"Recommendable: '{food_desc}' - Explanation: {explanation}")
    else:
        non_recommendable_foods.append({**row.to_dict(), "explanation": explanation})
        print(f"Not Recommendable: '{food_desc}' - Explanation: {explanation}")

    # sleep to avoid rate limiting
    time.sleep(2)

recommendable_foods_df = pd.DataFrame(recommendable_foods)
non_recommendable_foods_df = pd.DataFrame(non_recommendable_foods)

recommendable_foods_df.to_csv('../processed_data/recommendable_foods.csv', index=False)
non_recommendable_foods_df.to_csv('../processed_data/non_recommendable_foods.csv', index=False)
# Out:
# [autogen.oai.client: 09-29 00:57:06] {184} WARNING - The API key specified is not a valid OpenAI format; it won't work with the OpenAI-hosted model.
# Not Recommendable: 'Hard candy' - Explanation: no, "hard candy" should not be recommended. it falls under the category of generic items and does not represent a complete food item or dish suitable for recommendation to users.
# Not Recommendable: 'Soft drink, root beer' - Explanation: no. this food description should not be recommended because "soft drink, root beer" falls under the category of beverages rather than a complete food item or dish suitable for recommendation.
# Recommendable: 'Potato chips, baked, flavored' - Explanation: yes, this food description should be recommended. "potato chips, baked, flavored" represents a complete food item that can be enjoyed as a snack or part of a meal. the description includes preparation method (baked) and additional detail (flavored), making it suitable for recommendation to users looking for snack options.
# Recommendable: 'Ham, prepackaged or deli, luncheon meat, reduced sodium' - Explanation: yes, this food description should be recommended. it represents a specific food item (reduced sodium luncheon meat) that can be used in a variety of recipes or eaten on its own. so, it meets the criteria for recommendation as a complete food item suitable for users.
# Recommendable: 'Bread, wheat or cracked wheat' - Explanation: yes, this description "bread, wheat or cracked wheat" can be recommended as it represents a complete food item that can be used in various recipes and dishes. it is not too generic, it's not just a single ingredient, and it's not a raw food item. bread can be used as a main component in sandwiches, soups, salads, and various other dishes, making it suitable for recommendation to users.
# Recommendable: 'Mayonnaise-type salad dressing' - Explanation: yes, the food description "mayonnaise-type salad dressing" can be recommended as it represents a condiment that is commonly used in various recipes or dishes, such as salads, sandwiches, or as a dipping sauce. it adds flavor and creaminess to different dishes, making it suitable for user recommendation.
# Recommendable: 'Popcorn, air-popped, no butter added' - Explanation: yes, this food description should be recommended. popcorn, air-popped without butter added, represents a complete food item that can be consumed as a snack or part of a recipe. it meets the criteria for being a suitable recommendation to users.
# Not Recommendable: 'Fruit flavored drink, powdered, reconstituted' - Explanation: no.
# explanation: this description falls under the category of a generic drink that is not a complete food item or dish suitable for recommendation.
# Not Recommendable: 'Pretzels, NFS' - Explanation: no, this should not be recommended. the food description "pretzels, nfs" is too generic and lacks detail about how the pretzels are prepared or what dish they are a part of. it does not provide enough information to be considered a suitable food recommendation for users.
# Recommendable: 'Cookie, shortbread' - Explanation: yes, this food description "cookie, shortbread" can be recommended. shortbread cookies represent a complete food item that can be enjoyed as a treat or snack.
# Recommendable: 'Crackers, sandwich, peanut butter filled' - Explanation: yes, "crackers, sandwich, peanut butter filled" can be recommended. it represents a complete food item or dish that can be consumed as is, making it suitable for recommendation to users.
# Recommendable: 'Chicken thigh, sauteed, skin not eaten' - Explanation: yes, this food description should be recommended. it represents a complete food item (chicken thigh) that is suitable for recommendation to users as it can be part of a recipe or a full dish (sauteed chicken thigh).
# Recommendable: 'Chicken drumstick, sauteed, skin not eaten' - Explanation: yes, this food description can be recommended. it specifies a prepared food item (chicken drumstick) that has been sauteed. the additional detail about not eating the skin provides context for potential dietary preferences. overall, this description represents a complete dish suitable for recommendation to users.
# Recommendable: 'Potato salad with egg, made with mayonnaise' - Explanation: yes, this food description should be recommended. it represents a complete dish, "potato salad with egg, made with mayonnaise," which is a suitable food item for recommendation to users.
# Not Recommendable: 'Roll, white, soft' - Explanation: no. this food description is too generic and lacks specific details about the actual food item or dish. it does not provide enough information to determine if it is a recommendable food item.
# Recommendable: 'Fruit juice drink' - Explanation: yes. "fruit juice drink" is a recommendable food item as it represents a complete beverage that can be consumed and enjoyed by users. it is not too generic, and it is a full dish in itself suitable for recommendation.
# Recommendable: 'Egg Salad, made with any type of fat free dressing' - Explanation: yes, this food description should be recommended. "egg salad" is a complete dish that can be made with various types of fat-free dressings, making it suitable for users looking for a healthy and flavorful meal option.
# Recommendable: 'Grits, instant, made with water, no added fat' - Explanation: yes, this food description can be recommended. grits made with water can be a complete dish suitable for consumption, meeting the criteria of being a full food item that can be used in a recipe.
# Not Recommendable: 'Butter, tub' - Explanation: no, "butter, tub" should not be recommended as it is a single ingredient and does not constitute a complete food item or dish.
# Recommendable: 'Potato, french fries, fast food' - Explanation: yes, this food description can be recommended. it includes a specific food item (potato) and a dish made from it (french fries). french fries are a popular and complete food item, making it suitable for recommendation to users.
# Recommendable: 'Chili con carne, NS as to beans' - Explanation: yes, this food description can be recommended. "chili con carne" is a complete dish featuring a flavorful meat stew typically containing beans, tomatoes, and spices. it's a well-known and popular dish that can be enjoyed as a full meal.
# Recommendable: 'Soft drink, fruit flavored, caffeine free' - Explanation: yes, this food description can be recommended. it represents a complete food item that is suitable for consumption and can be enjoyed as a beverage.
# Not Recommendable: 'Candy, taffy' - Explanation: no, this should not be recommended. the description of "candy, taffy" is too generic and doesn't represent a specific dish or recipe.
# Recommendable: 'Tortilla chips, plain' - Explanation: yes, "tortilla chips, plain" can be recommended as they are a complete food item that can be consumed as a snack or used in various recipes, such as nachos or with salsa.
# Not Recommendable: 'Salsa, red' - Explanation: no. raw salsa, red is not recommended as per the criteria since it's a condiment, and it doesn't represent a complete food item or dish.
# Recommendable: 'Breakfast tart' - Explanation: yes, "breakfast tart" can be recommended. it represents a complete food item suitable for users as it is a dish that can be consumed as part of a meal.
# Recommendable: 'Orange juice, 100%, canned, bottled or in a carton' - Explanation: yes.
#
# explanation: the description "orange juice, 100%, canned, bottled or in a carton" represents a complete food item that can be readily consumed. it can be recommended as it is a suitable beverage option for users.
# Recommendable: 'Chicken fillet, grilled' - Explanation: yes, this food description should be recommended. it represents a complete food item suitable for consumption and can be used as an ingredient in various dishes or recipes (e.g., salads, sandwiches, etc.).
# Not Recommendable: 'Ketchup' - Explanation: no, "ketchup" should not be recommended. ketchup is a condiment and not a complete food item or dish that can be used as part of a recipe on its own.
# Not Recommendable: 'Soft drink, cola' - Explanation: no. this food description should not be recommended as it falls under the category of non-food items (soft drink) and is too generic (cola). it does not represent a complete food item or dish suitable for recommendation to users.
# Recommendable: 'Cookie, chocolate chip' - Explanation: yes, this food description should be recommended. it represents a complete food item (cookie) with a specific flavor (chocolate chip) that is suitable for recommendation to users. it can be enjoyed on its own or used in various recipes and dishes.
# Recommendable: 'Pizza with pepperoni, from frozen, thick crust' - Explanation: yes, this food description should be recommended. it represents a complete food item - "pizza with pepperoni, from frozen, thick crust" - that can be a delicious and satisfying meal for users.
# Recommendable: 'Lemonade, frozen concentrate, not reconstituted' - Explanation: yes, this food description can be recommended. lemonade, frozen concentrate, not reconstituted is a specific food item that can be used to prepare a refreshing beverage by adding water according to instructions. it is suitable for recommendation as it represents a complete food item with culinary value.
# Recommendable: 'Egg, cheese, and sausage griddle cake sandwich' - Explanation: yes, this food description should be recommended. it represents a complete dish - an egg, cheese, and sausage griddle cake sandwich - suitable for recommendation to users as it combines different ingredients to create a full and satisfying meal.
# Recommendable: 'Ravioli, cheese and spinach filled, with tomato sauce' - Explanation: yes, this food description should be recommended. it represents a complete dish - ravioli filled with cheese and spinach served with tomato sauce. it is suitable for recommendation to users as it is a ready-to-eat dish that can be enjoyed as a meal.
# Recommendable: 'Garlic bread, from frozen' - Explanation: yes, this food description should be recommended. "garlic bread, from frozen" represents a specific food item that can be consumed as is or incorporated into a meal. it is a complete and ready-to-eat dish rather than just a single ingredient, making it suitable for user recommendation.
# Recommendable: 'Egg, cheese, and bacon on biscuit' - Explanation: yes. the food description "egg, cheese, and bacon on biscuit" should be recommended. it represents a complete food item that can be used in a recipe or consumed as a full dish, meeting the criteria for recommendation.
# Recommendable: 'Chocolate milk, ready to drink, whole' - Explanation: yes, this food description can be recommended. chocolate milk, ready to drink, whole, is a complete and consumable food item suitable for recommendation to users. it can be enjoyed as a beverage on its own or used in various recipes and dishes.
# Not Recommendable: 'Soft drink, cola, fruit or vanilla flavored' - Explanation: no.
#
# explanation: soft drinks are generally considered beverages and do not qualify as a full dish or recipe component.
# Recommendable: 'Roll, sweet, cinnamon bun, frosted' - Explanation: yes, this food description should be recommended. it represents a complete food item - a sweet cinnamon bun that is frosted. it is suitable for recommendation as it is a recognizable and complete dish that can be enjoyed by users.
# Recommendable: 'Catfish, coated, fried, made with cooking spray' - Explanation: yes, this food description should be recommended. it represents a complete dish - fried catfish made with cooking spray, which is suitable for recommendation to users as it can be part of a meal or recipe.
# Recommendable: 'Cornbread, prepared from mix' - Explanation: yes, "cornbread, prepared from mix" should be recommended. it represents a complete food item that is suitable for recommendation to users as it is a specific dish that can be enjoyed on its own or as part of a meal.
# Recommendable: 'Okra, batter-dipped, fried' - Explanation: yes, this food description should be recommended. it represents a complete dish - "okra, batter-dipped, fried" which is a common and popular dish in many cuisines. it is suitable for recommendation to users as it is a prepared food item and not just a single ingredient or condiment.
# Not Recommendable: 'Coffee substitute, dry powder' - Explanation: no. this food description should not be recommended. "coffee substitute, dry powder" falls under the category of a beverage or beverage alternative, which is not a complete food item or dish suitable for recommendation.
# Not Recommendable: 'Lemon juice, 100%, freshly squeezed' - Explanation: no.
#
# explanation: lemon juice, even though it is a common ingredient used in recipes, this description specifically mentions it as 100% freshly squeezed. this detail makes it more of a single ingredient rather than a complete dish or recipe.
# Not Recommendable: 'Sugar substitute, saccharin, powder' - Explanation: no. this food description should not be recommended. it falls under the category of condiments which are not suitable for recommendation based on the provided criteria.
# Recommendable: 'Chocolate candy, candy shell' - Explanation: yes. this food description, "chocolate candy, candy shell," can be recommended as it represents a complete food item that can be enjoyed as a treat or snack. it is a specific item with culinary value and can be part of a recipe or enjoyed on its own.
# Recommendable: 'Ice cream, vanilla' - Explanation: yes, "ice cream, vanilla" can be recommended as it represents a complete food item that is suitable for recommendation to users. it is a well-known dessert dish that can be enjoyed on its own or used as an ingredient in various recipes.
# Not Recommendable: 'Topping, chocolate' - Explanation: no. this food description should not be recommended as it falls under the category of condiments, which are generally not standalone food items suitable for recommendation.
# Recommendable: 'Strawberries, cooked or canned, in syrup' - Explanation: yes. this food description of "strawberries, cooked or canned, in syrup" is recommendable as it represents a complete food item that can be used in various recipes or enjoyed as a standalone dish. it is not a raw fruit but rather a processed form suitable for consumption.
# Not Recommendable: 'Milk, whole' - Explanation: no.
#
# explanation: "milk, whole" is a generic single ingredient item and does not constitute a complete food item or dish. this description does not meet the criteria for recommendation as it is not a recipe or full dish.
# Not Recommendable: 'Coffee, brewed' - Explanation: no. "coffee, brewed" is too generic and does not represent a complete food item or dish suitable for recommendation to users according to the given criteria.
# Not Recommendable: 'Sugar, white, granulated or lump' - Explanation: no.
# this food description falls under the category of condiments and is not a complete food item or dish suitable for recommendation.
# Not Recommendable: 'Coffee creamer, powder' - Explanation: no. "coffee creamer, powder" is a condiment typically used to add flavor and creaminess to coffee rather than being a standalone food item or dish. since it falls under the category of condiments, it does not meet the criteria for a recommendable food description.
# Recommendable: 'Vegetable chips' - Explanation: yes, "vegetable chips" can be recommended as they represent a complete food item that is suitable for users. vegetable chips are a popular snack option that can be enjoyed on their own or used in recipes as a healthy alternative to traditional potato chips.
# Recommendable: 'Turkey or chicken, pork, and beef sausage, reduced sodium' - Explanation: yes, this food description can be recommended. it includes a combination of meats in sausage form with reduced sodium, which can be used in recipes or as part of a meal.
# Not Recommendable: 'Soft drink, ginger ale' - Explanation: no. this food description should not be recommended. while ginger ale is a beverage, it is not a food item or dish that represents a complete meal or recipe.
# Not Recommendable: 'Chewing gum, NFS' - Explanation: no. this food description should not be recommended. it violates the criteria because "chewing gum" is too generic and does not constitute a complete food item or dish suitable for recommendation to users.
# Not Recommendable: 'Beer, light' - Explanation: no.
#
# explanation: "beer, light" is considered too generic and lacks specific details about a dish or recipe. it does not represent a complete food item suitable for recommendation to users.
# Recommendable: 'Macaroni or noodles with cheese, canned' - Explanation: yes. this food description, "macaroni or noodles with cheese, canned," can be recommended as it represents a complete dish suitable for users.
# Recommendable: 'Chicken breast, sauteed, skin not eaten' - Explanation: yes.
# this food description can be recommended as it represents a complete food item that is suitable for consumption and can be used as part of a recipe or dish.
# Recommendable: 'Milk, reduced fat (2%)' - Explanation: yes. this can be recommended as it is a complete food item that can be consumed on its own or used in various recipes and dishes.
# Recommendable: 'Pie, apple' - Explanation: yes, this food description "pie, apple" should be recommended. it represents a complete food item (apple pie) that is suitable for recommendation to users. it is a dish with culinary value and can be enjoyed as part of a dessert or snack.
# Not Recommendable: 'Chocolate syrup' - Explanation: no. this should not be recommended as it falls under the category of condiments, which are generally not standalone food items or dishes suitable for recommendation.
# Not Recommendable: 'Baby Toddler juice, apple' - Explanation: no. this food description should not be recommended because it is too generic and lacks specific details about the preparation or combination of ingredients to constitute a full dish or recipe.
# Not Recommendable: 'Tequila' - Explanation: no. tequila is a beverage and not a food item or dish. therefore, it does not fit the criteria for a recommended food description.
# Recommendable: 'Tea, hot, herbal' - Explanation: yes, this food description can be recommended. "tea, hot, herbal" represents a complete food item that can be enjoyed as a beverage. it is suitable for recommendation to users as it is a commonly consumed and versatile option.
# Not Recommendable: 'Banana, raw' - Explanation: no.
#
# explanation: "banana, raw" falls under the category of raw fruits which are not recommended as per the guidelines provided.
# Recommendable: 'Infant formula, powder, made with water, NFS (Similac Go and Grow)' - Explanation: yes. this food description can be recommended as it represents a complete food item suitable for consumption. infant formula is a complete nutritional product that is commonly used as a substitute or supplement for breast milk in infants.
# Not Recommendable: 'Honey' - Explanation: no. honey is considered as a condiment and does not constitute a stand-alone food item or dish that can be recommended.
# Not Recommendable: 'Fruit juice drink (Capri Sun)' - Explanation: no. this food description should not be recommended because it falls under the category of pre-packaged beverages and not a complete dish or food item suitable for recommendation.
# Recommendable: 'Pork sausage, reduced sodium' - Explanation: yes. this food description, "pork sausage, reduced sodium," can be recommended as it represents a complete food item that is suitable for use in various recipes or as part of a dish.
# Recommendable: 'Egg, whole, boiled or poached ' - Explanation: yes, this food description should be recommended. it represents a complete food item that can be enjoyed on its own or used in various recipes and dishes such as salads, sandwiches, or as a topping for toast.
# Recommendable: 'Rice, white, cooked with fat, Puerto Rican style' - Explanation: yes. this food description, "rice, white, cooked with fat, puerto rican style," can be recommended as it represents a complete food item suitable to be used in a recipe or consumed as a dish. it provides specific details about the way the rice is prepared and the style it is cooked in, making it suitable for recommendation to users.
# Recommendable: 'Bread, wheat or cracked wheat, toasted' - Explanation: yes. this food description can be recommended as it represents a complete food item - toasted bread made from wheat or cracked wheat. it is suitable for consumption as part of a meal or snack.
# Not Recommendable: 'Pork, chop, coated, lean and fat eaten' - Explanation: no. this food description should not be recommended. the description provided is too generic and lacks specific details about the preparation or cooking method to make it suitable for recommendation.
# Recommendable: 'Bread, whole wheat' - Explanation: yes, this should be recommended. "bread, whole wheat" represents a complete food item that can be used as part of various recipes or dishes. it is a staple food item with culinary value and can be enjoyed in different ways.
# Not Recommendable: 'Whiskey' - Explanation: no. whiskey is not a food item or dish suitable for recommendation as it is an alcoholic beverage and does not constitute a complete recipe or dish.
# Not Recommendable: 'Potato chips, fat free' - Explanation: no. potato chips, even if they are described as fat-free, are not typically considered a complete or healthy food item. they fall more into the category of snack foods rather than a balanced meal or recipe component.
# Recommendable: 'Pork sausage, reduced sodium' - Explanation: yes. this food description, "pork sausage, reduced sodium," can be recommended as it represents a complete food item that is suitable for use in various recipes or as part of a dish.
# Recommendable: 'Biscuit, from fast food / restaurant' - Explanation: yes. the food description "biscuit, from fast food / restaurant" can be recommended as it represents a complete food item that can be served as part of a meal.
# Not Recommendable: 'Jelly' - Explanation: no. "jelly" is too generic and lacks specific details about the type of jelly or how it can be used as part of a recipe or dish. it does not meet the criteria for a recommendable food description.
# Recommendable: 'Potato, hash brown, from fresh, with cheese' - Explanation: yes, this food description should be recommended. it represents a complete food item or dish - "potato hash brown with cheese" - that can be served as a dish by itself or as part of a meal. it meets the criteria for recommendation as it is a prepared food item with culinary value.
# Not Recommendable: 'Coffee substitute, dry powder' - Explanation: no. this food description should not be recommended. "coffee substitute, dry powder" falls under the category of a beverage or beverage alternative, which is not a complete food item or dish suitable for recommendation.
# Not Recommendable: 'Double hamburger, 2 medium patties, with condiments, on bun, from fast food / restaurant (Wendy's 1/2 lb Double)' - Explanation: no, this food description should not be recommended. the presence of "condiments" in the description falls under the category of items to avoid recommending as they are not considered complete food items or dishes suitable for user recommendation.
# Recommendable: 'Cereal (General Mills Cocoa Puffs)' - Explanation: yes. this food description "cereal (general mills cocoa puffs)" can be recommended as it represents a complete food item that can be consumed as a standalone dish or as part of a meal.
# Not Recommendable: 'Grape juice, 100%' - Explanation: no. this should not be recommended as grape juice is a standalone beverage and does not represent a complete food item or dish.
# Recommendable: 'Pork and beans' - Explanation: yes, "pork and beans" can be recommended as it represents a complete dish that is often served together. it is not a single ingredient, and it can be part of a recipe or a meal. therefore, it meets the criteria for a recommendable food description.
# Not Recommendable: 'Orange, raw' - Explanation: no. raw fruits like "orange, raw" are not recommended as they do not constitute a complete food item or dish.
# Not Recommendable: 'Bread, white' - Explanation: no, the food description "bread, white" should not be recommended based on the given criteria. it is a bit too generic and does not provide enough details to represent a complete food item or dish suitable for recommendation to users.
# Not Recommendable: 'Peanut butter' - Explanation: no.
#
# explanation: "peanut butter" is a single ingredient and falls under the category of condiments, which does not constitute a complete dish or recipe. therefore, it does not meet the criteria for recommendation as it is not a full food item or dish suitable for users.
# Not Recommendable: 'Fish, NS as to type, from fast food' - Explanation: no.
#
# explanation: the food description provided is too generic and does not specify the type of fish or any specific dish. it lacks details needed for a complete food item suitable for recommendation.
# Recommendable: 'Green beans, fresh, cooked, fat added, NS as to fat type' - Explanation: yes, this food description can be recommended. it specifies a complete food item (cooked green beans with added fat) suitable for consumption as part of a dish or recipe.
# Recommendable: 'Coffee, instant, reconstituted' - Explanation: yes. coffee, instant, reconstituted can be recommended as it represents a complete food item that is suitable for consumption and can be used to make various recipes or drinks.
# Not Recommendable: 'Soy milk' - Explanation: no. "soy milk" is a standalone beverage rather than a complete food item or dish suitable for recommendation.
# Recommendable: 'Oatmeal, NS as to regular, quick, or instant, no added fat' - Explanation: yes. "oatmeal, ns as to regular, quick, or instant, no added fat" can be recommended as a complete food item suitable for users. oatmeal can be cooked and served as a dish on its own, making it a suitable recommendation.
# Recommendable: 'Potato, mashed, NFS' - Explanation: yes, this food description can be recommended. mashed potatoes are a popular and complete food item that can be served as a side dish or used in various recipes.
# Recommendable: 'Gravy, beef or meat, fat free' - Explanation: yes, this food description should be recommended. "gravy, beef or meat, fat free" represents a food item that can be used as a component in cooking or as a topping for dishes, making it suitable for recommendation to users.
# Recommendable: 'Corn, canned, reduced sodium, cooked, no added fat' - Explanation: yes, this food description should be recommended. the description provides details about a specific food item suitable for consumption and can be used as an ingredient in various recipes or dishes.
# Not Recommendable: 'Margarine-oil blend, tub, light' - Explanation: no.
#
# explanation: margarine-oil blend, tub, light is a condiment and does not constitute a complete food item or dish. it falls under the category of condiments, which are not recommended according to the criteria provided.
# Attempt 1 failed for 'Slush frozen drink, no sugar added' with error: 'NoneType' object has no attribute 'lower'
# Recommendable: 'Slush frozen drink, no sugar added' - Explanation: yes, this food description can be recommended as it represents a complete food item - a slush frozen drink with the added detail of "no sugar added." it can be considered a ready-to-consume item that users might enjoy, making it suitable for recommendation.
# Recommendable: 'Pudding, chocolate, NS as to from dry mix or ready-to-eat' - Explanation: yes, this food description should be recommended. pudding chocolate is a complete food item that can be part of a dessert recipe or enjoyed as a standalone dish. it provides enough information for users to understand the food item.
# Not Recommendable: 'Apple, raw' - Explanation: no. this food description should not be recommended. raw fruits fall under the category of raw fruits which should be avoided as per the criteria mentioned.
# Recommendable: 'Cereal (Kellogg's Frosted Flakes)' - Explanation: yes. this food description should be recommended. "cereal (kellogg's frosted flakes)" represents a complete food item that is suitable for recommendation to users as it is a ready-to-eat breakfast option that can be enjoyed on its own or paired with milk or other ingredients.
# Not Recommendable: 'Apple juice, 100%' - Explanation: no.
#
# explanation: "apple juice, 100%" is a beverage and does not represent a complete food item or dish. it falls under the category of raw fruits and is not a recipe or a full dish suitable for recommendation to users.
# Recommendable: 'Shrimp, fried' - Explanation: yes, this food description "shrimp, fried" can be recommended as it represents a complete dish suitable for users. it involves a cooking method (fried) applied to a specific ingredient (shrimp), making it a dish rather than just a single ingredient.
# Recommendable: 'Pizza with pepperoni, from frozen, thick crust' - Explanation: yes, this food description should be recommended. it represents a complete food item - "pizza with pepperoni, from frozen, thick crust" - that can be a delicious and satisfying meal for users.
# Not Recommendable: 'Soft drink, cola, diet' - Explanation: no. the food description "soft drink, cola, diet" should not be recommended. it falls under the category of a non-generic beverage, which does not represent a complete food item or dish suitable for recommendation.
# Recommendable: 'Gelatin dessert, dietetic, with fruit, sweetened with low calorie sweetener' - Explanation: yes.
# this food description of "gelatin dessert, dietetic, with fruit, sweetened with low-calorie sweetener" is suitable for recommendation as it represents a complete food item that can be included in a recipe or be served as a standalone dish.
# Not Recommendable: 'Coffee, instant, decaffeinated, reconstituted' - Explanation: no. this food description should not be recommended. while coffee is a commonly consumed food item, instant decaffeinated coffee, when simply reconstituted, is not a complete dish or recipe that aligns with the recommendation criteria.
# Recommendable: 'Pan Dulce, with sugar topping' - Explanation: yes.
#
# explanation: "pan dulce with sugar topping" represents a complete food item, suitable for recommendation to users as it is a sweet bread often enjoyed as a snack or dessert.
# Recommendable: 'Spanish rice, fat added' - Explanation: yes, this food description can be recommended. "spanish rice, fat added" represents a complete dish that is suitable for recommendation to users. it is a specific food item with culinary value and is commonly used as part of a recipe.
# Recommendable: 'Pinto beans, from dried, fat added' - Explanation: yes, this food description can be recommended. pinto beans are a complete food item that can be used in various recipes when cooked from dried with added fat.
# Recommendable: 'Beef steak, fried, lean and fat eaten' - Explanation: yes, this food description should be recommended. it represents a complete dish - beef steak, fried, with a combination of lean and fat portions. it can be served as a standalone meal or incorporated into various recipes.
# Not Recommendable: 'Tortilla, corn' - Explanation: no. "tortilla, corn" should not be recommended as it is too generic and lacks specific details or incorporation into a recipe or dish.
# Recommendable: 'Cookie, sandwich-type, not chocolate or vanilla' - Explanation: yes, this food description can be recommended. it specifies a complete food item - a cookie of a sandwich-type that is not chocolate or vanilla. it is a suitable food item for recommendation to users as it represents a recognizable and complete dish variation.
# Recommendable: 'Pork stew, no potatoes, tomato-based sauce, Mexican style' - Explanation: yes. this food description, "pork stew, no potatoes, tomato-based sauce, mexican style," can be recommended as it represents a complete dish with specific ingredients and preparation style, suitable for users looking for a savory and hearty meal option.
# Not Recommendable: 'Cabbage, green, raw' - Explanation: no. this food description should not be recommended as it is a raw vegetable which falls under the category of raw vegetables that are not recommended in the given criteria.
# Recommendable: 'Bread, white, toasted' - Explanation: yes, this food description can be recommended. "bread, white, toasted" represents a complete food item that can be consumed as a stand-alone dish or used as an ingredient in recipes. it meets the criteria for recommendable food items.
# Not Recommendable: 'Butter, stick' - Explanation: no, the food description "butter, stick" should not be recommended. it falls under the category of a single ingredient that lacks culinary value on its own. it is not a complete food item or dish suitable for recommendation to users.
# Not Recommendable: 'Tea, hot, leaf, black' - Explanation: no. this food description should not be recommended because it is too generic and lacks specific details about a complete food item or dish. it does not provide enough information to be considered recommendable.
# Not Recommendable: 'Beef, ground' - Explanation: no. the food description "beef, ground" should not be recommended because it is a single ingredient that is too generic without specifying its culinary use or accompanying recipe.
# Not Recommendable: 'Lettuce, raw' - Explanation: no. "lettuce, raw" should not be recommended as it falls under the category of raw vegetables, which is not suitable for recommendation according to the criteria provided.
# Recommendable: 'Cheese, Brie' - Explanation: yes, this food description "cheese, brie" should be recommended. brie cheese is a complete food item that is commonly used in various dishes and recipes, making it suitable for recommendation to users.
# Recommendable: 'Oatmeal beverage with milk' - Explanation: yes. "oatmeal beverage with milk" can be recommended as it represents a complete food item that can be consumed as a drink or part of a breakfast routine. it provides sustenance and can be appealing to users looking for a comforting and nutritious beverage option.
# Recommendable: 'Crackers, matzo, reduced sodium' - Explanation: yes. this food description "crackers, matzo, reduced sodium" can be recommended as it represents a specific food item that can be used as a snack on its own or as part of a recipe. it is not too generic, and it is suitable for consumption.
# Recommendable: 'Potato, boiled, from fresh, peel not eaten, no added fat' - Explanation: yes, this food description can be recommended. it provides specific details about the food item (potato), how it has been prepared (boiled), and the absence of certain ingredients (no added fat). this information makes it suitable for recommendation as it represents a complete food item that can be used in various recipes or enjoyed on its own.
# Recommendable: 'Cauliflower, fresh, cooked, fat added, NS as to fat type' - Explanation: yes, this food description can be recommended. it represents a complete food item - cooked cauliflower with added fat, which is suitable as part of a recipe or a full dish.
# Not Recommendable: 'Hot Thai sauce' - Explanation: no. the description "hot thai sauce" falls under the category of condiments, which is not a complete food item or dish. so, it should not be recommended based on the criteria provided.
# Not Recommendable: 'Sugar substitute, sucralose, powder' - Explanation: no.
#
# explanation: the food description, "sugar substitute, sucralose, powder," is a condiment or additive rather than a complete food item or dish. it does not constitute a recipe on its own and falls under the category of non-recommendable items based on the criteria provided.
# Recommendable: 'Chocolate candy' - Explanation: yes, "chocolate candy" can be recommended because it represents a complete food item that is suitable for consumption as a snack or dessert. it is not a single ingredient and is a common treat enjoyed by many people.
# Recommendable: 'Milk chocolate candy, with almonds' - Explanation: yes. "milk chocolate candy with almonds" is a complete and enticing food item suitable for recommendation to users. it is a unique combination of milk chocolate and almonds, making it a delicious treat that can be enjoyed on its own or used in various desserts or recipes.
# Recommendable: 'Coffee, brewed, decaffeinated' - Explanation: yes. this food description, "coffee, brewed, decaffeinated," can be recommended as it represents a complete food item that is commonly consumed and prepared for consumption. it is a suitable item for users interested in decaffeinated beverages.
# Recommendable: 'Cookie, chocolate chip, sugar free' - Explanation: yes. this food description "cookie, chocolate chip, sugar free" can be recommended as it represents a complete food item suitable for users. it's a specific dish with ingredients that can be used in a recipe for sugar-free chocolate chip cookies.
# Recommendable: 'Macaroni or noodles with cheese' - Explanation: yes, this food description should be recommended. it represents a complete dish - macaroni or noodles with cheese - which is suitable for recommendation to users. it can be used as part of a recipe or enjoyed as a full dish.
# Not Recommendable: 'Walnuts, excluding honey roasted' - Explanation: no, this food description should not be recommended. walnuts, excluding honey roasted, fall under the category of raw nuts which are not typically recommended as a standalone dish for users.
# Not Recommendable: 'Cereal, O's, plain' - Explanation: no. this food description should not be recommended as it is too generic and lacks culinary detailing to make it suitable for a recipe or full dish recommendation.
# Not Recommendable: 'Soft drink, cola, decaffeinated' - Explanation: no, this should not be recommended. the description "soft drink, cola, decaffeinated" falls under the category of a beverage and not a complete food item or dish. it does not adhere to the criteria for recommendable food descriptions as it is a single beverage item and not part of a recipe or full dish.
# Recommendable: 'Egg Salad, made with any type of fat free dressing' - Explanation: yes, this food description should be recommended. "egg salad" is a complete dish that can be made with various types of fat-free dressings, making it suitable for users looking for a healthy and flavorful meal option.
# Recommendable: 'Sopa seca de arroz, home recipe, Mexican style' - Explanation: yes, this food description can be recommended. it represents a complete dish, "sopa seca de arroz," which is a mexican style home recipe. it meets the criteria of being a full dish suitable for recommendation to users.
# Recommendable: 'Cheese, Monterey' - Explanation: yes, this food description can be recommended. "cheese, monterey" is a specific type of cheese that can be used in various recipes or enjoyed on its own. it qualifies as a complete food item suitable for recommendation to users.
# Not Recommendable: 'Plum, raw' - Explanation: no. this description should not be recommended as it falls under the category of raw fruits which are not suitable for recommendation based on the criteria provided.
# Not Recommendable: 'Fruit juice blend, 100% juice' - Explanation: no. "fruit juice blend, 100% juice" should not be recommended as it is a generic description of a beverage without specific details on the exact fruits used or any culinary context to suggest a complete dish or recipe.
# Recommendable: 'Egg, cheese, and sausage on biscuit' - Explanation: yes, this should be recommended. the food description "egg, cheese, and sausage on biscuit" represents a complete dish that can be enjoyed by users, making it suitable for recommendation.
# Not Recommendable: 'Orange juice, 100%, NFS' - Explanation: no, this should not be recommended. orange juice, especially when specified as "100% nfs" (not-from-concentrate), is a beverage typically consumed on its own and does not represent a complete food item or dish suitable for recommendation.
# Recommendable: 'Bologna' - Explanation: yes, "bologna" can be recommended as it represents a complete food item that can be used in various dishes or recipes such as sandwiches, salads, and pasta dishes. it is a processed meat product suitable for consumption.
# Recommendable: 'Bagel' - Explanation: yes. "bagel" can be recommended as it represents a complete food item that can be consumed on its own or used as part of various recipes or dishes like sandwiches, bagel pizzas, etc. it is not too generic and fits the criteria for a recommendable food item.
# Not Recommendable: 'Mayonnaise, regular' - Explanation: no. mayonnaise, regular is considered a condiment and does not represent a complete food item or dish. it is commonly used as an ingredient in recipes rather than as a standalone dish. therefore, it does not meet the criteria for a recommended food description.
# Not Recommendable: 'Cheese, NFS' - Explanation: no. this food description should not be recommended as it is too generic and lacks specific details about the type of cheese or how it is utilized in a recipe.
# Not Recommendable: 'Tea, hot, leaf, black' - Explanation: no. this food description should not be recommended because it is too generic and lacks specific details about a complete food item or dish. it does not provide enough information to be considered recommendable.
# Recommendable: 'Lamb or mutton curry' - Explanation: yes, "lamb or mutton curry" should be recommended as it represents a complete dish suitable for users. it includes a cooked protein (lamb or mutton) prepared in a flavorful curry sauce, making it a dish that can be enjoyed on its own or with rice or bread.
# Recommendable: 'Rice with beans' - Explanation: yes.
# "rice with beans" represents a complete dish that is suitable for recommendation to users. it is a common and delicious combination of rice and beans that can be a satisfying meal.
# Recommendable: 'Egg Salad, made with any type of fat free dressing' - Explanation: yes, this food description should be recommended. "egg salad" is a complete dish that can be made with various types of fat-free dressings, making it suitable for users looking for a healthy and flavorful meal option.
# Recommendable: 'Onions, cooked, NS as to form, NS as to fat added in cooking' - Explanation: yes, this food description should be recommended. it specifies onions that are cooked, which indicates it can be used as part of a recipe or dish. the variations mentioned ("ns as to form, ns as to fat added in cooking") also suggest that the onions can be prepared in different ways, making it suitable for recommendation.
# Not Recommendable: 'Plantain, boiled, NS as to green or ripe' - Explanation: no. plantain, boiled, ns as to green or ripe does not fully constitute a dish or recipe. it falls under the category of raw fruits and lacks additional preparation or elements to be considered a complete food item suitable for recommendation.
# Not Recommendable: 'Cereal, puffed rice' - Explanation: no, the food description "cereal, puffed rice" should not be recommended. it is too generic and lacks specificity about the type of cereal or any additional ingredients that would make it suitable for a recipe recommendation.
# Recommendable: 'Ham, prepackaged or deli, luncheon meat, reduced sodium' - Explanation: yes, this food description should be recommended. it represents a specific food item (reduced sodium luncheon meat) that can be used in a variety of recipes or eaten on its own. so, it meets the criteria for recommendation as a complete food item suitable for users.
# Recommendable: 'Roll, white, hoagie, submarine' - Explanation: yes. this food description can be recommended as it represents a type of bread roll that can be used as a base for making sandwiches or other dishes.
# Not Recommendable: 'Tomatoes, raw' - Explanation: no. this food description should not be recommended as it refers to raw vegetables, which falls under the category of raw vegetables that are typically not recommended due to being too generic and not representing a complete dish or recipe.
# Recommendable: 'Snack mix' - Explanation: yes, "snack mix" can be recommended as it represents a complete food item that is suitable for snacking or as a party treat. it consists of a mix of various ingredients like nuts, dried fruits, crackers, and sometimes candies, making it a versatile and satisfying snack option for users.
# Not Recommendable: 'Grapes, raw' - Explanation: no. raw fruits like grapes are not recommended as they do not represent a complete food item or dish suitable for recommendation.
# Recommendable: 'Beef, sandwich steak' - Explanation: yes, this food description should be recommended. "beef, sandwich steak" represents a complete food item that can be used as the main ingredient in a sandwich or other dishes, making it suitable for recommendation to users.
# Not Recommendable: 'Olives, NFS' - Explanation: no. olives, nfs (not from concentrate) is too generic and lacks sufficient context to be considered a suitable food recommendation for users.
# Recommendable: 'Cookie, oatmeal, with raisins' - Explanation: yes, this food description should be recommended. it represents a complete food item - oatmeal cookie with raisins, which is a suitable recommendation to users as it can be consumed as a snack or dessert.
# Recommendable: 'Ham, prepackaged or deli, luncheon meat' - Explanation: yes. "ham, prepackaged or deli, luncheon meat" can be recommended as it is a complete food item that is commonly used in various dishes and recipes, such as sandwiches, salads, and pasta dishes. it has culinary value and can be consumed on its own or as part of a meal.
# Recommendable: 'Beef, ground, patty' - Explanation: yes, this food description "beef, ground, patty" should be recommended. it represents a complete food item that can be used as part of a recipe or served as a dish on its own, making it suitable for recommendation to users.
# Not Recommendable: 'Mustard' - Explanation: no. mustard falls under the category of condiments, which are typically not standalone foods but rather used as accompaniments or flavor enhancers. therefore, it does not represent a complete food item or dish suitable for recommendation to users.
# Not Recommendable: 'Soft drink, pepper type' - Explanation: no. "soft drink, pepper type" should not be recommended. it is a generic description that does not represent a full food item or dish suitable for recommendation. also, "soft drink" is not a food but a beverage, and the reference to "pepper type" is not clear in the context of recommending food items.
# Recommendable: 'Cake or cupcake, white, without icing or filling' - Explanation: yes. this food description of "cake or cupcake, white, without icing or filling" is recommended as it represents a complete food item that can be consumed on its own or used as part of a dessert recipe. it is specific enough to be a suitable recommendation for users looking for baked goods options.
# Recommendable: 'Chocolate milk, NFS' - Explanation: yes, chocolate milk can be recommended as it represents a complete food item/drink that is suitable for consumption. it is a popular and well-known beverage that can be enjoyed on its own or used in various recipes.
# Recommendable: 'Corn, yellow, cooked, NS as to form, fat not added in cooking' - Explanation: yes, this food description should be recommended. it represents a complete food item, cooked corn, that can be used in various recipes and dishes.
# Recommendable: 'Potato, mashed, from dry mix, made with milk' - Explanation: yes, this food description should be recommended. it represents a complete food item - mashed potatoes made from a dry mix with milk, which is a dish suitable for recommendation to users.
# ...
# Recommendable: 'Fish sandwich, fried, on white bun, with cheese' - Explanation: yes, this food description should be recommended. it represents a complete food item (a fish sandwich) with specific details such as being fried, served on a white bun, and with cheese. this description is suitable for recommendation as it provides a clear idea of a dish that users can consider trying.
# Recommendable: 'Frankfurter or hot dog sandwich, beef and pork, plain, on whole wheat bun' - Explanation: yes, this food description should be recommended. it represents a complete food item - a frankfurter or hot dog sandwich made with beef and pork, on a whole wheat bun. this dish is suitable for recommendation to users due to its completeness and potential culinary value.
# Recommendable: 'Potato, scalloped, from dry mix, with meat' - Explanation: yes. this food description of "potato, scalloped, from dry mix, with meat" is suitable for recommendation as it represents a complete dish that includes potatoes prepared in a scalloped style from a dry mix and meat. this description meets the criteria for recommendable items as it constitutes a full dish suitable for users.
# Recommendable: 'Jelly sandwich, reduced sugar jelly, on white bread' - Explanation: yes, this food description should be recommended. it represents a complete food item (jelly sandwich) that can be part of a recipe or meal. it includes specific ingredients that create a dish suitable for recommendation to users.
# Recommendable: 'Soy nut butter' - Explanation: yes, "soy nut butter" can be recommended as it is a specific food item that can be used as a spread, dip, or ingredient in various recipes. it is not too generic, and it has culinary value as a substitute for traditional nut butters for those with nut allergies.
# Recommendable: 'Frozen yogurt sandwich' - Explanation: yes, "frozen yogurt sandwich" should be recommended. it represents a complete food item that can be enjoyed as a dessert or snack. it is a combination of frozen yogurt (a dairy product with culinary value) sandwiched between some form of bread or cookie. this description meets the criteria for a recommendable food item.
# Recommendable: 'Potato, roasted, from fresh, peel not eaten, NS as to fat' - Explanation: yes. this food description of "potato, roasted, from fresh, peel not eaten, ns as to fat" can be recommended as it represents a complete food item suitable for consumption and can be used as an ingredient in various dishes or recipes.
# Recommendable: 'Cheese sandwich, reduced fat American cheese, on whole wheat bread, with mayonnaise' - Explanation: yes, this food description should be recommended. it represents a complete food item - a cheese sandwich with specific ingredients - suitable for recommendation to users as it can be easily prepared and enjoyed as a meal.
# Recommendable: 'Frozen yogurt cone, vanilla, waffle cone' - Explanation: yes, this food description should be recommended. it represents a complete food item, a frozen yogurt cone with vanilla flavor in a waffle cone, which is suitable for recommendation to users as it is a dessert that can be enjoyed as a standalone dish.
# Recommendable: 'Bologna and cheese sandwich, with spread' - Explanation: yes. this food description of a "bologna and cheese sandwich, with spread" is suitable for recommendation as it represents a complete dish that can be consumed by users. it includes multiple ingredients assembled to create a full meal, making it a good recommendation.
# Recommendable: 'Toddler meal, pasta' - Explanation: yes. this food description, "toddler meal, pasta," can be recommended as it represents a specific dish suitable for consumption. it includes pasta as the main component of the meal, making it a complete food item that can be enjoyed as part of a recipe or meal.
# Recommendable: 'Pasta, whole grain, with cream sauce, poultry, and added vegetables, restaurant' - Explanation: yes, this food description should be recommended. it represents a complete dish - pasta with whole grain, cream sauce, poultry, and added vegetables served in a restaurant. it meets the criteria as it is a full dish suitable for recommendation to users.
# Attempt 1 failed for 'Asparagus, canned, cooked with oil' with error: 'NoneType' object has no attribute 'lower'
# Recommendable: 'Asparagus, canned, cooked with oil' - Explanation: yes, this food description should be recommended. "asparagus, canned, cooked with oil" represents a complete food item cooked with an ingredient, which can be used in a recipe or consumed as part of a dish. it meets the criteria for recommendable food descriptions.
# Not Recommendable: 'Baby Toddler juice, NFS' - Explanation: no. this food description is not recommendable. it is too generic and lacks specific details about the type of juice or ingredients used.
# Not Recommendable: 'Barley' - Explanation: no. "barley" is a single ingredient and is not a complete food item or dish. it is not suitable for recommendation based on the criteria provided.
# Recommendable: 'Salami sandwich on white' - Explanation: yes, this food description should be recommended. it represents a complete food item or dish that is suitable for users - a salami sandwich on white bread. it is specific and can be easily understood by users as a meal option.
# Recommendable: 'Corned beef sandwich on wheat' - Explanation: yes, the food description "corned beef sandwich on wheat" should be recommended. it represents a complete food item (sandwich) consisting of corned beef and wheat bread, which is suitable for recommendation to users as it is a full dish that can be enjoyed as a meal.
# Recommendable: 'Gordita, cheese only' - Explanation: yes, the food description "gordita, cheese only" should be recommended. it represents a complete food item suitable for recommendation as it includes both the gordita (a type of dish) and cheese as components, making it a suitable choice for users looking for a flavorful dish to try.
# Recommendable: 'Cheese steak sandwich or sub on wheat' - Explanation: yes, this food description should be recommended. it represents a complete and popular dish - a cheese steak sandwich or sub made with wheat bread. it is a substantial food item suitable for recommendation to users.
# Recommendable: 'Burrito, chicken, with beans, cheese' - Explanation: yes. this food description of "burrito, chicken, with beans, cheese" is suitable for recommendation as it represents a complete dish that includes a combination of ingredients commonly used in recipes.
# Not Recommendable: 'Baby Toddler food, NFS' - Explanation: no, this should not be recommended. the description is too generic and does not specify any particular food item or dish.
# Not Recommendable: 'Baby Toddler meat, NFS' - Explanation: no, the food description "baby toddler meat, nfs" should not be recommended. while it specifies a type of meat suitable for a specific demographic (babies and toddlers), it does not provide enough detail to indicate a complete food item or dish that can be recommended to users. additionally, it falls under the category of raw meat, which is not recommended based on the criteria provided.
# Recommendable: 'Vegetable sandwich on wheat' - Explanation: yes. this food description, "vegetable sandwich on wheat," is recommended. it represents a complete food item with specific ingredients that can be used to create a dish suitable for recommendation to users.
# Recommendable: 'Johnnycake' - Explanation: yes, "johnnycake" can be recommended. it represents a complete food item that is suitable for recommendation to users.
# Recommendable: 'Nachos, NFS' - Explanation: yes, this food description should be recommended. nachos are a complete food item that can be used as a dish or as part of a recipe, making it suitable for recommendation to users.
# Not Recommendable: 'Baby Toddler multiple fruit, Stage 3' - Explanation: no, this food description should not be recommended. it is too generic and lacks specific details about the actual food item or dish. it does not provide enough information to determine if it meets the criteria for recommendable food descriptions.
# Not Recommendable: 'Toddler meal, NFS' - Explanation: no. this food description is too generic and lacks specific details about the meal. it does not provide any useful information for recommending it to users.
# Not Recommendable: 'Broccoli raab, raw' - Explanation: no. this food description "broccoli raab, raw" should not be recommended as it falls under the category of raw vegetables which are not suitable for recommendation according to the criteria provided.
# Recommendable: 'White beans, from canned, reduced sodium' - Explanation: yes. this food description of "white beans, from canned, reduced sodium" can be recommended as it represents a complete food item that can be used as an ingredient in various recipes or dishes.
# Recommendable: 'Burrito bowl, beef or pork' - Explanation: yes, this food description should be recommended. a "burrito bowl, beef or pork" represents a complete dish that includes protein (beef or pork) and a variety of other ingredients typically found in a burrito bowl like rice, beans, vegetables, and toppings. this dish is suitable for recommendation to users as it is a complete and satisfying meal option.
# Recommendable: 'Burrito bowl, chicken' - Explanation: yes, this food description should be recommended. a burrito bowl with chicken is a complete dish that can be enjoyed by users. it includes multiple components and is suitable for recommendation as part of a meal option.
# Not Recommendable: 'Beef, steak, T-bone,  lean and fat eaten' - Explanation: no. the food description provided is not suitable for recommendation as it consists of raw meat items and lacks a complete recipe or dish idea.
# Recommendable: 'Pasta, whole grain, with tomato-based sauce, meat, and added vegetables, restaurant' - Explanation: yes, this food description should be recommended. it represents a complete dish including pasta, whole grain, tomato-based sauce, meat, and vegetables. it is suitable for recommending to users as it constitutes a complete meal that can be prepared at home or ordered at a restaurant.
# Recommendable: 'Club sandwich on wheat, with cheese' - Explanation: yes
#
# explanation: the food description of "club sandwich on wheat, with cheese" represents a complete food item that is suitable for recommendation to users. it includes a combination of ingredients suitable for a dish.
# Recommendable: 'Almond butter and jelly sandwich, on white bread' - Explanation: yes, this food description should be recommended. it represents a complete food item (almond butter and jelly sandwich) that is suitable for users as a dish.
# Recommendable: 'Baby Toddler cereal, oatmeal, ready-to-eat' - Explanation: yes, this food description can be recommended. it represents a complete food item suitable for consumption, specifically baby and toddler oatmeal cereal that is ready-to-eat. it can be a convenient and nutritious option for parents looking for easy meals for their young children.
# Recommendable: 'Taco, flour tortilla, pork, with beans, cheese' - Explanation: yes, this food description should be recommended as it represents a complete dish – a taco made with a flour tortilla, pork, beans, and cheese. the combination of these ingredients forms a delicious and satisfying meal suitable for recommendation to users.
# Recommendable: 'Infant formula, organic, ready-to-feed' - Explanation: yes, this food description can be recommended. it represents a complete food item that is suitable for consumption and can be used as a standalone item for infants.
# Recommendable: 'Vegetable sandwich on white' - Explanation: yes, this food description should be recommended. a "vegetable sandwich on white" represents a complete food item suitable for recommendation to users. it includes ingredients that form a dish and can be used as part of a recipe.
# Recommendable: 'Club sandwich on wheat' - Explanation: yes, this food description should be recommended.
#
# explanation: the "club sandwich on wheat" represents a complete food item/dish that includes bread (wheat), various fillings like meat, cheese, lettuce, tomato, bacon, etc., and condiments like mayonnaise or mustard. it is suitable for recommendation as it is a well-known and popular sandwich option for a meal.
# Recommendable: 'Asparagus, frozen, cooked with oil' - Explanation: yes, this food description should be recommended. "asparagus, frozen, cooked with oil" represents a completed food item that can be used as part of a recipe or a full dish. it is a specific preparation of a vegetable that is suitable for recommendation to users.
# Recommendable: 'Cheese sandwich, reduced fat cheese, on wheat bread' - Explanation: yes.
#
# explanation: the food description provided represents a complete food item (cheese sandwich) that is suitable for recommendation to users. it includes specific ingredients and describes a dish that can be prepared and enjoyed as part of a meal.
# Recommendable: 'Oatmeal, instant, plain, made with non-dairy milk, fat added' - Explanation: yes, this food description should be recommended. it represents a complete dish - oatmeal made with non-dairy milk and added fat, which can be a suitable and flavorful breakfast option for users.
# Recommendable: 'White pizza, cheese, with meat and vegetables, thick crust' - Explanation: yes, this food description should be recommended. it represents a complete food item (white pizza) with cheese, meat, and vegetables on a thick crust, making it suitable for recommendation to users as a full dish.
# Recommendable: 'Ham biscuit sandwich' - Explanation: yes, "ham biscuit sandwich" should be recommended. it represents a complete food item that is suitable for recommendation to users as it is a dish and not just a single ingredient or raw item.
# Recommendable: 'Rice, white, with carrots, dark green vegetables, and tomatoes and/or tomato-based sauce, no added fat' - Explanation: yes. this food description can be recommended as it represents a complete dish with rice, carrots, dark green vegetables, and tomatoes or tomato-based sauce. it is a balanced meal without added fat, suitable for users looking for a healthy option.
# Recommendable: 'Ham salad sandwich' - Explanation: yes, "ham salad sandwich" can be recommended as it represents a complete food item that is suitable for users. it is a combination of ingredients put together to create a dish, making it a suitable recommendation.
# Recommendable: 'Kimchi soup' - Explanation: yes, "kimchi soup" should be recommended. it represents a complete food item that is suitable for users. it can serve as a flavorful and satisfying dish on its own or be used as a component in a larger meal.
# Recommendable: 'Turkey and ham sandwich or sub, restaurant' - Explanation: yes, "turkey and ham sandwich or sub, restaurant" can be recommended. it represents a complete food item suitable for users as it is a popular and satisfying dish that can be consumed as a meal or snack.
# Recommendable: 'Turkey and ham sandwich on white' - Explanation: yes, this food description should be recommended. the "turkey and ham sandwich on white" represents a complete food item suitable for recommendation as it is a dish that can be consumed directly by users.
# Recommendable: 'Taco, corn tortilla, pork, with beans, cheese' - Explanation: yes, this food description should be recommended. it represents a complete dish, specifically a taco with corn tortilla, pork, beans, and cheese. it meets the criteria as it is a full dish suitable for user recommendation.
# Recommendable: 'Corned beef sandwich on white, with cheese' - Explanation: yes, this food description should be recommended. it represents a complete food item, a "corned beef sandwich on white, with cheese," which is suitable for recommendation to users as it is a complete dish that can be prepared and enjoyed.
# Filtered data saved to 'recommendable_foods.csv' and 'non_recommendable_foods.csv'

# %%
recommendable_foods_df.to_csv('../processed_data/recommendable_foods_original.csv', index=False)
non_recommendable_foods_df.to_csv('../processed_data/non_recommendable_foods_original.csv', index=False)

# %%
import pandas as pd

# Load the recommendable_foods.csv into a DataFrame
recommendable_foods_df = pd.read_csv('../processed_data/recommendable_foods.csv')

# Load the food_tagging.csv into a DataFrame
food_tagging_df = pd.read_csv('../processed_data/food_tagging.csv')

# Perform a left join on 'food_id'
recommendable_foods_tagging_df = pd.merge(
    recommendable_foods_df,
    food_tagging_df,
    how='left',
    on='food_id'
)

# Save the joined DataFrame to a new CSV file
recommendable_foods_tagging_df.to_csv('../processed_data/recommendable_foods_tagging.csv', index=False)

# %% [markdown]
# ### **Q&A pairs creation:**

# %% [markdown]
# ##### Step 1: finding top 5,000 pairs of user-food that have the most macro tags in common (we don't care about the high/low level for now)

# %% [markdown]
# *Note: here, I initially used the wrong data: I used the whole users list (96k users) from user_tagging but forgot that we actually only need to look at opioid users and recovered users (i.e. excluding non-opioid users)*
#
# This will be fixed in the next step

# %%
import pandas as pd

num_qa = 5000

recommendable_foods_tagging = pd.read_csv('../processed_data/recommendable_foods_tagging.csv') 
food_tagging = pd.read_csv('../processed_data/food_tagging.csv')
user_tagging = pd.read_csv('../processed_data/user_tagging.csv')

# List of macro nutrient columns to consider
macro_columns = [
    'macro_carb', 'macro_phosphorus', 'macro_calorie', 'macro_potassium', 'macro_sodium',
    'macro_cholesterol', 'macro_saturated_fat', 'macro_protein', 'macro_sugar', 'macro_fiber',
    'macro_iron', 'macro_folic_acid', 'macro_vitamin_b12', 'macro_calcium', 'micro_vitamin_d',
    'macro_vitamin_c'
]

# Step 0: Filter food_tagging to only include food_ids that exist in recommendable_foods_tagging
food_tagging = food_tagging[food_tagging['food_id'].isin(recommendable_foods_tagging['food_id'])]

# Step 1: Identify Top num_qa Users with Most `macro_` Tags Equal to 1
user_tagging['macro_tag_count'] = user_tagging[macro_columns].sum(axis=1)
top_users = user_tagging.nlargest(num_qa, 'macro_tag_count')

# Step 2: Identify Top num_qa Foods with Most `macro_` Tags Equal to 1 (after filtering food_tagging)
food_tagging['macro_tag_count'] = food_tagging[macro_columns].sum(axis=1)
top_foods = food_tagging.nlargest(num_qa, 'macro_tag_count')

# Step 3: Perform cross join on the top num_qa users and top num_qa foods
user_macro_df = top_users[['SEQN'] + macro_columns]
food_macro_df = top_foods[['food_id'] + macro_columns]

# Cross join users and foods
user_food_cross = user_macro_df.assign(key=1).merge(food_macro_df.assign(key=1), on='key').drop('key', axis=1)

# Multiply corresponding macro columns and sum them up to calculate matching tags
for col in macro_columns:
    user_food_cross[f'{col}_match'] = user_food_cross[f'{col}_x'] * user_food_cross[f'{col}_y']

user_food_cross['matching_nutrients'] = user_food_cross[[f'{col}_match' for col in macro_columns]].sum(axis=1)

# Sort and select top pairs with the most matching macro tags
top_pairs = user_food_cross.sort_values(by='matching_nutrients', ascending=False).head(num_qa)

# Merge with recommendable_foods_tagging to get food descriptions, and filter out rows where 'food_desc' is NaN
top_with_desc = pd.merge(top_pairs, recommendable_foods_tagging[['food_id', 'food_desc']], on='food_id', how='left')
top_with_desc = top_with_desc[top_with_desc['food_desc'].notna()]

selected_columns = top_with_desc[['SEQN', 'food_id']]
selected_columns.to_csv('../processed_data/user_food_pairs.csv', index=False)
# Out:
#         SEQN   food_id                                          food_desc  \
# 0      34040  91770020                 Dietetic or low calorie hard candy
# 1      34040  95201000  Nutritional powder mix (Carnation Instant Brea...
# 2      34040  42203200                                     Soy nut butter
# 3      34040  95210020   Nutritional powder mix, high protein (Slim Fast)
# 4      34040  57332050           Cereal (General Mills Total Raisin Bran)
# ...      ...       ...                                                ...
# 4995   63287  57212100                Cereal (General Mills Frankenberry)
# 4996  114261  21302000                           Beef, neck bones, cooked
# 4997  114261  51109110                               Bread, pita, toasted
# 4998  114261  25221520  Salami, made from any type of meat, reduced so...
# 4999   83019  92309520             Tea, iced, bottled, green, unsweetened
#
#       matching_nutrients
# 0                     13
# 1                     13
# 2                     13
# 3                     13
# 4                     13
# ...                  ...
# 4995                  10
# 4996                  10
# 4997                  10
# 4998                  10
# 4999                  10
#
# [5000 rows x 4 columns]

# %%
# selected_columns = top_with_desc[['SEQN', 'food_id']]
# selected_columns.to_csv('../processed_data/user_food_pairs.csv', index=False)

# %%
import os
import pandas as pd
import time
from autogen import ConversableAgent
from dotenv import load_dotenv

load_dotenv()
api_key = os.getenv("OPENAI_API_KEY")

llm_config = {
    "model": "gpt-3.5-turbo",
    "api_key": api_key
}

# food recommendation agent 
agent = ConversableAgent(
    name="food_recommendation_agent",
    llm_config=llm_config,
    human_input_mode="NEVER",
)

recommendable_foods_df = pd.read_csv('../processed_data/recommendable_foods_tagging.csv')
user_tagging_df = pd.read_csv('../processed_data/user_tagging.csv')
user_food_pairs_df = pd.read_csv('../processed_data/user_food_pairs.csv')

# Create a helper function to get the nutrition tags with value 1 for user or food
def get_tags_with_value_1(row, prefix):
    return [col for col in row.index if row[col] == 1 and col.startswith(prefix)]

# Define scoring weights
high_weight_categories = [
    "low_calorie", "high_calorie", "low_protein", "high_protein", "low_carb", "high_carb",
    "low_sugar", "high_sugar", "low_fiber", "high_fiber", "low_saturated_fat", "high_saturated_fat",
    "low_cholesterol", "high_cholesterol", "low_sodium", "high_sodium"
]
low_weight_categories = [
    "low_calcium", "high_calcium", "low_phosphorus", "high_phosphorus", "low_potassium", "high_potassium",
    "low_iron", "high_iron", "low_folic_acid", "high_folic_acid", "low_vitamin_c", "high_vitamin_c",
    "low_vitamin_d", "high_vitamin_d", "low_vitamin_b12", "high_vitamin_b12"
]

# Define a question-answer template
qa_template = """
You must produce output following this template:

Question: For User <SEQN>, given the health profile: <all nutrition tags of the user, i.e. columns in user_tagging starting with prefix user_ and have value of 1>, please judge if Food <food_id> <food_desc>, <all nutrition tags of the food, i.e. columns in recommendable_foods_tagging starting with high_ or low_ and have value of 1>, is a healthy option to the user, and why?

Answer: <Yes/No>, because the food is <high/low> in <nutrients> (these nutrients match with the user's health profile), but <high/low> in <nutrients> (these nutrients are opposite to the user's health profile).
"""

# Iterate over user-food pairs to generate question-answer pairs
question_answer_pairs = []

for _, pair in user_food_pairs_df.iterrows():
    seqn = pair['SEQN']
    food_id = pair['food_id']
    
    # Get user nutritional tags
    user_row = user_tagging_df[user_tagging_df['SEQN'] == seqn]
    if user_row.empty:
        continue
    user_tags = get_tags_with_value_1(user_row.iloc[0], "user_")

    # Get food nutritional tags
    food_row = recommendable_foods_df[recommendable_foods_df['food_id'] == food_id]
    if food_row.empty:
        continue
    food_tags = get_tags_with_value_1(food_row.iloc[0], ("low_", "high_"))

    # Calculate health score
    health_score = 0
    for tag in user_tags:
        food_tag = tag.replace("user_", "")
        
        if food_tag in high_weight_categories:
            if food_tag in food_tags:
                health_score += 10  # Match in high-weight category
            else:
                health_score -= 10  # Mismatch in high-weight category
        elif food_tag in low_weight_categories:
            if food_tag in food_tags:
                health_score += 1  # Match in low-weight category
            else:
                health_score -= 1  # Mismatch in low-weight category

    # Determine the suitability based on health score
    is_healthy = health_score >= 0

    # Create question text
    user_tags_str = ", ".join(user_tags)
    food_desc = food_row.iloc[0]['food_desc']
    food_tags_str = ", ".join(food_tags)
    
    question = (
        f"For User {seqn}, given the health profile: {user_tags_str}, "
        f"please judge if Food {food_id} ({food_desc}), with nutritional properties: {food_tags_str}, "
        "is a healthy option for the user, and why?"
    )

    # Prepare the complete prompt by adding the QA template
    complete_prompt = qa_template + f"\n\n{question}"

    # Generate answer from the score
    answer = "Yes" if is_healthy else "No"

    # Generate reply from agent (LLM should generate a coherent explanation)
    try:
        response = agent.generate_reply(
            messages=[{"content": complete_prompt, "role": "user"}]
        )
        
        formatted_answer = f"{answer}, because {response.strip()}"
        
        question_answer_pairs.append({
            "SEQN": seqn,
            "food_id": food_id,
            "food_desc": food_desc,
            "question": question,
            "answer": formatted_answer
        })
        print(f"Generated answer for SEQN {seqn} and food_id {food_id}: {formatted_answer}")

    except Exception as e:
        print(f"Error generating answer for SEQN {seqn} and food_id {food_id}: {e}")
        continue

    # avoid exceeding rate limits
    time.sleep(2)

qa_pairs_df = pd.DataFrame(question_answer_pairs)
# Out:
# [autogen.oai.client: 09-29 10:36:59] {184} WARNING - The API key specified is not a valid OpenAI format; it won't work with the OpenAI-hosted model.
# Generated answer for SEQN 34040 and food_id 91770020: Yes, because Question: For User 34040, given the health profile: user_low_calorie, user_high_potassium, user_low_sodium, user_low_cholesterol, user_low_saturated_fat, user_low_protein, user_high_fiber, user_high_iron, user_high_folate_acid, user_high_vitamin_b12, user_high_calcium, user_high_vitamin_d, user_high_vitamin_c, please judge if Food 91770020 (Dietetic or low calorie hard candy), with nutritional properties: high_calorie, low_protein, high_carb, high_sugar, low_fiber, low_saturated_fat, low_cholesterol, low_sodium, low_calcium, low_phosphorus, low_potassium, low_iron, low_folic_acid, low_vitamin_c, low_vitamin_d, low_vitamin_b12, is a healthy option for the user, and why?
#
# Answer: No, because the food is high in sugar (opposite to user_high_fiber and user_low_sugar) and low in potassium (opposite to user_high_potassium).
# Generated answer for SEQN 34040 and food_id 95201000: No, because Question: For User 34040, given the health profile: user_low_calorie, user_high_potassium, user_low_sodium, user_low_cholesterol, user_low_saturated_fat, user_low_protein, user_high_fiber, user_high_iron, user_high_folate_acid, user_high_vitamin_b12, user_high_calcium, user_high_vitamin_d, user_high_vitamin_c, please judge if Food 95201000 (Nutritional powder mix (Carnation Instant Breakfast)), with nutritional properties: high_calorie, high_protein, high_sugar, low_fiber, low_saturated_fat, low_cholesterol, high_sodium, high_calcium, high_phosphorus, high_potassium, high_iron, high_folic_acid, high_vitamin_c, low_vitamin_d, high_vitamin_b12, is a healthy option for the user, and why?
#
# Answer: No, because the food is high in potassium (matches with the user's health profile), but high in sodium, high in sugar, and low in fiber, saturated fat, and vitamin D (opposite to the user's health profile).
# Generated answer for SEQN 34040 and food_id 42203200: No, because Question: For User 34040, given the health profile: user_low_calorie, user_high_potassium, user_low_sodium, user_low_cholesterol, user_low_saturated_fat, user_low_protein, user_high_fiber, user_high_iron, user_high_folate_acid, user_high_vitamin_b12, user_high_calcium, user_high_vitamin_d, user_high_vitamin_c, please judge if Food 42203200 (Soy nut butter), with nutritional properties: high_calorie, high_protein, low_carb, high_fiber, high_saturated_fat, low_cholesterol, high_sodium, high_calcium, high_phosphorus, high_potassium, high_iron, low_folic_acid, low_vitamin_c, low_vitamin_d, low_vitamin_b12, is a healthy option for the user, and why?
#
# Answer: No, because the food is high in potassium (matches user's requirement), high in iron (matches user's requirement), and high in fiber (matches user's requirement), but it is high in saturated fat (opposite to the user's health profile), high in sodium (opposite to the user's health profile), and low in vitamin C (opposite to the user's health profile).
# Generated answer for SEQN 34040 and food_id 95210020: Yes, because Question: For User 34040, given the health profile: user_low_calorie, user_high_potassium, user_low_sodium, user_low_cholesterol, user_low_saturated_fat, user_low_protein, user_high_fiber, user_high_iron, user_high_folate_acid, user_high_vitamin_b12, user_high_calcium, user_high_vitamin_d, user_high_vitamin_c, please judge if Food 95210020 (Nutritional powder mix, high protein (Slim Fast)), with nutritional properties: high_calorie, high_protein, low_carb, high_fiber, low_saturated_fat, low_cholesterol, high_sodium, high_calcium, high_phosphorus, high_potassium, high_iron, high_folic_acid, high_vitamin_c, high_vitamin_d, high_vitamin_b12, is a healthy option for the user, and why?
#
# Answer: No, because the food is high in protein (matches user's health profile) but high in sodium, saturated fat, and cholesterol (opposite to the user's health profile).
# Generated answer for SEQN 34040 and food_id 57332050: Yes, because Question: For User 34040, given the health profile: user_low_calorie, user_high_potassium, user_low_sodium, user_low_cholesterol, user_low_saturated_fat, user_low_protein, user_high_fiber, user_high_iron, user_high_folate_acid, user_high_vitamin_b12, user_high_calcium, user_high_vitamin_d, user_high_vitamin_c, please judge if Food 57332050 (Cereal (General Mills Total Raisin Bran)), with nutritional properties: high_calorie, low_protein, high_carb, high_sugar, high_fiber, low_saturated_fat, low_cholesterol, high_sodium, high_calcium, high_phosphorus, high_potassium, high_iron, high_folic_acid, low_vitamin_c, high_vitamin_d, high_vitamin_b12, is a healthy option for the user, and why?
#
# Answer: No, because the food is high in calorie (opposite to user_low_calorie), low in protein (opposite to user_low_protein), low in saturated fat (matches user preference), low in cholesterol (matches user preference), high in sodium (opposite to user_low_sodium), high in sugar (opposite to user's health profile), high in calcium (matches user preference), high in potassium (matches user preference), high in iron (matches user preference), high in folic acid (matches user preference), high in vitamin D (matches user preference), high in vitamin B12 (matches user preference), low in vitamin C (opposite to user's health profile), and high in fiber (matches user preference).
# Generated answer for SEQN 34040 and food_id 57321800: Yes, because Answer: No, because the food is high in calories, protein, sodium, calcium, phosphorus, iron (these nutrients match with the user's health profile), but low in fiber, folic acid, vitamin C, vitamin D, vitamin B12 (these nutrients are opposite to the user's health profile).
# Generated answer for SEQN 34040 and food_id 42200510: Yes, because Question: For User 34040, given the health profile: user_low_calorie, user_high_potassium, user_low_sodium, user_low_cholesterol, user_low_saturated_fat, user_low_protein, user_high_fiber, user_high_iron, user_high_folate_acid, user_high_vitamin_b12, user_high_calcium, user_high_vitamin_d, user_high_vitamin_c, please judge if Food 42200510 (Almond butter, lower sodium), with nutritional properties: high_calorie, high_protein, low_carb, high_fiber, high_saturated_fat, low_cholesterol, low_sodium, high_calcium, high_phosphorus, high_potassium, high_iron, low_folic_acid, low_vitamin_c, low_vitamin_d, low_vitamin_b12, is a healthy option for the user, and why?
#
# Answer: Yes, because the food is high in potassium (matches user_high_potassium), high in fiber (matches user_high_fiber), low in sodium (matches user_low_sodium), low in cholesterol (matches user_low_cholesterol), low in saturated fat (matches user_low_saturated_fat), high in calcium (matches user_high_calcium), and high in iron (matches user_high_iron). However, it is high in saturated fat (opposite to user's health profile) and low in vitamin C, vitamin D, and vitamin B12 (opposite to user's health profile).
# Generated answer for SEQN 34040 and food_id 11830210: Yes, because Question: For User 34040, given the health profile: user_low_calorie, user_high_potassium, user_low_sodium, user_low_cholesterol, user_low_saturated_fat, user_low_protein, user_high_fiber, user_high_iron, user_high_folate_acid, user_high_vitamin_b12, user_high_calcium, user_high_vitamin_d, user_high_vitamin_c, please judge if Food 11830210 (Chocolate beverage powder, light, dry mix, not reconstituted), with nutritional properties: high_calorie, low_protein, high_carb, high_sugar, low_fiber, low_saturated_fat, low_cholesterol, high_sodium, high_calcium, high_phosphorus, high_potassium, high_iron, low_folic_acid, high_vitamin_c, high_vitamin_d, high_vitamin_b12, is a healthy option for the user, and why?
#
# Answer: No, because the food is high in calorie (opposite to user_low_calorie), high in sodium (opposite to user_low_sodium), low in fiber (opposite to user_high_fiber), low in iron (opposite to user_high_iron), and low in folate acid (opposite to user_high_folate_acid).
# Generated answer for SEQN 34040 and food_id 92309040: Yes, because Question: For User 34040, given the health profile: user_low_calorie, user_high_potassium, user_low_sodium, user_low_cholesterol, user_low_saturated_fat, user_low_protein, user_high_fiber, user_high_iron, user_high_folate_acid, user_high_vitamin_b12, user_high_calcium, user_high_vitamin_d, user_high_vitamin_c, please judge if Food 92309040 (Tea, iced, bottled, black, unsweetened), with nutritional properties: low_calorie, low_protein, low_carb, low_sugar, low_fiber, low_saturated_fat, low_cholesterol, low_sodium, low_calcium, low_phosphorus, low_potassium, low_iron, low_folic_acid, low_vitamin_c, low_vitamin_d, low_vitamin_b12, is a healthy option for the user, and why?
#
# Answer: Yes, because the food is low in calorie, low in protein (matching user's health profile), but high in potassium, which is beneficial for the user's high potassium requirement. Additionally, it is low in sodium, cholesterol, saturated fat, and other nutrients that are not recommended in the user's health profile.
# Generated answer for SEQN 74262 and food_id 42101130: Yes, because Question: For User 74262, given the health profile: user_low_calorie, user_high_potassium, user_low_sodium, user_low_protein, user_low_sugar, user_high_fiber, user_high_iron, user_high_folate_acid, user_high_vitamin_b12, user_high_calcium, user_high_vitamin_d, user_high_vitamin_c, please judge if Food 42101130 (Almonds, unsalted), with nutritional properties: high_calorie, high_protein, low_carb, low_sugar, high_fiber, low_cholesterol, low_sodium, high_calcium, high_phosphorus, high_potassium, high_iron, low_folic_acid, low_vitamin_c, low_vitamin_d, low_vitamin_b12, is a healthy option for the user, and why?
#
# Answer: Yes, because the food is high in potassium (matches user's high potassium requirement), high in fiber (matches user's high fiber preference), high in iron (matches user's high iron preference), and high in calcium (matches user's high calcium preference), but low in sodium (matches user's low sodium preference), low in protein (matches user's low protein requirement), low in sugar (matches user's low sugar preference), low in folic acid (opposite to user's high folate acid preference), low in vitamin C (opposite to user's high vitamin C preference), low in vitamin D (opposite to user's high vitamin D preference), and low in vitamin B12 (opposite to user's high vitamin B12 preference).
# Generated answer for SEQN 74262 and food_id 42101300: No, because Question: For User 74262, given the health profile: user_low_calorie, user_high_potassium, user_low_sodium, user_low_protein, user_low_sugar, user_high_fiber, user_high_iron, user_high_folate_acid, user_high_vitamin_b12, user_high_calcium, user_high_vitamin_d, user_high_vitamin_c, please judge if Food 42101300 (Almonds, flavored), with nutritional properties: high_calorie, high_protein, low_carb, low_sugar, high_fiber, low_cholesterol, high_sodium, high_calcium, high_phosphorus, high_potassium, high_iron, low_folic_acid, low_vitamin_c, low_vitamin_d, low_vitamin_b12, is a healthy option for the user, and why?
#
# Answer: No, because the food is high in potassium (matches user's health profile), but high in sodium (opposite to user's health profile).
# Generated answer for SEQN 24811 and food_id 42101200: Yes, because Question: For User 24811, given the health profile: user_low_calorie, user_high_potassium, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, user_high_iron, user_high_folate_acid, user_high_vitamin_b12, user_high_calcium, user_high_vitamin_d, user_high_vitamin_c, please judge if Food 42101200 (Almonds, unsalted), with nutritional properties: high_calorie, high_protein, low_carb, low_sugar, high_fiber, low_cholesterol, high_sodium, high_calcium, high_phosphorus, high_potassium, high_iron, low_folic_acid, low_vitamin_c, low_vitamin_d, low_vitamin_b12, is a healthy option for the user, and why?
#
# Answer: No, because the food is high in protein (opposite to user_low_protein), high in sodium (opposite to user_low_sodium), and low in vitamin C (opposite to user_high_vitamin_c). However, it is high in potassium and fiber, which align with the user's health profile.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 133
#     130         continue
#     132     # Adding delay to avoid exceeding rate limits
# --> 133     time.sleep(2)
#     135 # Convert the question-answer pairs to a DataFrame
#     136 qa_pairs_df = pd.DataFrame(question_answer_pairs)
#
# KeyboardInterrupt:

# %%
# qa_pairs_df.to_csv('../processed_data/recommendable_foods_question_answers.csv', index=False)
# print("Question-answer pairs saved to '../processed_data/recommendable_foods_question_answers.csv'")

# %% [markdown]
# **Using the correct data:** filtering for only active & recovered opioid users by referencing users that are in joined_graph

# %%
import torch
import pandas as pd


num_qa = 5000

# Load the joined graph
joined_graph = torch.load('../processed_data/joined_graph.pt')

# Extract the user node IDs from the graph
user_ids_in_graph = joined_graph['user'].node_id.tolist()

# Load the user_tagging.csv file
user_tagging = pd.read_csv('../processed_data/user_tagging.csv')

# Filter user_tagging to include only users that are present in the graph
filtered_user_tagging = user_tagging[user_tagging['SEQN'].isin(user_ids_in_graph)]

# Now proceed with your original code using the filtered_user_tagging DataFrame

# List of macro nutrient columns to consider
macro_columns = [
    'macro_carb', 'macro_phosphorus', 'macro_calorie', 'macro_potassium', 'macro_sodium',
    'macro_cholesterol', 'macro_saturated_fat', 'macro_protein', 'macro_sugar', 'macro_fiber',
    'macro_iron', 'macro_folic_acid', 'macro_vitamin_b12', 'macro_calcium', 'micro_vitamin_d',
    'macro_vitamin_c'
]

# Step 0: Filter food_tagging to only include food_ids that exist in recommendable_foods_tagging
recommendable_foods_tagging = pd.read_csv('../processed_data/recommendable_foods_tagging.csv') 
food_tagging = pd.read_csv('../processed_data/food_tagging.csv')
food_tagging = food_tagging[food_tagging['food_id'].isin(recommendable_foods_tagging['food_id'])]

# Step 1: Identify Top num_qa Users with Most `macro_` Tags Equal to 1
filtered_user_tagging['macro_tag_count'] = filtered_user_tagging[macro_columns].sum(axis=1)
top_users = filtered_user_tagging.nlargest(num_qa, 'macro_tag_count')

# Step 2: Identify Top num_qa Foods with Most `macro_` Tags Equal to 1 (after filtering food_tagging)
food_tagging['macro_tag_count'] = food_tagging[macro_columns].sum(axis=1)
top_foods = food_tagging.nlargest(num_qa, 'macro_tag_count')

# Step 3: Perform cross join on the top num_qa users and top num_qa foods
user_macro_df = top_users[['SEQN'] + macro_columns]
food_macro_df = top_foods[['food_id'] + macro_columns]

# Cross join users and foods
user_food_cross = user_macro_df.assign(key=1).merge(food_macro_df.assign(key=1), on='key').drop('key', axis=1)

# Multiply corresponding macro columns and sum them up to calculate matching tags
for col in macro_columns:
    user_food_cross[f'{col}_match'] = user_food_cross[f'{col}_x'] * user_food_cross[f'{col}_y']

user_food_cross['matching_nutrients'] = user_food_cross[[f'{col}_match' for col in macro_columns]].sum(axis=1)

# Sort and select top pairs with the most matching macro tags
top_pairs = user_food_cross.sort_values(by='matching_nutrients', ascending=False).head(num_qa)

# Merge with recommendable_foods_tagging to get food descriptions, and filter out rows where 'food_desc' is NaN
top_with_desc = pd.merge(top_pairs, recommendable_foods_tagging[['food_id', 'food_desc']], on='food_id', how='left')
top_with_desc = top_with_desc[top_with_desc['food_desc'].notna()]

selected_columns = top_with_desc[['SEQN', 'food_id']]
selected_columns.to_csv('../processed_data/user_food_pairs.csv', index=False)
# Out:
# C:\Users\halan\AppData\Local\Temp\ipykernel_33608\127203116.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_user_tagging['macro_tag_count'] = filtered_user_tagging[macro_columns].sum(axis=1)

# %%
display(top_with_desc[['SEQN', 'food_id', 'food_desc', 'matching_nutrients']])
# Out:
#         SEQN   food_id                                          food_desc  \
# 0      23816  91770020                 Dietetic or low calorie hard candy
# 1     123231  14108060             Cheese, Parmesan, dry grated, fat free
# 2     123231  91770020                 Dietetic or low calorie hard candy
# 3     123231  57332050           Cereal (General Mills Total Raisin Bran)
# 4     123231  11830210  Chocolate beverage powder, light, dry mix, not...
# ...      ...       ...                                                ...
# 4995  123231  54337100                 Crackers, woven wheat, reduced fat
# 4996   95412  92650210              Cornmeal beverage with chocolate milk
# 4997   47343  57305174               Cereal (Malt-O-Meal Colossal Crunch)
# 4998   95656  92191400  Coffee, instant, pre-sweetened with sugar, not...
# 4999   47343  53260150                 Cookie, chocolate chip, sugar free
#
#       matching_nutrients
# 0                     12
# 1                     12
# 2                     12
# 3                     12
# 4                     12
# ...                  ...
# 4995                   9
# 4996                   9
# 4997                   9
# 4998                   9
# 4999                   9
#
# [5000 rows x 4 columns]

# %%
import os
import pandas as pd
import time
from autogen import ConversableAgent
from dotenv import load_dotenv

load_dotenv()
api_key = os.getenv("OPENAI_API_KEY")

llm_config = {
    "model": "gpt-3.5-turbo",
    "api_key": api_key
}

# food recommendation agent
agent = ConversableAgent(
    name="food_recommendation_agent",
    llm_config=llm_config,
    human_input_mode="NEVER",
)

recommendable_foods_df = pd.read_csv('../processed_data/recommendable_foods_tagging.csv')
user_tagging_df = pd.read_csv('../processed_data/user_tagging.csv')
user_food_pairs_df = pd.read_csv('../processed_data/user_food_pairs.csv')

# Define important and unimportant tags
important_tags = [
    "low_calorie", "high_calorie", "low_protein", "high_protein", "low_carb", "high_carb",
    "low_sugar", "high_sugar", "low_fiber", "high_fiber", "low_saturated_fat", "high_saturated_fat",
    "low_cholesterol", "high_cholesterol", "low_sodium", "high_sodium"
]
unimportant_tags = [
    "low_calcium", "high_calcium", "low_phosphorus", "high_phosphorus", "low_potassium", "high_potassium",
    "low_iron", "high_iron", "low_folic_acid", "high_folic_acid", "low_vitamin_c", "high_vitamin_c",
    "low_vitamin_d", "high_vitamin_d", "low_vitamin_b12", "high_vitamin_b12"
]

# Create a helper function to get the nutrition tags with value 1 for user or food
def get_tags_with_value_1(row, prefix):
    return [col for col in row.index if row[col] == 1 and col.startswith(prefix)]

# Define a question-answer template
qa_template = """
You must produce output following this template:

Question: For User <SEQN>, given the health profile: <all important nutrition tags of the user, i.e. columns in user_tagging starting with prefix user_ and have value of 1 from the list of important tags>, please judge if Food <food_id> <food_desc>, <all important nutrition tags of the food, i.e. columns in recommendable_foods_tagging starting with high_ or low_ and have value of 1 from the list of important tags>, is a healthy option to the user, and why?
Answer: <Yes/No>, because the food is <high/low> in <nutrients> (these nutrients match with the user's health profile), but <high/low> in <nutrients> (these nutrients are opposite to the user's health profile).
"""

# Iterate over user-food pairs to generate question-answer pairs
question_answer_pairs = []

for _, pair in user_food_pairs_df.iterrows():
    seqn = pair['SEQN']
    food_id = pair['food_id']
    
    # Get user nutritional tags
    user_row = user_tagging_df[user_tagging_df['SEQN'] == seqn]
    if user_row.empty:
        continue
    user_tags = get_tags_with_value_1(user_row.iloc[0], "user_")
    # Filter user_tags to include only important tags
    user_tags = [tag for tag in user_tags if tag.replace("user_", "") in important_tags]

    # Get food nutritional tags
    food_row = recommendable_foods_df[recommendable_foods_df['food_id'] == food_id]
    if food_row.empty:
        continue
    food_tags = get_tags_with_value_1(food_row.iloc[0], ("low_", "high_"))
    # Filter food_tags to include only important tags
    food_tags = [tag for tag in food_tags if tag in important_tags]

    # Create question text
    user_tags_str = ", ".join(user_tags)
    food_desc = food_row.iloc[0]['food_desc']
    food_tags_str = ", ".join(food_tags)
    
    question = (
        f"For User {seqn}, given the health profile: {user_tags_str}, "
        f"please judge if Food {food_id} ({food_desc}), with nutritional properties: {food_tags_str}, "
        "is a healthy option for the user, and why?"
    )

    # Prepare the complete prompt by adding the QA template
    complete_prompt = qa_template + f"\n\n{question}"

    # Generate reply from agent
    try:
        response = agent.generate_reply(
            messages=[{"content": complete_prompt, "role": "user"}]
        )
        
        # Extract the question and answer from the response (since it should be formatted as required)
        question_answer_pairs.append({
            "SEQN": seqn,
            "food_id": food_id,
            "food_desc": food_desc,
            "question": question,
            "answer": response.strip()
        })
        print('*' * 100)
        print(f"Generated answer for SEQN {seqn} and food_id {food_id}:\n\n{response}")

    except Exception as e:
        print(f"Error generating answer for SEQN {seqn} and food_id {food_id}: {e}")
        continue

    # avoid exceeding rate limits
    time.sleep(2)

qa_pairs_df = pd.DataFrame(question_answer_pairs)
# Out:
# [autogen.oai.client: 09-29 10:57:31] {184} WARNING - The API key specified is not a valid OpenAI format; it won't work with the OpenAI-hosted model.
# ****************************************************************************************************
# Generated answer for SEQN 23816 and food_id 91770020:
#
# Question: For User 23816, given the health profile: user_low_calorie, user_low_sodium, user_low_saturated_fat, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 91770020 (Dietetic or low calorie hard candy), with nutritional properties: high_calorie, low_protein, high_carb, high_sugar, low_fiber, low_saturated_fat, low_cholesterol, low_sodium, is a healthy option for the user, and why?
#
# Answer: No, because the food is high in calorie (opposite to user_low_calorie), low in protein (opposite to user_high_protein), high in sugar (opposite to user_low_sugar), low in fiber (opposite to user_high_fiber), low in saturated fat (matches user_low_saturated_fat), low in cholesterol (not directly relevant to the user's health profile), and low in sodium (matches user_low_sodium).
# ****************************************************************************************************
# Generated answer for SEQN 123231 and food_id 14108060:
#
# Question: For User 123231, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 14108060 (Cheese, Parmesan, dry grated, fat free), with nutritional properties: high_calorie, high_protein, low_carb, low_sugar, low_fiber, high_sodium, is a healthy option for the user, and why?
# Answer: No, because the food is high in protein (matches user_high_protein) and low in sugar (matches user_low_sugar), but it is high in sodium (opposite to user_low_sodium) and low in fiber (opposite to user_high_fiber).
# ****************************************************************************************************
# Generated answer for SEQN 123231 and food_id 91770020:
#
# Question: For User 123231, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 91770020 (Dietetic or low calorie hard candy), with nutritional properties: high_calorie, low_protein, high_carb, high_sugar, low_fiber, low_saturated_fat, low_cholesterol, low_sodium, is a healthy option for the user, and why?
#
# Answer: No, because the food is high in calories (opposite of low_calorie), high in sugar (opposite of low_sugar), and low in fiber (opposite of high_fiber).
# ****************************************************************************************************
# Generated answer for SEQN 123231 and food_id 57332050:
#
# Question: For User 123231, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 57332050 (Cereal (General Mills Total Raisin Bran)), with nutritional properties: high_calorie, low_protein, high_carb, high_sugar, high_fiber, low_saturated_fat, low_cholesterol, high_sodium, is a healthy option for the user, and why?
#
# Answer: No, because the food is high in fiber (matches with the user's health profile), but high in sugar and sodium (opposite to the user's health profile).
# ****************************************************************************************************
# Generated answer for SEQN 123231 and food_id 11830210:
#
# Question: For User 123231, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 11830210 (Chocolate beverage powder, light, dry mix, not reconstituted), with nutritional properties: high_calorie, low_protein, high_carb, high_sugar, low_fiber, low_saturated_fat, low_cholesterol, high_sodium, is a healthy option for the user, and why?
# Answer: No, because the food is high in calories (opposite to user_low_calorie), low in protein (opposite to user_high_protein), high in sugar (opposite to user_low_sugar), low in fiber (opposite to user_high_fiber), high in sodium (opposite to user_low_sodium).
# ****************************************************************************************************
# Generated answer for SEQN 123231 and food_id 92309040:
#
# Question: For User 123231, given the health profile: low_calorie, low_sodium, low_protein, high_protein, low_sugar, high_fiber, please judge if Food 92309040 (Tea, iced, bottled, black, unsweetened), with nutritional properties: low_calorie, low_protein, low_carb, low_sugar, low_fiber, low_saturated_fat, low_cholesterol, low_sodium, is a healthy option for the user, and why?
# Answer: Yes, because the food is low in calories (matches user's low calorie profile) and low in sodium (matches user's low sodium profile), but low in protein and fiber (opposite to user's high protein and high fiber profiles). This food aligns with the user's low calorie and low sodium preferences.
# ****************************************************************************************************
# Generated answer for SEQN 123231 and food_id 42101200:
#
# Question: For User 123231, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 42101200 (Almonds, unsalted), with nutritional properties: high_calorie, high_protein, low_carb, low_sugar, high_fiber, low_cholesterol, high_sodium, is a healthy option for the user, and why?
#
# Answer: No, because the food is high in protein (matches with user_high_protein), but high in sodium (opposite to user_low_sodium).
# ****************************************************************************************************
# Generated answer for SEQN 123231 and food_id 42101210:
#
# Question: For User 123231, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 42101210 (Almonds, unsalted), high_calorie, high_protein, low_carb, low_sugar, high_fiber, low_cholesterol, low_sodium, is a healthy option for the user, and why?
# Answer: Yes, because the food is high in fiber (matches the user's health profile), but high in protein (opposite to the user's health profile).
# ****************************************************************************************************
# Generated answer for SEQN 123231 and food_id 95201000:
#
# Question: For User 123231, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 95201000 (Nutritional powder mix (Carnation Instant Breakfast)), with nutritional properties: high_calorie, high_protein, high_sugar, low_fiber, low_saturated_fat, low_cholesterol, high_sodium, is a healthy option for the user, and why?
# Answer: No, because the food is high in protein (matches user's high protein preference) but high in sugar (opposite to user's low sugar preference). Additionally, it is high in sodium which is not suitable for the user's low sodium health profile.
# ****************************************************************************************************
# Generated answer for SEQN 123231 and food_id 42101130:
#
# Question: For User 123231, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 42101130 (Almonds, unsalted), high_calorie, high_protein, low_carb, low_sugar, high_fiber, low_cholesterol, low_sodium, is a healthy option to the user, and why?
#
# Answer: Yes, because the food is high in fiber (matches with user_high_fiber) and low in sodium (matches with user_low_sodium), but high in protein (opposite to user_low_protein) and high in calories (opposite to user_low_calorie). Despite being high in protein and calories, the benefits of high fiber and low sodium make it a healthy option overall for the user.
# ****************************************************************************************************
# Generated answer for SEQN 123231 and food_id 42101300:
#
# Question: For User 123231, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 42101300 (Almonds, flavored), with nutritional properties: high_calorie, high_protein, low_carb, low_sugar, high_fiber, low_cholesterol, high_sodium, is a healthy option for the user, and why?
#
# Answer: No, because the food is high in protein (matches user profile of high protein), but it is high in sodium (opposite to user profile of low sodium). Also, it is high in calorie (opposite to user profile of low calorie), and low in sugar (matches user profile of low sugar).
# ****************************************************************************************************
# Generated answer for SEQN 123231 and food_id 11830120:
#
# Question: For User 123231, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 11830120 (Hot chocolate / Cocoa, dry mix, no sugar added, not reconstituted), with nutritional properties: high_calorie, high_protein, high_sugar, low_fiber, low_cholesterol, high_sodium, is a healthy option for the user, and why?
#
# Answer: No, because the food is high in protein (matches user_high_protein) but high in sugar (opposite of user_low_sugar). Additionally, the food is high in sodium (opposite of user_low_sodium) and low in fiber (opposite of user_high_fiber), which are not aligned with the user's health profile.
# ****************************************************************************************************
# Generated answer for SEQN 83019 and food_id 57332050:
#
# Question: For User 83019, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 57332050 (Cereal (General Mills Total Raisin Bran)), with nutritional properties: high_calorie, low_protein, high_carb, high_sugar, high_fiber, low_saturated_fat, low_cholesterol, high_sodium, is a healthy option for the user, and why?
# Answer: No, because the food is high in fiber (matches user's health profile), but low in protein (opposite to user's health profile).
# ****************************************************************************************************
# Generated answer for SEQN 123231 and food_id 11830165:
#
# Question: For User 123231, given the health profile: low_calorie, low_sodium, low_protein, high_protein, low_sugar, high_fiber, please judge if Food 11830165 (Chocolate beverage powder, light, dry mix, not reconstituted), with nutritional properties: high_calorie, low_protein, high_sugar, high_fiber, low_cholesterol, high_sodium, is a healthy option for the user, and why?
#
# Answer: No, because the food is high in calories (opposite to low_calorie in user's profile), low in protein (opposite to high_protein in user's profile), high in sugar (opposite to low_sugar in user's profile), high in fiber (matches with high_fiber in user's profile), low in cholesterol (not identified as a user profile tag), and high in sodium (opposite to low_sodium in user's profile).
# ****************************************************************************************************
# Generated answer for SEQN 32756 and food_id 91770020:
#
# Question: For User 32756, given the health profile: user_low_calorie, user_low_sodium, user_low_cholesterol, user_low_saturated_fat, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 91770020 (Dietetic or low calorie hard candy), with nutritional properties: high_calorie, low_protein, high_carb, high_sugar, low_fiber, low_saturated_fat, low_cholesterol, low_sodium, is a healthy option for the user, and why?
#
# Answer: No, because the food is high in calorie and sugar, which are opposite to the user's health profile of low calorie and low sugar. Additionally, it is low in fiber and protein, which may not align with the user's preferences for high fiber and protein intake.
# ****************************************************************************************************
# Generated answer for SEQN 24811 and food_id 91770020:
#
# Question: For User 24811, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 91770020 (Dietetic or low calorie hard candy), with nutritional properties: high_calorie, low_protein, high_carb, high_sugar, low_fiber, low_saturated_fat, low_cholesterol, low_sodium, is a healthy option for the user, and why?
# Answer: No, because the food is high in calories (opposite to user_low_calorie), high in sugar (opposite to user_low_sugar), low in protein (matches with user_low_protein), low in fiber (opposite to user_high_fiber), and low in sodium (matches with user_low_sodium).
# ****************************************************************************************************
# Generated answer for SEQN 24811 and food_id 57332050:
#
# Question: For User 24811, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 57332050 (Cereal (General Mills Total Raisin Bran)), with nutritional properties: high_calorie, low_protein, high_carb, high_sugar, high_fiber, low_saturated_fat, low_cholesterol, high_sodium, is a healthy option for the user, and why?
#
# Answer: No, because the food is high in fiber (matches with the user's health profile), but high in sodium (opposite to the user's health profile).
# ****************************************************************************************************
# Generated answer for SEQN 24811 and food_id 11830210:
#
# Question: For User 24811, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 11830210 (Chocolate beverage powder, light, dry mix, not reconstituted), with nutritional properties: high_calorie, low_protein, high_carb, high_sugar, low_fiber, low_saturated_fat, low_cholesterol, high_sodium, is a healthy option for the user, and why?
# Answer: No, because the food is high in calorie (opposite to the user's low-calorie profile), low in protein (opposite to the user's high-protein profile), high in sugar (opposite to the user's low-sugar profile), low in fiber (opposite to the user's high-fiber profile), and high in sodium (opposite to the user's low-sodium profile).
# ****************************************************************************************************
# Generated answer for SEQN 24811 and food_id 92309040:
#
# Question: For User 24811, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 92309040 (Tea, iced, bottled, black, unsweetened), with nutritional properties: low_calorie, low_protein, low_carb, low_sugar, low_fiber, low_saturated_fat, low_cholesterol, low_sodium, is a healthy option for the user, and why?
#
# Answer: Yes, because the food is low in calorie, low in sugar, and low in sodium, matching the user's health profile. However, the food is low in protein, which is opposite to the user's preference for high protein intake.
# ****************************************************************************************************
# Generated answer for SEQN 83019 and food_id 11830165:
#
# Question: For User 83019, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 11830165 (Chocolate beverage powder, light, dry mix, not reconstituted), with nutritional properties: high_calorie, low_protein, high_sugar, high_fiber, low_cholesterol, high_sodium, is a healthy option for the user, and why?
#
# Answer: No, because the food is high in calorie (opposite to user_low_calorie), low in protein (opposite to user_high_protein), high in sugar (opposite to user_low_sugar), and high in sodium (opposite to user_low_sodium).
# ****************************************************************************************************
# Generated answer for SEQN 24811 and food_id 42101200:
#
# Question: For User 24811, given the health profile: low_calorie, low_sodium, low_protein, high_protein, low_sugar, high_fiber, please judge if Food 42101200 (Almonds, unsalted), with nutritional properties: high_calorie, high_protein, low_carb, low_sugar, high_fiber, low_cholesterol, high_sodium, is a healthy option for the user, and why?
# Answer: No, because the food is high in protein (matches with the user's high protein health profile), but high in sodium (opposite to the user's low sodium health profile).
# ****************************************************************************************************
# Generated answer for SEQN 24811 and food_id 42101210:
#
# Question: For User 24811, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 42101210 (Almonds, unsalted), with nutritional properties: high_calorie, high_protein, low_carb, low_sugar, high_fiber, low_cholesterol, low_sodium, is a healthy option for the user, and why?
#
# Answer: Yes, because the food is high in protein (matches user_high_protein profile) and high in fiber (matches user_high_fiber profile), but low in sodium (matches user_low_sodium profile) and low in sugar (matches user_low_sugar profile).
# ****************************************************************************************************
# Generated answer for SEQN 83019 and food_id 91770020:
#
# Question: For User 83019, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 91770020 (Dietetic or low calorie hard candy), with nutritional properties: high_calorie, low_protein, high_carb, high_sugar, low_fiber, low_saturated_fat, low_cholesterol, low_sodium, is a healthy option for the user, and why?
#
# Answer: No, because the food is high in calories (opposite to user_low_calorie) and high in sugar (opposite to user_low_sugar), which do not align with the user's health profile.
# ****************************************************************************************************
# Generated answer for SEQN 83019 and food_id 11830210:
#
# Question: For User 83019, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 11830210 (Chocolate beverage powder, light, dry mix, not reconstituted), with nutritional properties: high_calorie, low_protein, high_carb, high_sugar, low_fiber, low_saturated_fat, low_cholesterol, high_sodium, is a healthy option for the user, and why?
#
# Answer: No, because the food is high in calories (not matching with user_low_calorie) and high in sodium (not matching with user_low_sodium), but low in protein (matching with user_low_protein) and low in fiber (not matching with user_high_fiber).
# ****************************************************************************************************
# Generated answer for SEQN 23816 and food_id 57306700:
#
# Question: For User 23816, given the health profile: user_low_calorie, user_low_sodium, user_low_saturated_fat, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 57306700 (Cereal - Malt-O-Meal Toasted Oat Cereal), with nutritional properties: high_calorie, low_sugar, high_fiber, low_saturated_fat, low_cholesterol, high_sodium, is a healthy option for the user, and why?
#
# Answer: No, because the food is high in fiber and low in sugar, which align with the user's health profile. However, it is high in sodium, which is opposite to the user's preference for low-sodium foods.
# ****************************************************************************************************
# Generated answer for SEQN 93830 and food_id 11830210:
#
# Question: For User 93830, given the health profile: low calorie, low sodium, low protein, high protein, low sugar, high fiber, please judge if Food 11830210 (Chocolate beverage powder, light, dry mix, not reconstituted), with nutritional properties: high calorie, low protein, high carb, high sugar, low fiber, low saturated fat, low cholesterol, high sodium, is a healthy option to the user, and why?
#
# Answer: No, because the food is high in calorie (opposite to user's profile), low in protein (matches with user's profile), high in sugar (opposite to user's profile), low in fiber (opposite to user's profile), and high in sodium (opposite to user's profile).
# ****************************************************************************************************
# Generated answer for SEQN 93830 and food_id 11830165:
#
# Question: For User 93830, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 11830165 (Chocolate beverage powder, light, dry mix, not reconstituted), with nutritional properties: high_calorie, low_protein, high_sugar, high_fiber, low_cholesterol, high_sodium, is a healthy option for the user, and why?
#
# Answer: No, because the food is high in fiber (matches with the user's health profile), but high in calorie, high in sugar, high in sodium (opposite to the user's health profile).
# ****************************************************************************************************
# Generated answer for SEQN 93830 and food_id 11830120:
#
# Question: For User 93830, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 11830120 (Hot chocolate / Cocoa, dry mix, no sugar added, not reconstituted), with nutritional properties: high_calorie, high_protein, high_sugar, low_fiber, low_cholesterol, high_sodium, is a healthy option to the user, and why?
#
# Answer: No, because the food is high in protein (matches with user_high_protein) but high in sodium (opposite to user_low_sodium), and high in sugar (opposite to user_low_sugar).
# ****************************************************************************************************
# Generated answer for SEQN 93830 and food_id 14108060:
#
# Question: For User 93830, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 14108060 (Cheese, Parmesan, dry grated, fat free), with nutritional properties: high_calorie, high_protein, low_carb, low_sugar, low_fiber, high_sodium, is a healthy option for the user, and why?
# Answer: No, because the food is high in protein (matches with user's profile for high protein), but is high in sodium (opposite of the user's low sodium preference). Additionally, the food being high in calories and low in fiber does not align well with the user's low calorie and high fiber health profile.
# ****************************************************************************************************
# Generated answer for SEQN 93830 and food_id 42101300:
#
# Question: For User 93830, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 42101300 (Almonds, flavored), with nutritional properties: high_calorie, high_protein, low_carb, low_sugar, high_fiber, low_cholesterol, high_sodium, is a healthy option for the user, and why?
#
# Answer: No, because the food is high in protein (matches with the user's profile of high protein), but it is high in sodium (opposite to the user's profile of low sodium).
# ****************************************************************************************************
# Generated answer for SEQN 93830 and food_id 42101130:
#
# Question: For User 93830, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 42101130 (Almonds, unsalted), with nutritional properties: high_calorie, high_protein, low_carb, low_sugar, high_fiber, low_cholesterol, low_sodium, is a healthy option for the user, and why?
#
# Answer: Yes, because the food is high in protein (matching the user's high protein requirement) and high in fiber (matching the user's high fiber preference), but low in sodium (suitable for the user's low sodium preference) and low in sugar (matching the user's low sugar requirement).
# ****************************************************************************************************
# Generated answer for SEQN 93830 and food_id 95201000:
#
#
# Question: For User 93830, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 95201000 (Nutritional powder mix (Carnation Instant Breakfast)), with nutritional properties: high_calorie, high_protein, high_sugar, low_fiber, low_saturated_fat, low_cholesterol, high_sodium, is a healthy option for the user, and why?
# Answer: No, because the food is high in protein (matches with the user's high protein need) but high in sugar (opposite to the user's preference for low sugar intake).
# ****************************************************************************************************
# Generated answer for SEQN 93830 and food_id 42101210:
#
# Question: For User 93830, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 42101210 (Almonds, unsalted), with nutritional properties: high_calorie, high_protein, low_carb, low_sugar, high_fiber, low_cholesterol, low_sodium, is a healthy option for the user, and why?
#
# Answer: Yes, because the food is high in fiber (matches with the user's high fiber health profile), but low in calorie, low in sodium, and low in sugar (opposite to the user's low calorie, low sodium, and low sugar health profile).
# ****************************************************************************************************
# Generated answer for SEQN 93830 and food_id 42101200:
#
# Question: For User 93830, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 42101200 (Almonds, unsalted), with nutritional properties: high_calorie, high_protein, low_carb, low_sugar, high_fiber, low_cholesterol, high_sodium, is a healthy option for the user, and why?
# Answer: No, because the food is high in protein (matches with the user's high protein requirement) but high in sodium (opposite to the user's preference for low sodium intake).
# ****************************************************************************************************
# Generated answer for SEQN 93830 and food_id 92309040:
#
# Question: For User 93830, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 92309040 (Tea, iced, bottled, black, unsweetened), with nutritional properties: low_calorie, low_protein, low_carb, low_sugar, low_fiber, low_saturated_fat, low_cholesterol, low_sodium, is a healthy option for the user, and why?
# Answer: Yes, because the food is low in calories (matches with user_low_calorie), low in sodium (matches with user_low_sodium), low in protein (matches with user_low_protein), but it is also low in fiber (opposite to user_high_fiber).
# ****************************************************************************************************
# Generated answer for SEQN 93830 and food_id 57332050:
#
# Question: For User 93830, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 57332050 (Cereal (General Mills Total Raisin Bran)), with nutritional properties: high_calorie, low_protein, high_carb, high_sugar, high_fiber, low_saturated_fat, low_cholesterol, high_sodium, is a healthy option for the user, and why?
#
# Answer: No, because the food is high in fiber (matches with the user's high fiber requirement), but it is high in sodium (opposite to the user's low sodium requirement).
# ****************************************************************************************************
# Generated answer for SEQN 83019 and food_id 92309040:
#
# Question: For User 83019, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 92309040 (Tea, iced, bottled, black, unsweetened), with nutritional properties: low_calorie, low_protein, low_carb, low_sugar, low_fiber, low_saturated_fat, low_cholesterol, low_sodium, is a healthy option for the user, and why?
# Answer: Yes, because the food is low in calorie, low in protein (matches the user's health profile), but it's also low in sodium (opposite to the user's health profile).
# ****************************************************************************************************
# Generated answer for SEQN 93830 and food_id 91770020:
#
# Question: For User 93830, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 91770020 (Dietetic or low calorie hard candy), with nutritional properties: high_calorie, low_protein, high_carb, high_sugar, low_fiber, low_saturated_fat, low_cholesterol, low_sodium, is a healthy option for the user, and why?
#
# Answer: No, because the food is high in calories and high in sugar, which are opposite to the user's health profile of low calorie and low sugar. Additionally, the food is low in protein, which is not ideal for the user who requires a high protein intake.
# ****************************************************************************************************
# Generated answer for SEQN 83019 and food_id 11830165:
#
# Question: For User 83019, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 11830165 (Chocolate beverage powder, light, dry mix, not reconstituted), with nutritional properties: high_calorie, low_protein, high_sugar, high_fiber, low_cholesterol, high_sodium, is a healthy option for the user, and why?
#
# Answer: No, because the food is high in calorie (opposite to user_low_calorie), low in protein (opposite to user_high_protein), high in sugar (opposite to user_low_sugar), and high in sodium (opposite to user_low_sodium).
# ****************************************************************************************************
# Generated answer for SEQN 83019 and food_id 11830120:
#
# Question: For User 83019, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 11830120 (Hot chocolate / Cocoa, dry mix, no sugar added, not reconstituted), with nutritional properties: high_calorie, high_protein, high_sugar, low_fiber, low_cholesterol, high_sodium, is a healthy option for the user, and why?
# Answer: No, because the food is high in protein (matches user_high_protein), but it is high in sugar (opposite to user_low_sugar). Additionally, it is high in sodium (opposite to user_low_sodium) and low in fiber (opposite to user_high_fiber), which are not suitable for the user's health profile.
# ****************************************************************************************************
# Generated answer for SEQN 83019 and food_id 14108060:
#
# Question: For User 83019, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 14108060 (Cheese, Parmesan, dry grated, fat free), with nutritional properties: high_calorie, high_protein, low_carb, low_sugar, low_fiber, high_sodium, is a healthy option for the user, and why?
# Answer: No, because the food is high in protein (matches with the user's high protein profile), but low in fiber (opposite to the user's high fiber profile). Additionally, it is high in sodium which is opposite to the user's low sodium preference.
# ****************************************************************************************************
# Generated answer for SEQN 83019 and food_id 42101300:
#
# Question: For User 83019, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 42101300 (Almonds, flavored), with nutritional properties: high_calorie, high_protein, low_carb, low_sugar, high_fiber, low_cholesterol, high_sodium, is a healthy option for the user, and why?
# Answer: No, because the food is high in protein (matches with user_high_protein), and high in fiber (matches with user_high_fiber), but high in sodium (opposite to user_low_sodium).
# ****************************************************************************************************
# Generated answer for SEQN 83019 and food_id 42101130:
#
# Question: For User 83019, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 42101130 (Almonds, unsalted), with nutritional properties: high_calorie, high_protein, low_carb, low_sugar, high_fiber, low_cholesterol, low_sodium, is a healthy option for the user, and why?
#
# Answer: Yes, because the food is high in fiber (matches with the user's high fiber requirement), but low in sodium (opposite to the user's low sodium preference).
# ****************************************************************************************************
# Generated answer for SEQN 83019 and food_id 95201000:
#
# Question: For User 83019, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 95201000 (Nutritional powder mix (Carnation Instant Breakfast)), with nutritional properties: high_calorie, high_protein, high_sugar, low_fiber, low_saturated_fat, low_cholesterol, high_sodium, is a healthy option for the user, and why?
#
# Answer: No, because the food is high in protein (matches with the user's high protein requirement), but high in sodium and sugar (opposite to the user's low sodium and sugar preferences). Additionally, the food is low in fiber, which is also not ideal for this user's health profile.
# ****************************************************************************************************
# Generated answer for SEQN 83019 and food_id 42101210:
#
# Question: For User 83019, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 42101210 (Almonds, unsalted), with nutritional properties: high_calorie, high_protein, low_carb, low_sugar, high_fiber, low_cholesterol, low_sodium, is a healthy option for the user, and why?
#
# Answer: Yes, because the food is high in protein and high in fiber, which align with the user's health profile of requiring high protein and high fiber. However, the food is high in calories, which may not be ideal for the user's low-calorie preference.
# ****************************************************************************************************
# Generated answer for SEQN 83019 and food_id 42101200:
#
# Question: For User 83019, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 42101200 (Almonds, unsalted), with nutritional properties: high_calorie, high_protein, low_carb, low_sugar, high_fiber, low_cholesterol, high_sodium, is a healthy option for the user, and why?
# Answer: No, because the food is high in protein (which is good for the user's profile of high protein) but also high in sodium (opposite to the user's profile of low sodium).
# ****************************************************************************************************
# Generated answer for SEQN 24811 and food_id 95201000:
#
# Question: For User 24811, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 95201000 (Nutritional powder mix (Carnation Instant Breakfast)), with nutritional properties: high_calorie, high_protein, high_sugar, low_fiber, low_saturated_fat, low_cholesterol, high_sodium, is a healthy option for the user, and why?
# Answer: No, because the food is high in protein (matches with the user's health profile), but high in sugar and high in sodium (opposite to the user's health profile). Additionally, it is low in fiber, which is not ideal for the user's high fiber requirement.
# ****************************************************************************************************
# Generated answer for SEQN 24811 and food_id 42101130:
#
# Question: For User 24811, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 42101130 (Almonds, unsalted), with nutritional properties: high_calorie, high_protein, low_carb, low_sugar, high_fiber, low_cholesterol, low_sodium, is a healthy option for the user, and why?
# Answer: Yes, because the food is high in fiber (matches user_high_fiber) and high in protein (matches user_high_protein), but low in sodium (opposite of user_low_sodium).
# ****************************************************************************************************
# Generated answer for SEQN 24811 and food_id 42101300:
#
# Question: For User 24811, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 42101300 (Almonds, flavored), high_calorie, high_protein, low_carb, low_sugar, high_fiber, low_cholesterol, high_sodium, is a healthy option to the user, and why?
#
# Answer: No, because the food is high in protein (matches with the user's profile of high protein) but also high in sodium (opposite to the user's low sodium preference).
# ****************************************************************************************************
# Generated answer for SEQN 83019 and food_id 42101200:
#
# Question: For User 83019, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 42101200 (Almonds, unsalted), with nutritional properties: high_calorie, high_protein, low_carb, low_sugar, high_fiber, low_cholesterol, high_sodium, is a healthy option for the user, and why?
# Answer: No, because the food is high in protein (which is good for the user's profile of high protein) but also high in sodium (opposite to the user's profile of low sodium).
# ****************************************************************************************************
# Generated answer for SEQN 100851 and food_id 11830120:
#
# Question: For User 100851, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 11830120 (Hot chocolate / Cocoa, dry mix, no sugar added, not reconstituted), with nutritional properties: high_calorie, high_protein, high_sugar, low_fiber, low_cholesterol, high_sodium, is a healthy option for the user, and why?
#
# Answer: No, because the food is high in protein (matches with user_high_protein) but high in sugar (opposite to user_low_sugar).
# ****************************************************************************************************
# Generated answer for SEQN 100851 and food_id 11830165:
#
# Question: For User 100851, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 11830165 (Chocolate beverage powder, light, dry mix, not reconstituted), with nutritional properties: high_calorie, low_protein, high_sugar, high_fiber, low_cholesterol, high_sodium, is a healthy option for the user, and why?
#
# Answer: No, because the food is high in fiber (matches user's profile) but high in sugar and sodium (opposite to the user's profile).
# ****************************************************************************************************
# Generated answer for SEQN 83019 and food_id 11830165:
#
# Question: For User 83019, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 11830165 (Chocolate beverage powder, light, dry mix, not reconstituted), with nutritional properties: high_calorie, low_protein, high_sugar, high_fiber, low_cholesterol, high_sodium, is a healthy option for the user, and why?
#
# Answer: No, because the food is high in calorie (opposite to user_low_calorie), low in protein (opposite to user_high_protein), high in sugar (opposite to user_low_sugar), and high in sodium (opposite to user_low_sodium).
# ****************************************************************************************************
# Generated answer for SEQN 83019 and food_id 11830120:
#
# Question: For User 83019, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 11830120 (Hot chocolate / Cocoa, dry mix, no sugar added, not reconstituted), with nutritional properties: high_calorie, high_protein, high_sugar, low_fiber, low_cholesterol, high_sodium, is a healthy option for the user, and why?
# Answer: No, because the food is high in protein (matches user_high_protein), but it is high in sugar (opposite to user_low_sugar). Additionally, it is high in sodium (opposite to user_low_sodium) and low in fiber (opposite to user_high_fiber), which are not suitable for the user's health profile.
# ****************************************************************************************************
# Generated answer for SEQN 83019 and food_id 14108060:
#
# Question: For User 83019, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 14108060 (Cheese, Parmesan, dry grated, fat free), with nutritional properties: high_calorie, high_protein, low_carb, low_sugar, low_fiber, high_sodium, is a healthy option for the user, and why?
# Answer: No, because the food is high in protein (matches with the user's high protein profile), but low in fiber (opposite to the user's high fiber profile). Additionally, it is high in sodium which is opposite to the user's low sodium preference.
# ****************************************************************************************************
# Generated answer for SEQN 83019 and food_id 42101300:
#
# Question: For User 83019, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 42101300 (Almonds, flavored), with nutritional properties: high_calorie, high_protein, low_carb, low_sugar, high_fiber, low_cholesterol, high_sodium, is a healthy option for the user, and why?
# Answer: No, because the food is high in protein (matches with user_high_protein), and high in fiber (matches with user_high_fiber), but high in sodium (opposite to user_low_sodium).
# ****************************************************************************************************
# Generated answer for SEQN 83019 and food_id 42101130:
#
# Question: For User 83019, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 42101130 (Almonds, unsalted), with nutritional properties: high_calorie, high_protein, low_carb, low_sugar, high_fiber, low_cholesterol, low_sodium, is a healthy option for the user, and why?
#
# Answer: Yes, because the food is high in fiber (matches with the user's high fiber requirement), but low in sodium (opposite to the user's low sodium preference).
# ****************************************************************************************************
# Generated answer for SEQN 83019 and food_id 95201000:
#
# Question: For User 83019, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 95201000 (Nutritional powder mix (Carnation Instant Breakfast)), with nutritional properties: high_calorie, high_protein, high_sugar, low_fiber, low_saturated_fat, low_cholesterol, high_sodium, is a healthy option for the user, and why?
#
# Answer: No, because the food is high in protein (matches with the user's high protein requirement), but high in sodium and sugar (opposite to the user's low sodium and sugar preferences). Additionally, the food is low in fiber, which is also not ideal for this user's health profile.
# ****************************************************************************************************
# Generated answer for SEQN 83019 and food_id 42101210:
#
# Question: For User 83019, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 42101210 (Almonds, unsalted), with nutritional properties: high_calorie, high_protein, low_carb, low_sugar, high_fiber, low_cholesterol, low_sodium, is a healthy option for the user, and why?
#
# Answer: Yes, because the food is high in protein and high in fiber, which align with the user's health profile of requiring high protein and high fiber. However, the food is high in calories, which may not be ideal for the user's low-calorie preference.
# ****************************************************************************************************
# Generated answer for SEQN 83019 and food_id 92309040:
#
# Question: For User 83019, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 92309040 (Tea, iced, bottled, black, unsweetened), with nutritional properties: low_calorie, low_protein, low_carb, low_sugar, low_fiber, low_saturated_fat, low_cholesterol, low_sodium, is a healthy option for the user, and why?
# Answer: Yes, because the food is low in calorie, low in protein (matches the user's health profile), but it's also low in sodium (opposite to the user's health profile).
# ****************************************************************************************************
# Generated answer for SEQN 83019 and food_id 11830120:
#
# Question: For User 83019, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 11830120 (Hot chocolate / Cocoa, dry mix, no sugar added, not reconstituted), with nutritional properties: high_calorie, high_protein, high_sugar, low_fiber, low_cholesterol, high_sodium, is a healthy option for the user, and why?
# Answer: No, because the food is high in protein (matches user_high_protein), but it is high in sugar (opposite to user_low_sugar). Additionally, it is high in sodium (opposite to user_low_sodium) and low in fiber (opposite to user_high_fiber), which are not suitable for the user's health profile.
# ****************************************************************************************************
# Generated answer for SEQN 83019 and food_id 11830210:
#
# ...
# ****************************************************************************************************
# Generated answer for SEQN 32756 and food_id 75219013:
#
# Question: For User 32756, given the health profile: user_low_calorie, user_low_sodium, user_low_cholesterol, user_low_saturated_fat, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 75219013 (Mushrooms, cooked, from canned, fat not added in cooking), with nutritional properties: low_calorie, low_protein, low_carb, low_sugar, low_fiber, low_saturated_fat, low_cholesterol, high_sodium, is a healthy option for the user, and why?
# Answer: No, because the food is low in calories, low in saturated fat, and low in cholesterol which align with the user's health profile. However, it is high in sodium, which is opposite to the user's health profile of low sodium intake.
# ****************************************************************************************************
# Generated answer for SEQN 100851 and food_id 83204030:
#
# Question: For User 100851, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 83204030 (Mayonnaise, reduced fat, with olive oil), with nutritional properties: high_calorie, low_protein, low_carb, low_sugar, low_fiber, high_saturated_fat, high_sodium, is a healthy option for the user, and why?
#
# Answer: No, because the food is high in saturated fat and sodium, which are opposite to the user's health profile. Additionally, the food is low in fiber and protein, which are not in line with the user's dietary preferences for high fiber and protein intake.
# ****************************************************************************************************
# Generated answer for SEQN 100851 and food_id 53720700:
#
# Question: For User 100851, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 53720700 (Nutrition bar (Tiger's Milk)), with nutritional properties: high_calorie, high_protein, high_sugar, low_cholesterol, high_sodium, is a healthy option for the user, and why?
# Answer: No, because the food is high in protein (matches the user's high protein preference), but high in sugar and sodium (opposite to the user's low sugar and low sodium preferences).
# ****************************************************************************************************
# Generated answer for SEQN 100851 and food_id 57305174:
#
# Question: For User 100851, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 57305174 (Cereal (Malt-O-Meal Colossal Crunch)), with nutritional properties: high_calorie, low_protein, high_carb, high_sugar, low_fiber, low_cholesterol, high_sodium, is a healthy option for the user, and why?
#
# Answer: No, because the food is high in calories (opposite to user's low calorie preference), low in protein (opposite to user's high protein preference), high in sugar (opposite to user's low sugar preference), and high in sodium (opposite to user's low sodium preference).
# ****************************************************************************************************
# Generated answer for SEQN 93830 and food_id 57342010:
#
# Question: For User 93830, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 57342010 (Cereal (Kellogg's Smorz)), with nutritional properties: high_calorie, low_protein, high_carb, high_sugar, low_fiber, low_cholesterol, high_sodium, is a healthy option for the user, and why?
# Answer: No, because the food is high in calories (opposite to user_low_calorie), low in protein (opposite to user_high_protein), high in sugar (opposite to user_low_sugar), low in fiber (opposite to user_high_fiber), and high in sodium (opposite to user_low_sodium).
# ****************************************************************************************************
# Generated answer for SEQN 83019 and food_id 57316385:
#
# Question: For User 83019, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 57316385 (Cereal (General Mills Cheerios Protein)), with nutritional properties: high_calorie, high_carb, high_sugar, high_fiber, low_saturated_fat, low_cholesterol, high_sodium, is a healthy option for the user, and why?
#
# Answer: Yes, because the food is high in fiber (matches user_high_fiber), but high in sodium (opposite to user_low_sodium).
# ****************************************************************************************************
# Generated answer for SEQN 115518 and food_id 11830115:
#
# Question: For User 115518, given the health profile: user_low_calorie, user_low_sodium, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 11830115 (Hot chocolate / Cocoa, dry mix, no sugar added, not reconstituted), with nutritional properties: high_calorie, high_protein, high_sugar, low_cholesterol, high_sodium, is a healthy option for the user, and why?
#
# Answer: No, because the food is high in protein (matches user_high_protein) but high in sugar (opposite to user_low_sugar). Additionally, it's high in sodium (opposite to user_low_sodium) which is not ideal for the user's health profile.
# ****************************************************************************************************
# Generated answer for SEQN 100851 and food_id 57308400:
#
# Question: For User 100851, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 57308400 (Cereal, O's, multigrain), with nutritional properties: high_calorie, low_protein, high_carb, high_fiber, low_saturated_fat, low_cholesterol, high_sodium, is a healthy option for the user, and why?
# Answer: No, because the food is high in calorie (opposite to user_low_calorie), low in protein (matches user_low_protein), high in fiber (matches user_high_fiber), but high in sodium (opposite to user_low_sodium).
# ****************************************************************************************************
# Generated answer for SEQN 100851 and food_id 57137000:
#
# Question: For User 100851, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 57137000 (Cereal, corn puffs), high_calorie, low_protein, high_carb, high_fiber, low_saturated_fat, low_cholesterol, high_sodium, is a healthy option to the user, and why?
#
# Answer: No, because the food is high in fiber (matches with user_high_fiber) and low in protein (matches with user_low_protein), but it is high in sodium (opposite to user_low_sodium).
# ****************************************************************************************************
# Generated answer for SEQN 100851 and food_id 41430010:
#
# Question: For User 100851, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 41430010 (Vermicelli, made from soybeans), with nutritional properties: high_calorie, high_protein, low_carb, low_sugar, low_saturated_fat, low_cholesterol, high_sodium, is a healthy option for the user, and why?
# Answer: No, because the food is high in protein (matches user's high protein preference), but high in sodium (opposite to user's low sodium preference).
# ****************************************************************************************************
# Generated answer for SEQN 83019 and food_id 92304100:
#
# Question: For User 83019, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 92304100 (Tea, hot, leaf, oolong), with nutritional properties: low_calorie, low_protein, low_carb, low_sugar, low_fiber, low_saturated_fat, low_cholesterol, low_sodium, is a healthy option for the user, and why?
#
# Answer: Yes, because the food is low in sodium (matches user's profile) and low in sugar (matches user's profile), but it is low in protein (opposite of user's profile).
# ****************************************************************************************************
# Generated answer for SEQN 100851 and food_id 57209000:
#
# Question: For User 100851, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 57209000 (Cereal (Post Bran Flakes)), with nutritional properties: high_calorie, low_protein, high_carb, high_fiber, low_saturated_fat, low_cholesterol, high_sodium, is a healthy option for the user, and why?
#
# Answer: No, because the food is high in fiber (matches with user_high_fiber) but low in protein (opposite to user_high_protein). Additionally, the food is high in sodium (opposite to user_low_sodium) which is not suitable for the user's health profile.
# ****************************************************************************************************
# Generated answer for SEQN 100851 and food_id 14410100:
#
# Question: For User 100851, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 14410100 (Cheese, American and Swiss blends), with nutritional properties: high_calorie, high_protein, low_carb, low_sugar, low_fiber, high_saturated_fat, high_cholesterol, high_sodium, is a healthy option for the user, and why?
#
# Answer: No, because the food is high in protein (matches user_high_protein) but high in saturated fat, cholesterol, and sodium (opposite to user_low_sodium and user_low_protein).
# ****************************************************************************************************
# Generated answer for SEQN 100851 and food_id 57206700:
#
# Question: For User 100851, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 57206700 (Cereal (General Mills Fiber One)), with nutritional properties: low_protein, high_carb, low_sugar, high_fiber, low_saturated_fat, low_cholesterol, high_sodium, is a healthy option for the user, and why?
# Answer: Yes, because the food is high in fiber and low in sugar, which align with the user's health profile. However, it is high in sodium, which is opposite to the user's preference for low-sodium options.
# ****************************************************************************************************
# Generated answer for SEQN 100851 and food_id 57213850:
#
# Question: For User 100851, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 57213850 (Cereal (General Mills Cheerios Frosted)), with nutritional properties: high_calorie, low_protein, high_carb, high_sugar, low_saturated_fat, low_cholesterol, high_sodium, is a healthy option for the user, and why?
#
# Answer: No, because the food is high in calorie (opposite to user_low_calorie), low in protein (matches with user's health profile), high in sugar (opposite to user_low_sugar), and high in sodium (opposite to user_low_sodium).
# ****************************************************************************************************
# Generated answer for SEQN 83019 and food_id 54202010:
#
# Question: For User 83019, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 54202010 (Crackers, matzo, reduced sodium), with nutritional properties: high_calorie, low_protein, low_sugar, low_fiber, low_cholesterol, high_sodium, is a healthy option for the user, and why?
#
# Answer: No, because the food is high in sodium (matches with user_high_sodium), but low in fiber and protein (opposite to user_high_fiber and user_high_protein). Additionally, the food is high in calories, which is not suitable for the user's low-calorie health profile.
# ****************************************************************************************************
# Generated answer for SEQN 100851 and food_id 57224000:
#
# Question: For User 100851, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 57224000 (Cereal (General Mills Golden Grahams)), with nutritional properties: high_calorie, low_protein, high_carb, high_sugar, low_saturated_fat, low_cholesterol, high_sodium, is a healthy option for the user, and why?
#
# Answer: No, because the food is high in calories (opposite to user_low_calorie), high in sugar (opposite to user_low_sugar), and high in sodium (opposite to user_low_sodium).
# ****************************************************************************************************
# Generated answer for SEQN 100851 and food_id 57409100:
#
# Question: For User 100851, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 57409100 (Cereal (Post Waffle Crisp)), with nutritional properties: high_calorie, low_protein, high_carb, high_sugar, low_fiber, low_saturated_fat, low_cholesterol, high_sodium, is a healthy option for the user, and why?
# Answer: No, because the food is high in calorie (opposite to user_low_calorie), low in protein (matches user_low_protein), high in sugar (opposite to user_low_sugar), low in fiber (opposite to user_high_fiber), high in sodium (opposite to user_low_sodium).
# ****************************************************************************************************
# Generated answer for SEQN 100851 and food_id 54304500:
#
# Question: For User 100851, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 54304500 (Crackers, cheese, whole grain), with nutritional properties: high_calorie, low_protein, high_carb, low_sugar, high_fiber, low_saturated_fat, low_cholesterol, high_sodium, is a healthy option for the user, and why?
# Answer: No, because the food is high in calories (user_low_calorie), low in protein (user_low_protein), high in sodium (user_low_sodium), and low in sugar (user_low_sugar), which do not align with the user's health profile.
# ****************************************************************************************************
# Generated answer for SEQN 100851 and food_id 57215000:
#
# Question: For User 100851, given the health profile: user_low_calorie, user_low_sodium, user_low_protein, user_high_protein, user_low_sugar, user_high_fiber, please judge if Food 57215000 (Cereal (Kellogg's Frosted Mini-Wheats)), high_calorie, low_protein, high_carb, high_sugar, low_saturated_fat, low_cholesterol, high_sodium, is a healthy option to the user, and why?
#
# Answer: No, because the food is high in calories (user_low_calorie), high in sodium (user_low_sodium), and high in sugar (user_low_sugar), which do not align with the user's health profile. Additionally, it is low in protein (user_low_protein) and fiber (user_high_fiber), which are important components for the user's diet.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 112
#     109         continue
#     111     # Adding delay to avoid exceeding rate limits
# --> 112     time.sleep(2)
#     114 # Convert the question-answer pairs to a DataFrame
#     115 qa_pairs_df = pd.DataFrame(question_answer_pairs)
#
# KeyboardInterrupt:

# %%
qa_pairs_df.to_csv('../processed_data/recommendable_foods_question_answers.csv', index=False)
